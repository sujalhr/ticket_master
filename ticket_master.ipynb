# %% [markdown]
# # Ticketmaster - Event Data Fetching

# %% [markdown]
# ## **event end time/duration**

# %%
from google.colab import userdata

import requests
import pandas as pd
import json
from datetime import datetime
from IPython.display import display, HTML
import os
print(f"Current working directory: {os.getcwd()}")
api_key = userdata.get('TICKETMASTER_API_KEY')
base_url = "https://app.ticketmaster.com/discovery/v2/events.json"

def fetch_events(
    # Basic parameters
    country_code=None,
    size=20,
    page=0,
    sort="date,asc",

    # Identification parameters
    id=None,
    keyword=None,
    attraction_id=None,
    venue_id=None,

    # Geographic parameters
    city=None,
    state_code=None,
    postal_code=None,
    latlong=None,
    geo_point=None,
    radius=None,
    unit="miles",
    dma_id=None,

    # Date and time parameters
    start_date_time=None,
    end_date_time=None,
    local_start_date_time=None,
    local_start_end_date_time=None,
    start_end_date_time=None,

    # Classification parameters
    classification_name=None,
    classification_id=None,
    segment_id=None,
    segment_name=None,
    genre_id=None,
    sub_genre_id=None,
    type_id=None,
    sub_type_id=None,

    # Sale parameters
    onsale_start_date_time=None,
    onsale_end_date_time=None,
    onsale_on_start_date=None,
    onsale_on_after_start_date=None,
    pre_sale_date_time=None,
    public_visibility_start_date_time=None,

    # Include/exclude parameters
    include_tba="yes",
    include_tbd="yes",
    include_test="no",
    include_family="yes",
    include_spellcheck="no",

    # Other filtering parameters
    market_id=None,
    promoter_id=None,
    collection_id=None,
    source=None,
    locale="en",
    domain=None,
    preferred_country="us"
):
    # Define parameters dict with base parameters
    params = {
        'apikey': api_key,
        'size': size,
        'page': page,
        'sort': sort,
        'includeTBA': include_tba,
        'includeTBD': include_tbd,
        'includeTest': include_test,
        'includeFamily': include_family,
        'includeSpellcheck': include_spellcheck,
        'locale': locale,
        'preferredCountry': preferred_country
    }

    # Helper function to add parameters if they're provided
    def add_param(param_name, value, api_param_name=None):
        if value is not None:
            params[api_param_name or param_name] = value

    # Add identification parameters
    add_param('id', id)
    add_param('keyword', keyword)
    add_param('attractionId', attraction_id)
    add_param('venueId', venue_id)

    # Add geographic parameters
    add_param('countryCode', country_code)
    add_param('city', city)
    add_param('stateCode', state_code)
    add_param('postalCode', postal_code)
    add_param('latlong', latlong)
    add_param('geoPoint', geo_point)
    add_param('radius', radius)
    add_param('unit', unit)
    add_param('dmaId', dma_id)

    # Add date/time parameters
    add_param('startDateTime', start_date_time)
    add_param('endDateTime', end_date_time)
    add_param('localStartDateTime', local_start_date_time)
    add_param('localStartEndDateTime', local_start_end_date_time)
    add_param('startEndDateTime', start_end_date_time)

    # Add classification parameters
    add_param('classificationName', classification_name)
    add_param('classificationId', classification_id)
    add_param('segmentId', segment_id)
    add_param('segmentName', segment_name)
    add_param('genreId', genre_id)
    add_param('subGenreId', sub_genre_id)
    add_param('typeId', type_id)
    add_param('subTypeId', sub_type_id)

    # Add sale parameters
    add_param('onsaleStartDateTime', onsale_start_date_time)
    add_param('onsaleEndDateTime', onsale_end_date_time)
    add_param('onsaleOnStartDate', onsale_on_start_date)
    add_param('onsaleOnAfterStartDate', onsale_on_after_start_date)
    add_param('preSaleDateTime', pre_sale_date_time)
    add_param('publicVisibilityStartDateTime', public_visibility_start_date_time)

    # Add other filtering parameters
    add_param('marketId', market_id)
    add_param('promoterId', promoter_id)
    add_param('collectionId', collection_id)
    add_param('source', source)
    add_param('domain', domain)

    # Make the API request
    response = requests.get(base_url, params=params)

    # Check if the request was successful
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error: {response.status_code}")
        print(response.text)
        return None

# Process the events data into structured format
# Updated Process Events Function with proper end time and duration handling

def process_events(events_data):
    if not events_data or '_embedded' not in events_data:
        print("No events found or invalid response")
        return None

    event_list = []

    for event in events_data['_embedded']['events']:
        # Extract basic event info
        event_info = {
            'id': event['id'],
            'name': event['name'],
            #'url': event['url'],
            'status': event['dates']['status']['code'] if 'status' in event['dates'] else 'unknown',
            'start_date': event['dates']['start'].get('localDate', 'unknown'),
            'start_time': event['dates']['start'].get('localTime', 'unknown'),
        }

        # Add end date and time if available
        if 'end' in event['dates']:
            event_info['end_date'] = event['dates']['end'].get('localDate', 'unknown')
            event_info['end_time'] = event['dates']['end'].get('localTime', 'unknown')
        else:
            event_info['end_date'] = 'not specified'
            event_info['end_time'] = 'not specified'

        # Calculate duration if possible
        if ('end' in event['dates'] and
            event_info['start_date'] != 'unknown' and event_info['start_time'] != 'unknown' and
            event_info['end_date'] != 'unknown' and event_info['end_time'] != 'unknown'):
            try:
                # Fix the datetime format if the time format doesn't include seconds
                start_time = event_info['start_time']
                end_time = event_info['end_time']

                # Add seconds if they're not present
                if len(start_time) == 5:  # Format is HH:MM
                    start_time += ":00"
                if len(end_time) == 5:    # Format is HH:MM
                    end_time += ":00"

                start_dt = datetime.strptime(f"{event_info['start_date']} {start_time}", "%Y-%m-%d %H:%M:%S")
                end_dt = datetime.strptime(f"{event_info['end_date']} {end_time}", "%Y-%m-%d %H:%M:%S")
                duration = end_dt - start_dt
                event_info['duration_minutes'] = round(duration.total_seconds() / 60)
                # Add a human-readable duration
                hours, remainder = divmod(event_info['duration_minutes'], 60)
                if hours > 0:
                    event_info['duration_formatted'] = f"{hours} hour{'s' if hours != 1 else ''}"
                    if remainder > 0:
                        event_info['duration_formatted'] += f" {remainder} minute{'s' if remainder != 1 else ''}"
                else:
                    event_info['duration_formatted'] = f"{remainder} minute{'s' if remainder != 1 else ''}"
            except Exception as e:
                # Handle cases where time formats might be different
                print(f"Error calculating duration for event {event['id']}: {e}")
                event_info['duration_minutes'] = 'unknown'
                event_info['duration_formatted'] = 'unknown'
        else:
            event_info['duration_minutes'] = 'not available'
            event_info['duration_formatted'] = 'not available'

        # Rest of your existing code to extract venue, price, etc.
        # (Remaining code unchanged)

        # Add venue info if available
        if '_embedded' in event and 'venues' in event['_embedded'] and len(event['_embedded']['venues']) > 0:
            venue = event['_embedded']['venues'][0]
            event_info['venue_id'] = venue.get('id', 'unknown')
            event_info['venue_name'] = venue.get('name', 'unknown')
            event_info['venue_city'] = venue.get('city', {}).get('name', 'unknown')
            event_info['venue_state'] = venue.get('state', {}).get('name', 'unknown')
            event_info['venue_country'] = venue.get('country', {}).get('name', 'unknown')
            event_info['venue_postal_code'] = venue.get('postalCode', 'unknown')
            event_info['venue_url'] = venue.get('url', 'unknown')

            # Add venue coordinates if available
            if 'location' in venue:
                event_info['venue_latitude'] = venue['location'].get('latitude', 'unknown')
                event_info['venue_longitude'] = venue['location'].get('longitude', 'unknown')

        # Add price range if available
        if 'priceRanges' in event and len(event['priceRanges']) > 0:
            price_range = event['priceRanges'][0]
            event_info['min_price'] = price_range.get('min', 'unknown')
            event_info['max_price'] = price_range.get('max', 'unknown')
            event_info['currency'] = price_range.get('currency', 'unknown')

        # Add genre/classification if available
        if 'classifications' in event and len(event['classifications']) > 0:
            classification = event['classifications'][0]
            if 'segment' in classification and classification['segment']:
                event_info['segment'] = classification['segment'].get('name', 'unknown')
                event_info['segment_id'] = classification['segment'].get('id', 'unknown')
            if 'genre' in classification and classification['genre']:
                event_info['genre'] = classification['genre'].get('name', 'unknown')
                event_info['genre_id'] = classification['genre'].get('id', 'unknown')
            if 'subGenre' in classification and classification['subGenre']:
                event_info['subgenre'] = classification['subGenre'].get('name', 'unknown')
                event_info['subgenre_id'] = classification['subGenre'].get('id', 'unknown')
            if 'type' in classification and classification['type']:
                event_info['type'] = classification['type'].get('name', 'unknown')
                event_info['type_id'] = classification['type'].get('id', 'unknown')
            if 'subType' in classification and classification['subType']:
                event_info['subtype'] = classification['subType'].get('name', 'unknown')
                event_info['subtype_id'] = classification['subType'].get('id', 'unknown')

        # Add image URLs if available
        if 'images' in event and len(event['images']) > 0:
            # Find standard image
            standard_images = [img for img in event['images'] if img.get('ratio') == '16_9' and img.get('width') > 500]
            if standard_images:
                event_info['image_url'] = standard_images[0]['url']
            else:
                event_info['image_url'] = event['images'][0]['url']  # Fallback to first image

        # Add attractions/performers if available
        if '_embedded' in event and 'attractions' in event['_embedded'] and len(event['_embedded']['attractions']) > 0:
            attractions = []
            attraction_ids = []
            for attraction in event['_embedded']['attractions']:
                attractions.append(attraction.get('name', 'unknown'))
                attraction_ids.append(attraction.get('id', 'unknown'))
            event_info['attractions'] = ', '.join(attractions)
            event_info['attraction_ids'] = ', '.join(attraction_ids)

        # Add ticket info if available
        if 'sales' in event and 'public' in event['sales']:
            sales_public = event['sales']['public']
            if 'startDateTime' in sales_public:
                event_info['on_sale_date'] = sales_public['startDateTime']
            if 'endDateTime' in sales_public:
                event_info['off_sale_date'] = sales_public['endDateTime']

        # Add pre-sale info if available
        if 'sales' in event and 'presales' in event['sales'] and len(event['sales']['presales']) > 0:
            presale = event['sales']['presales'][0]  # Get the first pre-sale info
            event_info['presale_name'] = presale.get('name', 'unknown')
            event_info['presale_start_date'] = presale.get('startDateTime', 'unknown')
            event_info['presale_end_date'] = presale.get('endDateTime', 'unknown')

        event_list.append(event_info)

    # Create DataFrame
    df = pd.DataFrame(event_list)
    return df

# Modified display function to show end time and duration in the output
def display_structured_events(events_data):
    # Process the events
    events_df = process_events(events_data)

    if events_df is not None and not events_df.empty:
        # Display info
        print(f"Found {len(events_df)} events")

        # Display pagination info if available
        if 'pagination_info' in events_data:
            pagination = events_data['pagination_info']
            print("\n=== PAGINATION SUMMARY ===")
            print(f"Events per page: {pagination.get('events_per_page', 'Unknown')}")
            print(f"Total events available: {pagination.get('total_events', 'Unknown')}")
            print(f"Total pages available: {pagination.get('total_pages', 'Unknown')}")
            print("===========================")

        # Show a sample with focus on duration and end time
        print("\n=== SAMPLE EVENT WITH TIME INFO ===")
        sample = events_df.head(1)
        time_columns = ['name', 'start_date', 'start_time', 'end_date', 'end_time', 'duration_formatted']
        display(sample[time_columns])

        # Display as styled table (uncomment if needed)
        # print("\n=== EVENTS TABLE ===")
        # display(events_df)

        # Convert to JSON format and display
        print("\n=== EVENTS JSON ===")
        events_json = events_df.to_dict(orient='records')
        print(json.dumps(events_json, indent=2))

        # Create results dictionary including pagination info if available
        results = {
            'dataframe': events_df,
            'json': events_json
        }

        if 'pagination_info' in events_data:
            results['pagination'] = events_data['pagination_info']

        return results
    else:
        print("No events to display")
        return None

# Function to fetch events with pagination
def fetch_all_events(max_pages=5, events_per_page=20, **search_params):
    all_events = []
    total_elements = 0
    total_pages = 0
    pagination_info = {}

    for page in range(max_pages):
        # Update the page parameter
        search_params['page'] = page
        search_params['size'] = events_per_page

        # Fetch the current page
        events_data = fetch_events(**search_params)

        # Check if we have a valid response
        if events_data and '_embedded' in events_data and 'events' in events_data['_embedded']:
            # Get page info
            page_info = events_data.get('page', {})
            current_page = page_info.get('number', page)
            events_per_page_actual = page_info.get('size', events_per_page)
            total_elements = page_info.get('totalElements', 0)
            total_pages = page_info.get('totalPages', 0)

            # Store pagination information (from the first page)
            if page == 0:
                pagination_info = {
                    'events_per_page': events_per_page_actual,
                    'total_events': total_elements,
                    'total_pages': total_pages
                }

                # Print pagination information
                print(f"\n=== PAGINATION INFORMATION ===")
                print(f"Events per page: {events_per_page_actual}")
                print(f"Total events available: {total_elements}")
                print(f"Total pages available: {total_pages}")
                print(f"Maximum pages to fetch: {min(max_pages, total_pages)}")
                print("===============================\n")

            # Process the events and add them to our collection
            page_events = events_data['_embedded']['events']
            all_events.extend(page_events)

            print(f"Fetched page {current_page+1}/{total_pages} ({len(page_events)} events)")

            # Check if we've reached the last page
            if page >= total_pages - 1:
                break
        else:
            print(f"No events found on page {page+1} or error in response")
            break

    # Convert all events to raw format for processing
    raw_events_data = {
        '_embedded': {
            'events': all_events
        },
        'pagination_info': pagination_info
    }

    print(f"Total events fetched: {len(all_events)} out of {total_elements}")
    return raw_events_data

# Function to display results as table and JSON


# Save results to CSV, JSON, or Excel
def save_results(results, prefix='events'):
    if results is None or 'json' not in results:
        print("No JSON results to save")
        return

    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')

    # Specify an absolute path where you want to save the file
    # Change this to a directory you have write access to
    save_directory = "/path/to/your/directory"  # Example: "C:/Users/YourName/Documents" on Windows or "/home/username/Documents" on Linux

    filename = f"{save_directory}/{prefix}_{timestamp}.json"

    try:
        with open(filename, 'w') as f:
            json.dump(results['json'], f, indent=2)
        print(f"Successfully saved JSON to {filename}")
    except Exception as e:
        print(f"Error saving file: {e}")

    print(f"Saved JSON to {filename}")
# Example usage
def main():
    # Define your search parameters with more options
    params = {
        'country_code': "US",
        'classification_name': "music",  # Music, Sports, Arts, Film, etc.
        'city': "New York",
        'state_code': "NY",
        'start_date_time': "2025-05-15T00:00:00Z",  # Events after this date
        #'end_date_time': "2025-08-15T23:59:59Z",    # Events before this date
        'sort': "date,asc",                        # Sort by date ascending
        #'include_family': "yes"                    # Include family-friendly events
    }

    # Define pagination parameters
    max_pages = 10     # Maximum number of pages to fetch
    events_per_page = 200  # Number of events per page to request

    # You can control the number of events per page by changing the 'size' parameter
    # The API default is 20, but you can set it up to the API's maximum (usually 50-100)
    params['size'] = 200 # Uncomment to override events_per_page

    # Fetch events with pagination
    #print(f"Fetching {params['classification_name']} events in {params['city']}, {params['state_code']}...")
    #print(f"Time range: {params['start_date_time']} to {params['end_date_time']}")
    #print(f"Pagination settings: max {max_pages} pages, {events_per_page} events per page")

    events_data = fetch_all_events(max_pages=max_pages, events_per_page=events_per_page, **params)

    # Display structured results
    results = display_structured_events(events_data)

    # Save results to files
    save_results(results, prefix='_events')

    # Return all the information
    if results and 'pagination' in results:
        print("\n=== PAGINATION SUMMARY ===")
        print(f"Events per page: {results['pagination']['events_per_page']}")
        print(f"Total events available: {results['pagination']['total_events']}")
        print(f"Total pages available: {results['pagination']['total_pages']}")

    return results

# Run the main function
if __name__ == "__main__":
    results = main()
# Out:
# Current working directory: /content
#
# === PAGINATION INFORMATION ===
# Events per page: 200
# Total events available: 1745
# Total pages available: 9
# Maximum pages to fetch: 9
# ===============================
#
# Fetched page 1/9 (200 events)
# Fetched page 2/9 (200 events)
# Fetched page 3/9 (200 events)
# Fetched page 4/9 (200 events)
# Fetched page 5/9 (200 events)
# Error: 400
# {"errors":[{"_links":{"about":{"href":"/discovery/v2/errors.html#DIS1035"}},"code":"DIS1035","detail":"API Limits Exceeded: Max paging depth exceeded. (page * size) must be less than 1,000","status":"400 BAD_REQUEST"}]}
# No events found on page 6 or error in response
# Total events fetched: 1000 out of 1745
# Found 1000 events
#
# === PAGINATION SUMMARY ===
# Events per page: 200
# Total events available: 1745
# Total pages available: 9
# ===========================
#
# === SAMPLE EVENT WITH TIME INFO ===
#                                  name  start_date start_time    end_date  \
# 0  The Dandy Warhols - Three Day Pass  2025-05-16    unknown  2025-05-18
#
#   end_time duration_formatted
# 0  unknown      not available
# === EVENTS JSON ===
# [
#   {
#     "id": "k7vGFbPwnJPmM",
#     "name": "The Dandy Warhols - Three Day Pass",
#     "status": "onsale",
#     "start_date": "2025-05-16",
#     "start_time": "unknown",
#     "end_date": "2025-05-18",
#     "end_time": "unknown",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "KovZpZA7dkJA",
#     "venue_name": "Bowery Ballroom",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10002",
#     "venue_url": "https://www.ticketmaster.com/bowery-ballroom-tickets-new-york/venue/1100",
#     "venue_latitude": "40.72036400",
#     "venue_longitude": "-73.99354200",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Rock",
#     "genre_id": "KnvZfZ7vAeA",
#     "subgenre": "Alternative Rock",
#     "subgenre_id": "KZazBEonSMnZfZ7v6dt",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/b76/d95d07ed-0743-4457-97dc-ed2732d03b76_SOURCE",
#     "attractions": "The Dandy Warhols",
#     "attraction_ids": "K8vZ9171fdf",
#     "on_sale_date": "2025-02-28T17:13:00Z",
#     "off_sale_date": "2025-05-18T01:00:00Z",
#     "min_price": NaN,
#     "max_price": NaN,
#     "currency": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AK_MFV",
#     "name": "Birdland Big Band with Special Guest Hilary Kole",
#     "status": "offsale",
#     "start_date": "2025-05-16",
#     "start_time": "17:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "rZ7HnEZ178J7g",
#     "venue_name": "Birdland Jazz Club",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/birdland-jazz-club-new-york-ny/426135",
#     "venue_latitude": "40.7590167",
#     "venue_longitude": "-73.9896861",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Big Band",
#     "subgenre_id": "KZazBEonSMnZfZ7vk7v",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/bea/03d47f66-d37b-4aca-aa17-0135be64dbea_105801_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "attractions": NaN,
#     "attraction_ids": NaN,
#     "on_sale_date": "2025-01-31T19:00:00Z",
#     "off_sale_date": "2025-05-14T21:17:05Z",
#     "min_price": 0.0,
#     "max_price": 0.0,
#     "currency": "USD",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "k7vGFbINsVgpJ",
#     "name": "Evan Crommett, Velise",
#     "status": "onsale",
#     "start_date": "2025-05-16",
#     "start_time": "18:00:00",
#     "end_date": "not specified",
#     "end_time": "not specified",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "KovZpZAJAkAA",
#     "venue_name": "Mercury Lounge",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10002",
#     "venue_url": "https://www.ticketmaster.com/mercury-lounge-tickets-new-york/venue/1101",
#     "venue_latitude": "40.72203600",
#     "venue_longitude": "-73.98680600",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Rock",
#     "genre_id": "KnvZfZ7vAeA",
#     "subgenre": "Pop",
#     "subgenre_id": "KZazBEonSMnZfZ7v6F1",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/a0e/7b60841b-d94f-4cde-86ec-70725d23ea0e_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "attractions": "Evan Crommett, Velise",
#     "attraction_ids": "K8vZ917pXy7, K8vZ917rkTV",
#     "on_sale_date": "2025-04-11T14:00:00Z",
#     "off_sale_date": "2025-05-17T00:00:00Z",
#     "min_price": NaN,
#     "max_price": NaN,
#     "currency": NaN,
#     "presale_name": "Citi\u00ae Cardmember Presale",
#     "presale_start_date": "2025-04-09T14:00:00Z",
#     "presale_end_date": "2025-04-11T02:00:00Z"
#   },
#   {
#     "id": "k7vGFbPlztk6x",
#     "name": "Sidney Bird",
#     "status": "cancelled",
#     "start_date": "2025-05-16",
#     "start_time": "18:00:00",
#     "end_date": "not specified",
#     "end_time": "not specified",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "KovZpZAJAkAA",
#     "venue_name": "Mercury Lounge",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10002",
#     "venue_url": "https://www.ticketmaster.com/mercury-lounge-tickets-new-york/venue/1101",
#     "venue_latitude": "40.72203600",
#     "venue_longitude": "-73.98680600",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Pop",
#     "genre_id": "KnvZfZ7vAev",
#     "subgenre": "Pop",
#     "subgenre_id": "KZazBEonSMnZfZ7vk1t",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/e/3a0/1c6f71db-4d38-4462-b1b3-3137e67673a0_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "attractions": "Sidney Bird, Emily James",
#     "attraction_ids": "K8vZ917Qxq0, K8vZ917qHO0",
#     "on_sale_date": "2025-03-07T15:00:00Z",
#     "off_sale_date": "2025-05-17T00:00:00Z",
#     "min_price": NaN,
#     "max_price": NaN,
#     "currency": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "rZ7HnEZ1Af8dFK",
#     "name": "Badfish - A Tribute To Sublime NYC Sunset Concert Booze Cruise Party",
#     "status": "onsale",
#     "start_date": "2025-05-16",
#     "start_time": "18:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "rZ7HnEZ17QbqS",
#     "venue_name": "Grande Mariner | NYC Water Cruises",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10002",
#     "venue_url": "https://www.ticketweb.com/venue/grande-mariner--nyc-water-cruises-new-york-ny/698773",
#     "venue_latitude": "40.7100148",
#     "venue_longitude": "-73.984406",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Reggae",
#     "genre_id": "KnvZfZ7vAed",
#     "subgenre": "Reggae",
#     "subgenre_id": "KZazBEonSMnZfZ7vknl",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/a12/18d54130-0a37-46a6-9432-9250e6b2ba12_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "attractions": "Badfish - A Tribute To Sublime",
#     "attraction_ids": "K8vZ9175Mw0",
#     "on_sale_date": "2025-04-22T20:00:00Z",
#     "off_sale_date": "2025-05-17T23:00:00Z",
#     "min_price": 44.94,
#     "max_price": 58.56,
#     "currency": "USD",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "k7vGFbEmEHkOf",
#     "name": "Will Wood - Mr. Wood is Dead: 10 Year Anniversary Tour (18+)",
#     "status": "onsale",
#     "start_date": "2025-05-16",
#     "start_time": "19:00:00",
#     "end_date": "not specified",
#     "end_time": "not specified",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "KovZpZAEAdaA",
#     "venue_name": "Gramercy Theatre",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10010",
#     "venue_url": "https://www.ticketmaster.com/gramercy-theatre-tickets-new-york/venue/107",
#     "venue_latitude": "40.73975368",
#     "venue_longitude": "-73.98501292",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Pop",
#     "genre_id": "KnvZfZ7vAev",
#     "subgenre": "Pop",
#     "subgenre_id": "KZazBEonSMnZfZ7vk1t",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/364/5ca9d25c-4523-4a03-a8ca-36f1576b7364_TABLET_LANDSCAPE_16_9.jpg",
#     "attractions": "Will Wood, Shayfer James",
#     "attraction_ids": "K8vZ917Q6Q7, K8vZ9172Nq7",
#     "on_sale_date": "2025-04-04T14:00:00Z",
#     "off_sale_date": "2025-05-17T01:00:00Z",
#     "min_price": NaN,
#     "max_price": NaN,
#     "currency": NaN,
#     "presale_name": "Live Nation Presale",
#     "presale_start_date": "2025-04-03T14:00:00Z",
#     "presale_end_date": "2025-04-04T02:00:00Z"
#   },
#   {
#     "id": "k7vGFbpXRlVnR",
#     "name": "The Kiffness: Vote4Pets Tour",
#     "status": "onsale",
#     "start_date": "2025-05-16",
#     "start_time": "19:00:00",
#     "end_date": "not specified",
#     "end_time": "not specified",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "KovZpaFPje",
#     "venue_name": "Irving Plaza Powered By Verizon 5G",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10003",
#     "venue_url": "https://www.ticketmaster.com/irving-plaza-powered-by-verizon-5g-tickets-new-york/venue/47",
#     "venue_latitude": "40.73491700",
#     "venue_longitude": "-73.98844690",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Other",
#     "genre_id": "KnvZfZ7vAvl",
#     "subgenre": "Other",
#     "subgenre_id": "KZazBEonSMnZfZ7vk1I",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/f38/0dd0dcbc-4ff6-41c1-93c7-0dd707d36f38_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "attractions": "The Kiffness",
#     "attraction_ids": "K8vZ917h_e7",
#     "on_sale_date": "2024-11-22T15:00:00Z",
#     "off_sale_date": "2025-05-17T01:00:00Z",
#     "min_price": NaN,
#     "max_price": NaN,
#     "currency": NaN,
#     "presale_name": "Citi\u00ae Cardmember Preferred Tickets",
#     "presale_start_date": "2024-11-22T15:00:00Z",
#     "presale_end_date": "2025-04-19T02:00:00Z"
#   },
#   {
#     "id": "rZ7HnEZ1AKQv0V",
#     "name": "Sweet Melissa's Studio 54",
#     "status": "onsale",
#     "start_date": "2025-05-16",
#     "start_time": "19:00:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "rZ7HnEZa9V3",
#     "venue_name": "The Bowery Electric",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10003",
#     "venue_url": "https://www.ticketweb.com/venue/the-bowery-electric-new-york-ny/97554",
#     "venue_latitude": "40.7257",
#     "venue_longitude": "-73.991673",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Pop",
#     "genre_id": "KnvZfZ7vAev",
#     "subgenre": "Dance",
#     "subgenre_id": "KZazBEonSMnZfZ7vkJI",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/4f2/0109888a-61b5-4525-8432-b026ef04f4f2_105631_RETINA_PORTRAIT_16_9.jpg",
#     "attractions": NaN,
#     "attraction_ids": NaN,
#     "on_sale_date": "2025-02-03T18:15:00Z",
#     "off_sale_date": "2025-05-16T23:00:00Z",
#     "min_price": 11.55,
#     "max_price": 11.55,
#     "currency": "USD",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfFkqd",
#     "name": "Gil Gutierrez Trio",
#     "status": "offsale",
#     "start_date": "2025-05-16",
#     "start_time": "19:00:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "rZ7HnEZ174KrF",
#     "venue_name": "Birdland Theater",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/birdland-theater-new-york-ny/553788",
#     "venue_latitude": "40.7590167",
#     "venue_longitude": "-73.9896861",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Jazz",
#     "subgenre_id": "KZazBEonSMnZfZ7vkda",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/bea/03d47f66-d37b-4aca-aa17-0135be64dbea_105801_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "attractions": NaN,
#     "attraction_ids": NaN,
#     "on_sale_date": "2025-01-20T22:45:00Z",
#     "off_sale_date": "2025-05-16T19:30:55Z",
#     "min_price": 0.0,
#     "max_price": 0.0,
#     "currency": "USD",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "Z7r9jZ1A7akA3",
#     "name": "Ren??e Fleming and Rod Gilfry Sing Kevin Puts",
#     "status": "onsale",
#     "start_date": "2025-05-16",
#     "start_time": "19:30:00",
#     "end_date": "not specified",
#     "end_time": "not specified",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "Z6r9jZed7e",
#     "venue_name": "David Geffen Hall",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10023",
#     "venue_url": "unknown",
#     "venue_latitude": "40.776100000",
#     "venue_longitude": "-73.984100000",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Classical",
#     "genre_id": "KnvZfZ7vAeJ",
#     "subgenre": "Classical/Vocal",
#     "subgenre_id": "KZazBEonSMnZfZ7vF1A",
#     "type": NaN,
#     "type_id": NaN,
#     "subtype": NaN,
#     "subtype_id": NaN,
#     "image_url": "https://s1.ticketm.net/dam/c/f7b/ef64d601-8740-43cd-86ea-ed9b392e4f7b_105961_RETINA_PORTRAIT_16_9.jpg",
#     "attractions": "New York Philharmonic",
#     "attraction_ids": "K8vZ9175MOV",
#     "on_sale_date": "1900-01-01T06:00:00Z",
#     "off_sale_date": "2025-05-16T23:30:00Z",
#     "min_price": NaN,
#     "max_price": NaN,
#     "currency": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfC98S",
#     "name": "Double Album Release + Brutal Zine Launch",
#     "status": "onsale",
#     "start_date": "2025-05-16",
#     "start_time": "19:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "rZ7HnEZ17QkQd",
#     "venue_name": "Night Club 101",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10009",
#     "venue_url": "https://www.ticketweb.com/venue/night-club-101-new-york-ny/686683",
#     "venue_latitude": "40.725911",
#     "venue_longitude": "-73.984043",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Other",
#     "genre_id": "KnvZfZ7vAvl",
#     "subgenre": NaN,
#     "subgenre_id": NaN,
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/060/c5c08e7a-9912-456c-a060-2758be94e060_105881_TABLET_LANDSCAPE_16_9.jpg",
#     "attractions": NaN,
#     "attraction_ids": NaN,
#     "on_sale_date": "2025-04-22T14:00:00Z",
#     "off_sale_date": "2025-05-16T23:30:00Z",
#     "min_price": 23.62,
#     "max_price": 23.62,
#     "currency": "USD",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfGwqd",
#     "name": "Dash Rip Rock | Eric Ambel",
#     "status": "onsale",
#     "start_date": "2025-05-16",
#     "start_time": "19:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "rZ7HnEZ178g0P",
#     "venue_name": "Berlin",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10009",
#     "venue_url": "https://www.ticketweb.com/venue/berlin-new-york-ny/435925",
#     "venue_latitude": "40.722974",
#     "venue_longitude": "-73.986080",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Rock",
#     "genre_id": "KnvZfZ7vAeA",
#     "subgenre": "Pop",
#     "subgenre_id": "KZazBEonSMnZfZ7v6F1",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/fbc/b293c0ad-c904-4215-bc59-8d7f2414dfbc_106141_RETINA_LANDSCAPE_16_9.jpg",
#     "attractions": "Dash Rip Rock",
#     "attraction_ids": "K8vZ9171fc7",
#     "on_sale_date": "2025-03-27T22:15:00Z",
#     "off_sale_date": "2025-05-17T00:00:00Z",
#     "min_price": 28.25,
#     "max_price": 28.25,
#     "currency": "USD",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "Z7r9jZ1A74gee",
#     "name": "Rapsody (18 & Over)",
#     "status": "onsale",
#     "start_date": "2025-05-16",
#     "start_time": "20:00:00",
#     "end_date": "not specified",
#     "end_time": "not specified",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "Z7r9jZa7MU",
#     "venue_name": "Racket NYC",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10011",
#     "venue_url": "unknown",
#     "venue_latitude": "40.740898000",
#     "venue_longitude": "-73.999702000",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Other",
#     "genre_id": "KnvZfZ7vAvl",
#     "subgenre": "Other",
#     "subgenre_id": "KZazBEonSMnZfZ7vk1I",
#     "type": NaN,
#     "type_id": NaN,
#     "subtype": NaN,
#     "subtype_id": NaN,
#     "image_url": "https://s1.ticketm.net/dam/a/104/1160080d-a937-444a-9db8-bc35b5334104_RETINA_PORTRAIT_16_9.jpg",
#     "attractions": "Rapsody",
#     "attraction_ids": "K8vZ917C8w0",
#     "on_sale_date": "1900-01-01T06:00:00Z",
#     "off_sale_date": "2025-05-17T00:00:00Z",
#     "min_price": NaN,
#     "max_price": NaN,
#     "currency": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "Z7r9jZ1A7fgak",
#     "name": "Malcolm Todd (16 & Over)",
#     "status": "onsale",
#     "start_date": "2025-05-16",
#     "start_time": "20:00:00",
#     "end_date": "not specified",
#     "end_time": "not specified",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "ZFr9jZk7ke",
#     "venue_name": "Terminal 5",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10019",
#     "venue_url": "unknown",
#     "venue_latitude": "40.765202000",
#     "venue_longitude": "-73.985298000",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Pop",
#     "genre_id": "KnvZfZ7vAev",
#     "subgenre": "Pop",
#     "subgenre_id": "KZazBEonSMnZfZ7vk1t",
#     "type": NaN,
#     "type_id": NaN,
#     "subtype": NaN,
#     "subtype_id": NaN,
#     "image_url": "https://s1.ticketm.net/dam/a/11e/da4bd7ec-5617-45d4-beac-de9d28c8511e_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "attractions": "Malcolm Todd",
#     "attraction_ids": "K8vZ917jb-V",
#     "on_sale_date": "2025-03-07T15:00:00Z",
#     "off_sale_date": "2025-05-17T00:00:00Z",
#     "min_price": NaN,
#     "max_price": NaN,
#     "currency": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "k7vGFb4NNK_CP",
#     "name": "Fontaines D.C. USA TOUR 2025",
#     "status": "onsale",
#     "start_date": "2025-05-16",
#     "start_time": "20:00:00",
#     "end_date": "not specified",
#     "end_time": "not specified",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "KovZpZAEAE6A",
#     "venue_name": "Manhattan Center Hammerstein Ballroom",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10001",
#     "venue_url": "https://www.ticketmaster.com/manhattan-center-hammerstein-ballroom-tickets-new-york/venue/280",
#     "venue_latitude": "40.75266400",
#     "venue_longitude": "-73.99430900",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Pop",
#     "genre_id": "KnvZfZ7vAev",
#     "subgenre": "Pop",
#     "subgenre_id": "KZazBEonSMnZfZ7vk1t",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/7d1/4d6b30ea-b761-4b43-8945-c8a1a560c7d1_RETINA_PORTRAIT_16_9.jpg",
#     "attractions": "Fontaines D.C., Jadu Heart",
#     "attraction_ids": "K8vZ9179LP7, K8vZ917bQbV",
#     "on_sale_date": "2024-11-01T14:00:00Z",
#     "off_sale_date": "2025-05-17T02:00:00Z",
#     "min_price": NaN,
#     "max_price": NaN,
#     "currency": NaN,
#     "presale_name": "Artist Presale",
#     "presale_start_date": "2024-10-30T14:00:00Z",
#     "presale_end_date": "2024-11-01T02:00:00Z"
#   },
#   {
#     "id": "k7vGFbP2aPf3q",
#     "name": "The Dandy Warhols",
#     "status": "onsale",
#     "start_date": "2025-05-16",
#     "start_time": "20:00:00",
#     "end_date": "not specified",
#     "end_time": "not specified",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "KovZpZA7dkJA",
#     "venue_name": "Bowery Ballroom",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10002",
#     "venue_url": "https://www.ticketmaster.com/bowery-ballroom-tickets-new-york/venue/1100",
#     "venue_latitude": "40.72036400",
#     "venue_longitude": "-73.99354200",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Rock",
#     "genre_id": "KnvZfZ7vAeA",
#     "subgenre": "Alternative Rock",
#     "subgenre_id": "KZazBEonSMnZfZ7v6dt",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/e/b2e/b3cfc1a2-d75a-40e6-8f2c-e7f07788cb2e_SOURCE",
#     "attractions": "The Dandy Warhols, Sisters of Your Sunshine Vapor",
#     "attraction_ids": "K8vZ9171fdf, K8vZ91721OV",
#     "on_sale_date": "2025-02-28T15:00:00Z",
#     "off_sale_date": "2025-05-17T02:00:00Z",
#     "min_price": NaN,
#     "max_price": NaN,
#     "currency": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfGMbS",
#     "name": "Back To The Eighties Show with Jessie's Girl",
#     "status": "onsale",
#     "start_date": "2025-05-16",
#     "start_time": "20:00:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "rZ7HnEZakQx",
#     "venue_name": "S.O.B.'s",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10014",
#     "venue_url": "https://www.ticketweb.com/venue/sobs-new-york-ny/26274",
#     "venue_latitude": "40.7284733",
#     "venue_longitude": "-74.0050445",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Pop",
#     "genre_id": "KnvZfZ7vAev",
#     "subgenre": "Pop Rock",
#     "subgenre_id": "KZazBEonSMnZfZ7vkEl",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/25c/1d958219-65b8-4ef1-a0ff-603224e6725c_TABLET_LANDSCAPE_16_9.jpg",
#     "attractions": "Jessie's Girl",
#     "attraction_ids": "K8vZ9178l5V",
#     "on_sale_date": "2025-04-03T14:00:00Z",
#     "off_sale_date": "2025-05-17T01:00:00Z",
#     "min_price": 45.72,
#     "max_price": 75.06,
#     "currency": "USD",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfaJ4S",
#     "name": "Chris Dave & Jason Moran Duet",
#     "status": "onsale",
#     "start_date": "2025-05-16",
#     "start_time": "20:00:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "rZ7HnEZaASU",
#     "venue_name": "Blue Note Jazz Club",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10012",
#     "venue_url": "https://www.ticketweb.com/venue/blue-note-jazz-club-new-york-ny/23798",
#     "venue_latitude": "40.730940",
#     "venue_longitude": "-74.000650",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "R&B",
#     "genre_id": "KnvZfZ7vAee",
#     "subgenre": "R&B",
#     "subgenre_id": "KZazBEonSMnZfZ7vkIt",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/bea/03d47f66-d37b-4aca-aa17-0135be64dbea_105801_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "attractions": "Jason Moran",
#     "attraction_ids": "K8vZ9175EHV",
#     "on_sale_date": "2025-03-04T14:45:00Z",
#     "off_sale_date": "2025-05-17T00:00:00Z",
#     "min_price": 49.38,
#     "max_price": 66.27,
#     "currency": "USD",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AKQpFV",
#     "name": "Gil Evans Project Directed by Ryan Truesdell",
#     "status": "offsale",
#     "start_date": "2025-05-16",
#     "start_time": "20:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "rZ7HnEZ178J7g",
#     "venue_name": "Birdland Jazz Club",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/birdland-jazz-club-new-york-ny/426135",
#     "venue_latitude": "40.7590167",
#     "venue_longitude": "-73.9896861",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Jazz",
#     "subgenre_id": "KZazBEonSMnZfZ7vkda",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/bea/03d47f66-d37b-4aca-aa17-0135be64dbea_105801_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "attractions": NaN,
#     "attraction_ids": NaN,
#     "on_sale_date": "2025-02-06T16:00:00Z",
#     "off_sale_date": "2025-05-16T18:13:10Z",
#     "min_price": 0.0,
#     "max_price": 0.0,
#     "currency": "USD",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "k7vGFbnhbtA8M",
#     "name": "Fireworks Music Presents: Jeremy Elliot & Friends",
#     "status": "onsale",
#     "start_date": "2025-05-16",
#     "start_time": "21:00:00",
#     "end_date": "not specified",
#     "end_time": "not specified",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "KovZpZAJAkAA",
#     "venue_name": "Mercury Lounge",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10002",
#     "venue_url": "https://www.ticketmaster.com/mercury-lounge-tickets-new-york/venue/1101",
#     "venue_latitude": "40.72203600",
#     "venue_longitude": "-73.98680600",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Rock",
#     "genre_id": "KnvZfZ7vAeA",
#     "subgenre": "Pop",
#     "subgenre_id": "KZazBEonSMnZfZ7v6F1",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/e/6a6/94ae6759-fb3c-45d8-8311-f471a5d036a6_TABLET_LANDSCAPE_16_9.jpg",
#     "attractions": "Jeremy Elliot",
#     "attraction_ids": "K8vZ917b_n0",
#     "on_sale_date": "2025-05-06T19:26:00Z",
#     "off_sale_date": "2025-05-17T03:00:00Z",
#     "min_price": NaN,
#     "max_price": NaN,
#     "currency": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfFkrK",
#     "name": "Gil Gutierrez Trio",
#     "status": "onsale",
#     "start_date": "2025-05-16",
#     "start_time": "21:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "rZ7HnEZ174KrF",
#     "venue_name": "Birdland Theater",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/birdland-theater-new-york-ny/553788",
#     "venue_latitude": "40.7590167",
#     "venue_longitude": "-73.9896861",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Jazz",
#     "subgenre_id": "KZazBEonSMnZfZ7vkda",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/bea/03d47f66-d37b-4aca-aa17-0135be64dbea_105801_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "attractions": NaN,
#     "attraction_ids": NaN,
#     "on_sale_date": "2025-01-20T22:45:00Z",
#     "off_sale_date": "2025-05-17T01:30:00Z",
#     "min_price": 30.06,
#     "max_price": 45.76,
#     "currency": "USD",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "rZ7HnEZ1Afod-S",
#     "name": "Pop Edits Party with WTCHCRFT",
#     "status": "onsale",
#     "start_date": "2025-05-16",
#     "start_time": "22:00:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "rZ7HnEZ17QkQd",
#     "venue_name": "Night Club 101",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10009",
#     "venue_url": "https://www.ticketweb.com/venue/night-club-101-new-york-ny/686683",
#     "venue_latitude": "40.725911",
#     "venue_longitude": "-73.984043",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Dance/Electronic",
#     "genre_id": "KnvZfZ7vAvF",
#     "subgenre": "Dance Pop",
#     "subgenre_id": "KZazBEonSMnZfZ7vAJJ",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/df8/81eadad8-4449-412e-a2b1-3d8bbb78edf8_106181_RETINA_PORTRAIT_16_9.jpg",
#     "attractions": NaN,
#     "attraction_ids": NaN,
#     "on_sale_date": "2025-05-06T14:00:00Z",
#     "off_sale_date": "2025-05-17T02:00:00Z",
#     "min_price": 0.0,
#     "max_price": 0.0,
#     "currency": "USD",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "rZ7HnEZ1Afokrd",
#     "name": "Cantina After Dark FRIDAYS",
#     "status": "onsale",
#     "start_date": "2025-05-16",
#     "start_time": "22:00:00",
#     "end_date": "2025-05-17",
#     "end_time": "04:00:00",
#     "duration_minutes": 360,
#     "duration_formatted": "6 hours",
#     "venue_id": "rZ7HnEZ173v3A",
#     "venue_name": "Cantina Rooftop",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/cantina-rooftop-new-york-ny/481485",
#     "venue_latitude": "40.7649566",
#     "venue_longitude": "-73.995973",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "World",
#     "genre_id": "KnvZfZ7vAeF",
#     "subgenre": "Latin",
#     "subgenre_id": "KZazBEonSMnZfZ7vFdJ",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/548/5fefbd1c-973b-4b0e-9b2e-d78e4ce37548_106111_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "attractions": NaN,
#     "attraction_ids": NaN,
#     "on_sale_date": "2025-05-06T16:00:00Z",
#     "off_sale_date": "2025-05-17T02:00:00Z",
#     "min_price": 0.0,
#     "max_price": 20.47,
#     "currency": "USD",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AKQpA0",
#     "name": "Gil Evans Project Directed by Ryan Truesdell",
#     "status": "onsale",
#     "start_date": "2025-05-16",
#     "start_time": "22:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "rZ7HnEZ178J7g",
#     "venue_name": "Birdland Jazz Club",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/birdland-jazz-club-new-york-ny/426135",
#     "venue_latitude": "40.7590167",
#     "venue_longitude": "-73.9896861",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Jazz",
#     "subgenre_id": "KZazBEonSMnZfZ7vkda",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/bea/03d47f66-d37b-4aca-aa17-0135be64dbea_105801_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "attractions": NaN,
#     "attraction_ids": NaN,
#     "on_sale_date": "2025-02-06T16:00:00Z",
#     "off_sale_date": "2025-05-17T02:30:00Z",
#     "min_price": 40.61,
#     "max_price": 50.91,
#     "currency": "USD",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfaJpd",
#     "name": "Chris Dave & Jason Moran Duet",
#     "status": "onsale",
#     "start_date": "2025-05-16",
#     "start_time": "22:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "rZ7HnEZaASU",
#     "venue_name": "Blue Note Jazz Club",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10012",
#     "venue_url": "https://www.ticketweb.com/venue/blue-note-jazz-club-new-york-ny/23798",
#     "venue_latitude": "40.730940",
#     "venue_longitude": "-74.000650",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "R&B",
#     "genre_id": "KnvZfZ7vAee",
#     "subgenre": "R&B",
#     "subgenre_id": "KZazBEonSMnZfZ7vkIt",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/bea/03d47f66-d37b-4aca-aa17-0135be64dbea_105801_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "attractions": "Jason Moran",
#     "attraction_ids": "K8vZ9175EHV",
#     "on_sale_date": "2025-03-04T14:45:00Z",
#     "off_sale_date": "2025-05-17T02:30:00Z",
#     "min_price": 49.38,
#     "max_price": 66.27,
#     "currency": "USD",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "rZ7HnEZ1Afo7vS",
#     "name": "bbbBbBB with Callie Reiff, Ella Strauss",
#     "status": "onsale",
#     "start_date": "2025-05-16",
#     "start_time": "23:00:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "rZ7HnEZ17QkQd",
#     "venue_name": "Night Club 101",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10009",
#     "venue_url": "https://www.ticketweb.com/venue/night-club-101-new-york-ny/686683",
#     "venue_latitude": "40.725911",
#     "venue_longitude": "-73.984043",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Dance/Electronic",
#     "genre_id": "KnvZfZ7vAvF",
#     "subgenre": NaN,
#     "subgenre_id": NaN,
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/df8/81eadad8-4449-412e-a2b1-3d8bbb78edf8_106181_RETINA_PORTRAIT_16_9.jpg",
#     "attractions": NaN,
#     "attraction_ids": NaN,
#     "on_sale_date": "2025-05-06T07:00:00Z",
#     "off_sale_date": "2025-05-17T03:00:00Z",
#     "min_price": 0.0,
#     "max_price": 0.0,
#     "currency": "USD",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfCvfd",
#     "name": "Paola Di Leo | NADR",
#     "status": "onsale",
#     "start_date": "2025-05-17",
#     "start_time": "17:00:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "rZ7HnEZa9V3",
#     "venue_name": "The Bowery Electric",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10003",
#     "venue_url": "https://www.ticketweb.com/venue/the-bowery-electric-new-york-ny/97554",
#     "venue_latitude": "40.7257",
#     "venue_longitude": "-73.991673",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Other",
#     "genre_id": "KnvZfZ7vAvl",
#     "subgenre": NaN,
#     "subgenre_id": NaN,
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/060/c5c08e7a-9912-456c-a060-2758be94e060_105881_TABLET_LANDSCAPE_16_9.jpg",
#     "attractions": NaN,
#     "attraction_ids": NaN,
#     "on_sale_date": "2025-04-14T20:55:00Z",
#     "off_sale_date": "2025-05-17T21:00:00Z",
#     "min_price": 17.45,
#     "max_price": 23.1,
#     "currency": "USD",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfG67d",
#     "name": "Marcos Caba\u00f1as",
#     "status": "onsale",
#     "start_date": "2025-05-17",
#     "start_time": "17:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "rZ7HnEZ178g0P",
#     "venue_name": "Berlin",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10009",
#     "venue_url": "https://www.ticketweb.com/venue/berlin-new-york-ny/435925",
#     "venue_latitude": "40.722974",
#     "venue_longitude": "-73.986080",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Other",
#     "genre_id": "KnvZfZ7vAvl",
#     "subgenre": NaN,
#     "subgenre_id": NaN,
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/060/c5c08e7a-9912-456c-a060-2758be94e060_105881_TABLET_LANDSCAPE_16_9.jpg",
#     "attractions": NaN,
#     "attraction_ids": NaN,
#     "on_sale_date": "2025-03-18T20:55:00Z",
#     "off_sale_date": "2025-05-17T21:30:00Z",
#     "min_price": 11.55,
#     "max_price": 11.55,
#     "currency": "USD",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "rZ7HnEZ1Afa-0K",
#     "name": "Joe Alterman Trio: Celebrating Ramsey Lewis",
#     "status": "onsale",
#     "start_date": "2025-05-17",
#     "start_time": "17:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "rZ7HnEZ178J7g",
#     "venue_name": "Birdland Jazz Club",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/birdland-jazz-club-new-york-ny/426135",
#     "venue_latitude": "40.7590167",
#     "venue_longitude": "-73.9896861",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Jazz",
#     "subgenre_id": "KZazBEonSMnZfZ7vkda",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/bea/03d47f66-d37b-4aca-aa17-0135be64dbea_105801_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "attractions": NaN,
#     "attraction_ids": NaN,
#     "on_sale_date": "2025-03-03T19:05:00Z",
#     "off_sale_date": "2025-05-17T21:30:00Z",
#     "min_price": 30.06,
#     "max_price": 40.61,
#     "currency": "USD",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "k7vGFbNDUGJjF",
#     "name": "DLG.",
#     "status": "onsale",
#     "start_date": "2025-05-17",
#     "start_time": "18:00:00",
#     "end_date": "not specified",
#     "end_time": "not specified",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "KovZpZAJAkAA",
#     "venue_name": "Mercury Lounge",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10002",
#     "venue_url": "https://www.ticketmaster.com/mercury-lounge-tickets-new-york/venue/1101",
#     "venue_latitude": "40.72203600",
#     "venue_longitude": "-73.98680600",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Latin",
#     "genre_id": "KnvZfZ7vAJ6",
#     "subgenre": "Latin",
#     "subgenre_id": "KZazBEonSMnZfZ7va1a",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/42c/d4aab5d0-8525-4735-a1e0-1e0a94e7b42c_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "attractions": "DLG., Schur",
#     "attraction_ids": "K8vZ917KYf7, K8vZ917jU70",
#     "on_sale_date": "2025-02-07T15:00:00Z",
#     "off_sale_date": "2025-05-18T00:00:00Z",
#     "min_price": NaN,
#     "max_price": NaN,
#     "currency": NaN,
#     "presale_name": "Citi\u00ae Cardmember Presale",
#     "presale_start_date": "2025-02-05T18:00:00Z",
#     "presale_end_date": "2025-02-07T03:00:00Z"
#   },
#   {
#     "id": "k7vGFbERUb6yl",
#     "name": "Patrice Roberts Presents I Am Woman",
#     "status": "onsale",
#     "start_date": "2025-05-17",
#     "start_time": "19:00:00",
#     "end_date": "not specified",
#     "end_time": "not specified",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "KovZpZA77eJA",
#     "venue_name": "Capital One City Parks Foundation SummerStage",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10021",
#     "venue_url": "https://www.ticketmaster.com/capital-one-city-parks-foundation-summerstage-tickets-new-york/venue/21",
#     "venue_latitude": "40.76920158",
#     "venue_longitude": "-73.97155468",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Latin",
#     "genre_id": "KnvZfZ7vAJ6",
#     "subgenre": "Latin",
#     "subgenre_id": "KZazBEonSMnZfZ7va1a",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/42b/4187f31b-6556-44d7-8263-a10a44a7942b_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "attractions": "Patrice Roberts",
#     "attraction_ids": "K8vZ917prT0",
#     "on_sale_date": "2025-04-04T16:00:00Z",
#     "off_sale_date": "2025-05-18T01:00:00Z",
#     "min_price": NaN,
#     "max_price": NaN,
#     "currency": NaN,
#     "presale_name": "Artist Presale",
#     "presale_start_date": "2025-04-01T14:00:00Z",
#     "presale_end_date": "2025-04-04T02:00:00Z"
#   },
#   {
#     "id": "rZ7HnEZ1AfFkqN",
#     "name": "Gil Gutierrez Trio",
#     "status": "onsale",
#     "start_date": "2025-05-17",
#     "start_time": "19:00:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "rZ7HnEZ174KrF",
#     "venue_name": "Birdland Theater",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/birdland-theater-new-york-ny/553788",
#     "venue_latitude": "40.7590167",
#     "venue_longitude": "-73.9896861",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Jazz",
#     "subgenre_id": "KZazBEonSMnZfZ7vkda",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/bea/03d47f66-d37b-4aca-aa17-0135be64dbea_105801_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "attractions": NaN,
#     "attraction_ids": NaN,
#     "on_sale_date": "2025-01-20T22:45:00Z",
#     "off_sale_date": "2025-05-17T23:00:00Z",
#     "min_price": 30.06,
#     "max_price": 45.76,
#     "currency": "USD",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "rZ7HnEZ1Afa0ZS",
#     "name": "Subhumans And War On Women Concert Cruise",
#     "status": "onsale",
#     "start_date": "2025-05-17",
#     "start_time": "19:00:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "rZ7HnEZ178tqA",
#     "venue_name": "The Liberty Belle - Rocks Off Concert Cruise",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10002",
#     "venue_url": "https://www.ticketweb.com/venue/the-liberty-belle--rocks-off-concert-cruise-new-york-ny/429745",
#     "venue_latitude": "40.706355",
#     "venue_longitude": "-73.974563",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Other",
#     "genre_id": "KnvZfZ7vAvl",
#     "subgenre": NaN,
#     "subgenre_id": NaN,
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
# ...
#     "status": "onsale",
#     "start_date": "2025-07-20",
#     "start_time": "13:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "rZ7HnEZaASU",
#     "venue_name": "Blue Note Jazz Club",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10012",
#     "venue_url": "https://www.ticketweb.com/venue/blue-note-jazz-club-new-york-ny/23798",
#     "venue_latitude": "40.730940",
#     "venue_longitude": "-74.000650",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Religious",
#     "genre_id": "KnvZfZ7vAe7",
#     "subgenre": "Gospel",
#     "subgenre_id": "KZazBEonSMnZfZ7v6ea",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/36b/1230a923-8031-494f-b228-a95bc77ca36b_RETINA_PORTRAIT_16_9.jpg",
#     "attractions": "Harlem Gospel Choir",
#     "attraction_ids": "K8vZ9171nx7",
#     "on_sale_date": "2025-04-01T13:00:00Z",
#     "off_sale_date": "2025-07-20T17:30:00Z",
#     "min_price": 38.05,
#     "max_price": 38.05,
#     "currency": "USD",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AKjFjV",
#     "name": "Deborah Silver",
#     "status": "onsale",
#     "start_date": "2025-07-20",
#     "start_time": "17:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "rZ7HnEZ178J7g",
#     "venue_name": "Birdland Jazz Club",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/birdland-jazz-club-new-york-ny/426135",
#     "venue_latitude": "40.7590167",
#     "venue_longitude": "-73.9896861",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Jazz",
#     "subgenre_id": "KZazBEonSMnZfZ7vkda",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/bea/03d47f66-d37b-4aca-aa17-0135be64dbea_105801_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "attractions": NaN,
#     "attraction_ids": NaN,
#     "on_sale_date": "2025-02-11T17:20:00Z",
#     "off_sale_date": "2025-07-20T21:30:00Z",
#     "min_price": 35.46,
#     "max_price": 45.76,
#     "currency": "USD",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "G5diZbxBtyskP",
#     "name": "Shinedown: Dance, Kid, Dance",
#     "status": "onsale",
#     "start_date": "2025-07-20",
#     "start_time": "19:00:00",
#     "end_date": "not specified",
#     "end_time": "not specified",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "KovZpZA7AAEA",
#     "venue_name": "Madison Square Garden",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10001",
#     "venue_url": "https://www.ticketmaster.com/madison-square-garden-tickets-new-york/venue/483329",
#     "venue_latitude": "40.74970620",
#     "venue_longitude": "-73.99160060",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Rock",
#     "genre_id": "KnvZfZ7vAeA",
#     "subgenre": "Pop",
#     "subgenre_id": "KZazBEonSMnZfZ7v6F1",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/bab/40a9b10a-8b16-4cb1-8400-3c971e277bab_SOURCE",
#     "attractions": "Shinedown, Bush, Morgan Wade",
#     "attraction_ids": "K8vZ91750H7, K8vZ91713C7, K8vZ917_flV",
#     "on_sale_date": "2025-01-24T15:00:00Z",
#     "off_sale_date": "2025-07-21T01:00:00Z",
#     "min_price": NaN,
#     "max_price": NaN,
#     "currency": NaN,
#     "presale_name": "Citi\u00ae Cardmember Presale",
#     "presale_start_date": "2025-01-21T19:00:00Z",
#     "presale_end_date": "2025-01-24T03:00:00Z"
#   },
#   {
#     "id": "rZ7HnEZ1AfCe_d",
#     "name": "Hot Club of Cowtown",
#     "status": "onsale",
#     "start_date": "2025-07-20",
#     "start_time": "19:00:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "rZ7HnEZ174KrF",
#     "venue_name": "Birdland Theater",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/birdland-theater-new-york-ny/553788",
#     "venue_latitude": "40.7590167",
#     "venue_longitude": "-73.9896861",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Country",
#     "genre_id": "KnvZfZ7vAv6",
#     "subgenre": "Western Swing & Country Boogie",
#     "subgenre_id": "KZazBEonSMnZfZ7vA1F",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/df8/81eadad8-4449-412e-a2b1-3d8bbb78edf8_106181_RETINA_PORTRAIT_16_9.jpg",
#     "attractions": "Hot Club of Cowtown",
#     "attraction_ids": "K8vZ9171nNf",
#     "on_sale_date": "2025-04-15T15:00:00Z",
#     "off_sale_date": "2025-07-20T21:30:00Z",
#     "min_price": 30.06,
#     "max_price": 40.61,
#     "currency": "USD",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AK_fQ7",
#     "name": "The Bad Plus",
#     "status": "onsale",
#     "start_date": "2025-07-20",
#     "start_time": "20:00:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "rZ7HnEZaASU",
#     "venue_name": "Blue Note Jazz Club",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10012",
#     "venue_url": "https://www.ticketweb.com/venue/blue-note-jazz-club-new-york-ny/23798",
#     "venue_latitude": "40.730940",
#     "venue_longitude": "-74.000650",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Jazz",
#     "subgenre_id": "KZazBEonSMnZfZ7vkda",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/4b1/51028dc3-30bd-4d75-908f-fbd757eb04b1_RETINA_LANDSCAPE_16_9.jpg",
#     "attractions": "The Bad Plus",
#     "attraction_ids": "K8vZ9175Nef",
#     "on_sale_date": "2025-03-07T14:45:00Z",
#     "off_sale_date": "2025-07-21T00:00:00Z",
#     "min_price": 32.28,
#     "max_price": 43.61,
#     "currency": "USD",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfGI4N",
#     "name": "Indigenous",
#     "status": "onsale",
#     "start_date": "2025-07-20",
#     "start_time": "20:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "rZ7HnEZaert",
#     "venue_name": "Iridium",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10019",
#     "venue_url": "https://www.ticketweb.com/venue/iridium-new-york-ny/10153",
#     "venue_latitude": "40.761816",
#     "venue_longitude": "-73.983389",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Rock",
#     "genre_id": "KnvZfZ7vAeA",
#     "subgenre": "Pop",
#     "subgenre_id": "KZazBEonSMnZfZ7v6F1",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/85b/d3328a4f-e18f-431b-b3a0-7bfa2ef4f85b_414121_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "attractions": "Indigenous",
#     "attraction_ids": "K8vZ9171-z7",
#     "on_sale_date": "2025-03-26T04:00:00Z",
#     "off_sale_date": "2025-07-20T23:30:00Z",
#     "min_price": 32.72,
#     "max_price": 38.56,
#     "currency": "USD",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfGf3d",
#     "name": "The Afro Latin Jazz Orchestra",
#     "status": "onsale",
#     "start_date": "2025-07-20",
#     "start_time": "20:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "rZ7HnEZ178J7g",
#     "venue_name": "Birdland Jazz Club",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/birdland-jazz-club-new-york-ny/426135",
#     "venue_latitude": "40.7590167",
#     "venue_longitude": "-73.9896861",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Jazz",
#     "subgenre_id": "KZazBEonSMnZfZ7vkda",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/c22/9915039e-156b-4713-9408-0f895e423c22_SOURCE",
#     "attractions": "Arturo O'Farrill",
#     "attraction_ids": "K8vZ917uu_f",
#     "on_sale_date": "2025-03-20T15:20:00Z",
#     "off_sale_date": "2025-07-21T00:30:00Z",
#     "min_price": 35.46,
#     "max_price": 45.76,
#     "currency": "USD",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfCebN",
#     "name": "Hot Club of Cowtown",
#     "status": "onsale",
#     "start_date": "2025-07-20",
#     "start_time": "21:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "rZ7HnEZ174KrF",
#     "venue_name": "Birdland Theater",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/birdland-theater-new-york-ny/553788",
#     "venue_latitude": "40.7590167",
#     "venue_longitude": "-73.9896861",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Country",
#     "genre_id": "KnvZfZ7vAv6",
#     "subgenre": "Western Swing & Country Boogie",
#     "subgenre_id": "KZazBEonSMnZfZ7vA1F",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/df8/81eadad8-4449-412e-a2b1-3d8bbb78edf8_106181_RETINA_PORTRAIT_16_9.jpg",
#     "attractions": "Hot Club of Cowtown",
#     "attraction_ids": "K8vZ9171nNf",
#     "on_sale_date": "2025-04-15T15:00:00Z",
#     "off_sale_date": "2025-07-21T00:00:00Z",
#     "min_price": 30.06,
#     "max_price": 40.61,
#     "currency": "USD",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AK_f_V",
#     "name": "The Bad Plus",
#     "status": "onsale",
#     "start_date": "2025-07-20",
#     "start_time": "22:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "rZ7HnEZaASU",
#     "venue_name": "Blue Note Jazz Club",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10012",
#     "venue_url": "https://www.ticketweb.com/venue/blue-note-jazz-club-new-york-ny/23798",
#     "venue_latitude": "40.730940",
#     "venue_longitude": "-74.000650",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Jazz",
#     "subgenre_id": "KZazBEonSMnZfZ7vkda",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/4b1/51028dc3-30bd-4d75-908f-fbd757eb04b1_RETINA_LANDSCAPE_16_9.jpg",
#     "attractions": "The Bad Plus",
#     "attraction_ids": "K8vZ9175Nef",
#     "on_sale_date": "2025-03-07T14:45:00Z",
#     "off_sale_date": "2025-07-21T02:30:00Z",
#     "min_price": 32.28,
#     "max_price": 43.61,
#     "currency": "USD",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfGffS",
#     "name": "The Afro Latin Jazz Orchestra",
#     "status": "onsale",
#     "start_date": "2025-07-20",
#     "start_time": "22:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "rZ7HnEZ178J7g",
#     "venue_name": "Birdland Jazz Club",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/birdland-jazz-club-new-york-ny/426135",
#     "venue_latitude": "40.7590167",
#     "venue_longitude": "-73.9896861",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Jazz",
#     "subgenre_id": "KZazBEonSMnZfZ7vkda",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/c22/9915039e-156b-4713-9408-0f895e423c22_SOURCE",
#     "attractions": "Arturo O'Farrill",
#     "attraction_ids": "K8vZ917uu_f",
#     "on_sale_date": "2025-03-20T15:00:00Z",
#     "off_sale_date": "2025-07-21T02:30:00Z",
#     "min_price": 35.46,
#     "max_price": 45.76,
#     "currency": "USD",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfGf0S",
#     "name": "Vince Giordano and the Nighthawks",
#     "status": "onsale",
#     "start_date": "2025-07-21",
#     "start_time": "17:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "duration_minutes": "not available",
#     "duration_formatted": "not available",
#     "venue_id": "rZ7HnEZ174KrF",
#     "venue_name": "Birdland Theater",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/birdland-theater-new-york-ny/553788",
#     "venue_latitude": "40.7590167",
#     "venue_longitude": "-73.9896861",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Rock",
#     "genre_id": "KnvZfZ7vAeA",
#     "subgenre": "Pop",
#     "subgenre_id": "KZazBEonSMnZfZ7v6F1",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/fbc/b293c0ad-c904-4215-bc59-8d7f2414dfbc_106141_RETINA_LANDSCAPE_16_9.jpg",
#     "attractions": "Vince Giordano and the Nighthawks",
#     "attraction_ids": "K8vZ917uP3V",
#     "on_sale_date": "2025-03-20T16:00:00Z",
#     "off_sale_date": "2025-07-21T21:30:00Z",
#     "min_price": 24.91,
#     "max_price": 45.76,
#     "currency": "USD",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   }
# ]
# Error saving file: [Errno 2] No such file or directory: '/path/to/your/directory/_events_20250516_215955.json'
# Saved JSON to /path/to/your/directory/_events_20250516_215955.json
#
# === PAGINATION SUMMARY ===
# Events per page: 200
# Total events available: 1745
# Total pages available: 9

# %% [markdown]
# # **classification endpoint **

# %%
import requests
import json
import pandas as pd  # Added for Colab display
from google.colab import files  # For downloading files in Colab
from google.colab import userdata  # For accessing secrets

# Get API key from Colab secrets
try:
    API_KEY = userdata.get('TICKETMASTER_API_KEY')
    print("API key loaded from Colab secrets")
except Exception as e:
    print(f"Error loading API key from secrets: {e}")

# Endpoints
CLASSIFICATIONS_URL = "https://app.ticketmaster.com/discovery/v2/classifications.json"
PAGE_SIZE = 500

def fetch_all_classifications():
    page = 0
    all_classifications = []

    while True:
        params = {
            "apikey": API_KEY,
            "size": PAGE_SIZE,
            "page": page
        }

        print(f"Fetching page {page}...")
        response = requests.get(CLASSIFICATIONS_URL, params=params)
        response.raise_for_status()
        data = response.json()

        embedded = data.get("_embedded", {})
        classifications = embedded.get("classifications", [])

        if not classifications:
            break

        all_classifications.extend(classifications)

        page_info = data.get("page", {})
        total_pages = page_info.get("totalPages", 0)
        print(f"Fetched page {page + 1} of {total_pages}")

        page += 1
        if page >= total_pages:
            break

    return all_classifications

def build_structured_entries(classifications):
    entries = []

    for c in classifications:
        classification_id = c.get("id")
        classification_name = c.get("name")
        classification_primary = c.get("primary", False)  # Added primary flag
        classification_type = c.get("type")  # Added classification type

        # Get segment information
        segment = c.get("segment", {})
        if segment:
            segment_name = segment.get("name")
            segment_id = segment.get("id")
            # Added more segment details
            segment_locale = segment.get("locale")
            segment_primary = segment.get("primary", False)
            segment_level = segment.get("level")

            genres = segment.get("_embedded", {}).get("genres", [])

            if not genres:
                entries.append({
                    "classificationId": classification_id,
                    "classificationName": classification_name,
                    "classificationType": classification_type,
                    "classificationPrimary": classification_primary,
                    "segment": segment_name,
                    "segmentId": segment_id,
                    "segmentLocale": segment_locale,
                    "segmentPrimary": segment_primary,
                    "segmentLevel": segment_level,
                    "genre": None,
                    "genreId": None,
                    "genreLocale": None,
                    "genrePrimary": None,
                    "genreLevel": None,
                    "subgenre": None,
                    "subgenreId": None,
                    "subgenreLocale": None,
                    "subgenrePrimary": None,
                    "subgenreLevel": None
                })
                continue

            for genre in genres:
                genre_name = genre.get("name")
                genre_id = genre.get("id")
                # Added more genre details
                genre_locale = genre.get("locale")
                genre_primary = genre.get("primary", False)
                genre_level = genre.get("level")

                subgenres = genre.get("_embedded", {}).get("subgenres", [])

                if not subgenres:
                    entries.append({
                        "classificationId": classification_id,
                        "classificationName": classification_name,
                        "classificationType": classification_type,
                        "classificationPrimary": classification_primary,
                        "segment": segment_name,
                        "segmentId": segment_id,
                        "segmentLocale": segment_locale,
                        "segmentPrimary": segment_primary,
                        "segmentLevel": segment_level,
                        "genre": genre_name,
                        "genreId": genre_id,
                        "genreLocale": genre_locale,
                        "genrePrimary": genre_primary,
                        "genreLevel": genre_level,
                        "subgenre": None,
                        "subgenreId": None,
                        "subgenreLocale": None,
                        "subgenrePrimary": None,
                        "subgenreLevel": None
                    })
                else:
                    for subgenre in subgenres:
                        # Added more subgenre details
                        subgenre_locale = subgenre.get("locale")
                        subgenre_primary = subgenre.get("primary", False)
                        subgenre_level = subgenre.get("level")

                        entries.append({
                            "classificationId": classification_id,
                            "classificationName": classification_name,
                            "classificationType": classification_type,
                            "classificationPrimary": classification_primary,
                            "segment": segment_name,
                            "segmentId": segment_id,
                            "segmentLocale": segment_locale,
                            "segmentPrimary": segment_primary,
                            "segmentLevel": segment_level,
                            "genre": genre_name,
                            "genreId": genre_id,
                            "genreLocale": genre_locale,
                            "genrePrimary": genre_primary,
                            "genreLevel": genre_level,
                            "subgenre": subgenre.get("name"),
                            "subgenreId": subgenre.get("id"),
                            "subgenreLocale": subgenre_locale,
                            "subgenrePrimary": subgenre_primary,
                            "subgenreLevel": subgenre_level
                        })

    return entries

# Main execution for Colab
if __name__ == "__main__":

    # Fetch all classifications
    print("Fetching classifications from Ticketmaster API...")
    classifications = fetch_all_classifications()

    # Save raw classifications to file
    with open("raw_classifications.json", "w") as f:
        json.dump(classifications, f, indent=2)
    print("Saved raw classifications to raw_classifications.json")

    # Build structured entries
    print("Processing classifications into structured format...")
    structured_entries = build_structured_entries(classifications)

    # Save structured data to file
    with open("full_classifications.json", "w") as f:
        json.dump(structured_entries, f, indent=2)
    print("Saved structured classifications to full_classifications.json")

    # Create a dataframe for display in Colab
    df = pd.DataFrame(structured_entries)
    print(f"\nCreated dataframe with {len(df)} rows and {len(df.columns)} columns")
    print("\nPreview of the data:")
    display(df.head())

    # Download files in Colab
    print("\nDownloading files to your computer...")
    files.download("raw_classifications.json")
    files.download("full_classifications.json")

    print("\nProcess completed successfully!")
# Out:
# API key loaded from Colab secrets
# Fetching classifications from Ticketmaster API...
# Fetching page 0...
# Fetched page 1 of 1
# Saved raw classifications to raw_classifications.json
# Processing classifications into structured format...
# Saved structured classifications to full_classifications.json
#
# Created dataframe with 1086 rows and 19 columns
#
# Preview of the data:
#   classificationId classificationName classificationType  \
# 0             None               None               None
# 1             None               None               None
# 2             None               None               None
# 3             None               None               None
# 4             None               None               None
#
#    classificationPrimary        segment           segmentId segmentLocale  \
# 0                  False  Miscellaneous  KZFzniwnSyZfZ7v7n1         en-us
# 1                  False  Miscellaneous  KZFzniwnSyZfZ7v7n1         en-us
# 2                  False  Miscellaneous  KZFzniwnSyZfZ7v7n1         en-us
# 3                  False  Miscellaneous  KZFzniwnSyZfZ7v7n1         en-us
# 4                  False  Miscellaneous  KZFzniwnSyZfZ7v7n1         en-us
#
#    segmentPrimary segmentLevel               genre      genreId genreLocale  \
# 0           False         None       Casino/Gaming  KnvZfZ7vAAa       en-us
# 1           False         None              Comedy  KnvZfZ7vAA1       en-us
# 2           False         None     Community/Civic  KnvZfZ7vAAE       en-us
# 3           False         None  Community/Cultural  KnvZfZ7v7lE       en-us
# 4           False         None   Fairs & Festivals  KnvZfZ7vAeE       en-us
#
#    genrePrimary genreLevel           subgenre           subgenreId  \
# 0         False       None      Casino/Gaming  KZazBEonSMnZfZ7vFnt
# 1         False       None             Comedy  KZazBEonSMnZfZ7vFnn
# 2         False       None    Community/Civic  KZazBEonSMnZfZ7vFlv
# 3         False       None     Public Skating  KZazBEonSMnZfZ7vAvk
# 4         False       None  Fairs & Festivals  KZazBEonSMnZfZ7vF1F
#
#   subgenreLocale  subgenrePrimary subgenreLevel
# 0          en-us            False          None
# 1          en-us            False          None
# 2          en-us            False          None
# 3          en-us            False          None
# 4          en-us            False          None
# Downloading files to your computer...
# Process completed successfully!

# %% [markdown]
# fetch genre/sub-genre... using segment id

# %%
import requests
import json
import pandas as pd
import time
from google.colab import files
from google.colab import userdata
from IPython.display import display, HTML

# Get API key from Colab secrets
try:
    API_KEY = userdata.get('TICKETMASTER_API_KEY')
    print("API key loaded from Colab secrets")
except Exception as e:
    print(f"Error loading API key from secrets: {e}")
    API_KEY = ""  # Will be requested later if empty

# Ticketmaster API endpoints
CLASSIFICATIONS_URL = "https://app.ticketmaster.com/discovery/v2/classifications.json"
EVENTS_URL = "https://app.ticketmaster.com/discovery/v2/events.json"
PAGE_SIZE = 200  # Maximum allowed by API

class TicketmasterAPI:
    def __init__(self, api_key):
        self.api_key = api_key
        # Dictionary to cache classification data
        self.classifications_cache = None
        # Dictionary for mapping IDs to names for easier lookup
        self.id_name_mapping = {
            'segments': {},
            'genres': {},
            'subgenres': {}
        }

    def _handle_rate_limit(self, response):
        """Handle rate limiting from Ticketmaster API"""
        if response.status_code == 429:  # Too Many Requests
            retry_after = int(response.headers.get('Retry-After', 1))
            print(f"Rate limited. Waiting {retry_after} seconds...")
            time.sleep(retry_after)
            return True
        return False

    def fetch_all_classifications(self):
        """Fetch all classifications from Ticketmaster API"""
        if self.classifications_cache is not None:
            print("Using cached classifications data")
            return self.classifications_cache

        page = 0
        all_classifications = []

        while True:
            params = {
                "apikey": self.api_key,
                "size": PAGE_SIZE,
                "page": page
            }

            print(f"Fetching classifications page {page}...")
            response = requests.get(CLASSIFICATIONS_URL, params=params)

            # Handle rate limiting
            if self._handle_rate_limit(response):
                continue

            response.raise_for_status()
            data = response.json()

            embedded = data.get("_embedded", {})
            classifications = embedded.get("classifications", [])

            if not classifications:
                break

            all_classifications.extend(classifications)

            # Update our ID to name mappings for easier lookup
            self._update_id_mappings(classifications)

            page_info = data.get("page", {})
            total_pages = page_info.get("totalPages", 0)
            print(f"Fetched classifications page {page + 1} of {total_pages}")

            page += 1
            if page >= total_pages:
                break

        self.classifications_cache = all_classifications
        return all_classifications

    def _update_id_mappings(self, classifications):
        """Update ID to name mappings for easier lookup"""
        for c in classifications:
            segment = c.get("segment", {})
            if segment:
                segment_id = segment.get("id")
                segment_name = segment.get("name")
                if segment_id and segment_name:
                    self.id_name_mapping['segments'][segment_id] = segment_name

                genres = segment.get("_embedded", {}).get("genres", [])
                for genre in genres:
                    genre_id = genre.get("id")
                    genre_name = genre.get("name")
                    if genre_id and genre_name:
                        self.id_name_mapping['genres'][genre_id] = genre_name

                    subgenres = genre.get("_embedded", {}).get("subgenres", [])
                    for subgenre in subgenres:
                        subgenre_id = subgenre.get("id")
                        subgenre_name = subgenre.get("name")
                        if subgenre_id and subgenre_name:
                            self.id_name_mapping['subgenres'][subgenre_id] = subgenre_name

    def get_id_name_mapping(self):
        """Get ID to name mappings for segments, genres, and subgenres"""
        # Ensure classifications have been fetched
        if not self.classifications_cache:
            self.fetch_all_classifications()
        return self.id_name_mapping

    def fetch_events_by_classification(self, classification_type, classification_id, country_code=None, city=None, start_date=None, end_date=None, size=50, page=0, sort=None):
        """
        Fetch events by classification type and ID

        Parameters:
        - classification_type: 'segment', 'genre', or 'subgenre'
        - classification_id: ID of the classification
        - country_code: Optional country code filter (e.g., 'US')
        - city: Optional city name filter
        - start_date: Optional start date in ISO format (e.g., '2023-05-01T00:00:00Z')
        - end_date: Optional end date in ISO format (e.g., '2023-06-01T00:00:00Z')
        - size: Number of events per page (max 200)
        - page: Page number
        - sort: Sort order (e.g., 'date,asc', 'relevance,desc')

        Returns:
        - Dictionary of events data
        """
        # Validate classification type
        if classification_type not in ['segment', 'genre', 'subgenre']:
            raise ValueError("classification_type must be 'segment', 'genre', or 'subgenre'")

        # Build parameters
        params = {
            "apikey": self.api_key,
            f"{classification_type}Id": classification_id,
            "size": min(size, PAGE_SIZE),
            "page": page
        }

        # Add optional parameters if provided
        if country_code:
            params["countryCode"] = country_code
        if city:
            params["city"] = city
        if start_date:
            params["startDateTime"] = start_date
        if end_date:
            params["endDateTime"] = end_date
        if sort:
            params["sort"] = sort

        # Fetch events
        print(f"Fetching events for {classification_type} ID {classification_id}...")
        response = requests.get(EVENTS_URL, params=params)

        # Handle rate limiting
        if self._handle_rate_limit(response):
            return self.fetch_events_by_classification(
                classification_type, classification_id, country_code, city,
                start_date, end_date, size, page, sort
            )

        response.raise_for_status()
        return response.json()

    def fetch_all_events_by_classification(self, classification_type, classification_id, country_code=None, city=None, start_date=None, end_date=None, max_pages=10, sort=None):
        """
        Fetch all events by classification type and ID with pagination

        Parameters:
        - See fetch_events_by_classification
        - max_pages: Maximum number of pages to fetch (to avoid excessive API calls)

        Returns:
        - List of event objects
        """
        all_events = []
        page = 0

        while page < max_pages:
            data = self.fetch_events_by_classification(
                classification_type, classification_id, country_code, city,
                start_date, end_date, PAGE_SIZE, page, sort
            )

            embedded = data.get("_embedded", {})
            events = embedded.get("events", [])

            if not events:
                break

            all_events.extend(events)

            page_info = data.get("page", {})
            total_pages = page_info.get("totalPages", 0)
            current_page = page_info.get("number", 0)

            print(f"Fetched events page {current_page + 1} of {total_pages} ({len(events)} events)")

            page += 1
            if page >= total_pages:
                break

        return all_events

    def process_events_data(self, events):
        """
        Process events data into a structured format

        Parameters:
        - events: List of event objects

        Returns:
        - List of dictionaries with structured event data
        """
        processed_events = []

        for event in events:
            event_data = {
                "id": event.get("id"),
                "name": event.get("name"),
                "url": event.get("url"),
                "status": event.get("dates", {}).get("status", {}).get("code"),
                "startDate": event.get("dates", {}).get("start", {}).get("dateTime"),
                "timezone": event.get("dates", {}).get("timezone"),
                "images": [img.get("url") for img in event.get("images", [])[:1]],  # Just get the first image URL
                "priceRanges": event.get("priceRanges", []),
                "seatmap": event.get("seatmap", {}).get("staticUrl"),
                "ticketLimit": event.get("ticketLimit", {}),
            }

            # Add venue info if available
            embedded = event.get("_embedded", {})
            venues = embedded.get("venues", [])
            if venues:
                venue = venues[0]  # Get the first venue
                event_data["venue"] = {
                    "id": venue.get("id"),
                    "name": venue.get("name"),
                    "city": venue.get("city", {}).get("name"),
                    "state": venue.get("state", {}).get("name"),
                    "country": venue.get("country", {}).get("name"),
                    "address": venue.get("address", {}).get("line1"),
                    "location": {
                        "latitude": venue.get("location", {}).get("latitude"),
                        "longitude": venue.get("location", {}).get("longitude")
                    }
                }

            # Add attractions info if available
            attractions = embedded.get("attractions", [])
            if attractions:
                event_data["attractions"] = [{
                    "id": attraction.get("id"),
                    "name": attraction.get("name"),
                    "type": attraction.get("type"),
                    "url": attraction.get("url")
                } for attraction in attractions]

            # Add classifications info
            classifications = event.get("classifications", [])
            if classifications:
                classification = classifications[0]  # Get the first classification
                event_data["classification"] = {
                    "segment": {
                        "id": classification.get("segment", {}).get("id"),
                        "name": classification.get("segment", {}).get("name")
                    },
                    "genre": {
                        "id": classification.get("genre", {}).get("id"),
                        "name": classification.get("genre", {}).get("name")
                    },
                    "subgenre": {
                        "id": classification.get("subGenre", {}).get("id"),
                        "name": classification.get("subGenre", {}).get("name")
                    }
                }

            processed_events.append(event_data)

        return processed_events

    def display_classification_selector(self):
        """Display interactive classification selector in Colab"""
        # Ensure classifications have been fetched
        if not self.classifications_cache:
            self.fetch_all_classifications()

        # Prepare data for display
        segments = [{"id": k, "name": v} for k, v in self.id_name_mapping['segments'].items()]
        genres = [{"id": k, "name": v} for k, v in self.id_name_mapping['genres'].items()]
        subgenres = [{"id": k, "name": v} for k, v in self.id_name_mapping['subgenres'].items()]

        # Sort by name
        segments.sort(key=lambda x: x['name'])
        genres.sort(key=lambda x: x['name'])
        subgenres.sort(key=lambda x: x['name'])

        # Display segment selector
        print("\n=== SEGMENTS ===")
        segment_df = pd.DataFrame(segments)
        display(segment_df)

        # Display genre selector
        print("\n=== GENRES ===")
        genre_df = pd.DataFrame(genres)
        display(genre_df)

        # Display subgenre selector
        print("\n=== SUBGENRES ===")
        subgenre_df = pd.DataFrame(subgenres)
        display(subgenre_df)

        return {
            'segments': segment_df,
            'genres': genre_df,
            'subgenres': subgenre_df
        }

def example_usage():
    """Example usage of the Ticketmaster API wrapper"""
    # Make sure you have your API key set
    global API_KEY
    if not API_KEY:
        print("API key not found in Colab secrets.")
        print("To add your API key to Colab secrets:")
        print("1. Click on the 🔑 icon in the left sidebar")
        print("2. Add a new secret with name 'TICKETMASTER_API_KEY' and your API key as the value")
        print("3. Restart the runtime and run again")
        API_KEY = input("Or enter your Ticketmaster API key manually: ")

    # Initialize the API wrapper
    tm_api = TicketmasterAPI(API_KEY)

    # Fetch classifications to populate the mapping
    tm_api.fetch_all_classifications()

    # Display classification selector
    print("\nClassification Selector:")
    selector_dfs = tm_api.display_classification_selector()

    # Example: Fetch events by segment ID
    # Music segment ID: KZFzniwnSyZfZ7v7nJ
    segment_id = input("\nEnter segment ID (or press Enter to skip): ").strip()
    if segment_id:
        segment_name = tm_api.id_name_mapping['segments'].get(segment_id, "Unknown")
        print(f"\nFetching events for segment: {segment_name} (ID: {segment_id})")
        segment_events = tm_api.fetch_all_events_by_classification('segment', segment_id, max_pages=2)
        processed_segment_events = tm_api.process_events_data(segment_events)

        # Save segment events to file
        with open(f"segment_{segment_id}_events.json", "w") as f:
            json.dump(processed_segment_events, f, indent=2)
        print(f"Saved {len(processed_segment_events)} segment events to segment_{segment_id}_events.json")

        # Display preview
        segment_events_df = pd.DataFrame(processed_segment_events)
        if not segment_events_df.empty:
            display(segment_events_df[['name', 'startDate', 'venue']].head())
            files.download(f"segment_{segment_id}_events.json")

    # Example: Fetch events by genre ID
    genre_id = input("\nEnter genre ID (or press Enter to skip): ").strip()
    if genre_id:
        genre_name = tm_api.id_name_mapping['genres'].get(genre_id, "Unknown")
        print(f"\nFetching events for genre: {genre_name} (ID: {genre_id})")
        genre_events = tm_api.fetch_all_events_by_classification('genre', genre_id, max_pages=2)
        processed_genre_events = tm_api.process_events_data(genre_events)

        # Save genre events to file
        with open(f"genre_{genre_id}_events.json", "w") as f:
            json.dump(processed_genre_events, f, indent=2)
        print(f"Saved {len(processed_genre_events)} genre events to genre_{genre_id}_events.json")

        # Display preview
        genre_events_df = pd.DataFrame(processed_genre_events)
        if not genre_events_df.empty:
            display(genre_events_df[['name', 'startDate', 'venue']].head())
            files.download(f"genre_{genre_id}_events.json")

    # Example: Fetch events by subgenre ID
    subgenre_id = input("\nEnter subgenre ID (or press Enter to skip): ").strip()
    if subgenre_id:
        subgenre_name = tm_api.id_name_mapping['subgenres'].get(subgenre_id, "Unknown")
        print(f"\nFetching events for subgenre: {subgenre_name} (ID: {subgenre_id})")
        subgenre_events = tm_api.fetch_all_events_by_classification('subgenre', subgenre_id, max_pages=2)
        processed_subgenre_events = tm_api.process_events_data(subgenre_events)

        # Save subgenre events to file
        with open(f"subgenre_{subgenre_id}_events.json", "w") as f:
            json.dump(processed_subgenre_events, f, indent=2)
        print(f"Saved {len(processed_subgenre_events)} subgenre events to subgenre_{subgenre_id}_events.json")

        # Display preview
        subgenre_events_df = pd.DataFrame(processed_subgenre_events)
        if not subgenre_events_df.empty:
            display(subgenre_events_df[['name', 'startDate', 'venue']].head())
            files.download(f"subgenre_{subgenre_id}_events.json")

if __name__ == "__main__":
    example_usage()
# Out:
# API key loaded from Colab secrets
# Fetching classifications page 0...
# Fetched classifications page 1 of 1
#
# Classification Selector:
#
# === SEGMENTS ===
#                    id            name
# 0  KZFzniwnSyZfZ7v7na  Arts & Theatre
# 1  KZFzniwnSyZfZ7v7nn            Film
# 2  KZFzniwnSyZfZ7v7n1   Miscellaneous
# 3  KZFzniwnSyZfZ7v7nJ           Music
# 4  KZFzniwnSyZfZ7v7nE          Sports
# 5  KZFzniwnSyZfZ7v7nl       Undefined
# === GENRES ===
#               id              name
# 0    KnvZfZ7vAke  Action/Adventure
# 1    KnvZfZ7vAvv       Alternative
# 2    KnvZfZ7vAkd         Animation
# 3    KnvZfZ7vAeI          Aquatics
# 4    KnvZfZ7vAk7          Arthouse
# ..           ...               ...
# 119  KnvZfZ7vAA7        Volleyball
# 120  KnvZfZ7vAAA         Waterpolo
# 121  KnvZfZ7vAeF             World
# 122  KnvZfZ7vAAk         Wrestling
# 123  KnvZfZ7vAJF           eSports
#
# [124 rows x 2 columns]
# === SUBGENRES ===
#                        id                   name
# 0     KZazBEonSMnZfZ7vA1I                 2-Step
# 1     KZazBEonSMnZfZ7vA1t  2-Step/British Garage
# 2     KZazBEonSMnZfZ7vAnA             A Cappella
# 3     KZazBEonSMnZfZ7vaJF             A Cappella
# 4     KZazBEonSMnZfZ7vFEk                    AFL
# ...                   ...                    ...
# 1081  KZazBEonSMnZfZ7vF1v               Zimbabwe
# 1082  KZazBEonSMnZfZ7vF1e                   Zouk
# 1083  KZazBEonSMnZfZ7vaJE                  Zumba
# 1084  KZazBEonSMnZfZ7vkvn                 Zydeco
# 1085  KZazBEonSMnZfZ7vaEe                eSports
#
# [1086 rows x 2 columns]
# Enter segment ID (or press Enter to skip): KZFzniwnSyZfZ7v7nn
#
# Fetching events for segment: Film (ID: KZFzniwnSyZfZ7v7nn)
# Fetching events for segment ID KZFzniwnSyZfZ7v7nn...
# Fetched events page 1 of 3 (200 events)
# Fetching events for segment ID KZFzniwnSyZfZ7v7nn...
# Fetched events page 2 of 3 (200 events)
# Saved 400 segment events to segment_KZFzniwnSyZfZ7v7nn_events.json
#                                    name             startDate  \
# 0               Harry Potter In Concert  2025-06-14T23:00:00Z
# 1               Harry Potter In Concert  2025-06-15T19:00:00Z
# 2  Silent Movie Mondays: 4-Film Package                  None
# 3                      C. Thomas Howell  2025-06-08T00:00:00Z
# 4                      The Accountant 2  2025-05-17T20:45:00Z
#
#                                                venue
# 0  {'id': 'KovZ917ALBC', 'name': 'Steven Tanger C...
# 1  {'id': 'KovZ917ALBC', 'name': 'Steven Tanger C...
# 2  {'id': 'KovZpZAFkvEA', 'name': 'Paramount Thea...
# 3  {'id': 'KovZpZA17ItA', 'name': 'Columbus Athen...
# 4  {'id': 'KovZ917Am4e', 'name': 'The Paramount T...
# Enter genre ID (or press Enter to skip): KnvZfZ7vAJF
#
# Fetching events for genre: eSports (ID: KnvZfZ7vAJF)
# Fetching events for genre ID KnvZfZ7vAJF...
# Fetched events page 1 of 1 (5 events)
# Saved 5 genre events to genre_KnvZfZ7vAJF_events.json
#                                                 name startDate  \
# 0  BLAST.tv Austin Major 2025: 4 Day Package - Ti...      None
# 1  BLAST.tv Austin Major 2025: 2 Day Package - Th...      None
# 2  BLAST.tv Austin Major 2025: 2 Day Package - Sa...      None
# 3  Rocket League Championship Series: Raleigh Maj...      None
# 4                       Brawlhalla Championship Expo      None
#
#                                                venue
# 0  {'id': 'KovZ917ANwG', 'name': 'Moody Center AT...
# 1  {'id': 'KovZ917ANwG', 'name': 'Moody Center AT...
# 2  {'id': 'KovZ917ANwG', 'name': 'Moody Center AT...
# 3  {'id': 'KovZpZAdakJA', 'name': 'Lenovo Center'...
# 4  {'id': 'KovZ917A-mZ', 'name': 'Gateway Center ...
# Enter subgenre ID (or press Enter to skip): KZazBEonSMnZfZ7vAnA
#
# Fetching events for subgenre: A Cappella (ID: KZazBEonSMnZfZ7vAnA)
# Fetching events for subgenre ID KZazBEonSMnZfZ7vAnA...
# Fetched events page 1 of 1351 (200 events)
# Fetching events for subgenre ID KZazBEonSMnZfZ7vAnA...
# Fetched events page 2 of 1351 (200 events)
# Saved 400 subgenre events to subgenre_KZazBEonSMnZfZ7vAnA_events.json
#                                      name             startDate  \
# 0  New York Yankees vs. Baltimore Orioles  2025-06-21T17:05:00Z
# 1     New York Yankees vs. Houston Astros  2025-08-08T23:05:00Z
# 2          New York Yankees vs. Athletics  2025-06-28T17:05:00Z
# 3      New York Yankees vs. New York Mets  2025-05-16T23:05:00Z
# 4  New York Yankees vs. Baltimore Orioles  2025-09-27T17:05:00Z
#
#                                                venue
# 0  {'id': 'KovZpZA6t77A', 'name': 'Yankee Stadium...
# 1  {'id': 'KovZpZA6t77A', 'name': 'Yankee Stadium...
# 2  {'id': 'KovZpZA6t77A', 'name': 'Yankee Stadium...
# 3  {'id': 'KovZpZA6t77A', 'name': 'Yankee Stadium...
# 4  {'id': 'KovZpZA6t77A', 'name': 'Yankee Stadium...
# WARNING: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %% [markdown]
# # fetch events - **events endpoint**

# %%
from google.colab import userdata

import requests
import pandas as pd
import json
from datetime import datetime
from IPython.display import display, HTML

api_key = userdata.get('TICKETMASTER_API_KEY')
base_url = "https://app.ticketmaster.com/discovery/v2/events.json"

def fetch_events(country_code="US",
                 classification_name=None,
                 city=None,
                 state_code=None,
                 start_date=None,
                 keyword=None,
                 size=20,
                 page=0,
                 sort="date,asc"):

    # Define parameters
    params = {
        'apikey': api_key,
        'countryCode': country_code,
        'size': size,
        'page': page,
        'sort': sort
    }

    # Add optional parameters if provided
    if classification_name:
        params['classificationName'] = classification_name
    if city:
        params['city'] = city
    if state_code:
        params['stateCode'] = state_code
    if start_date:
        params['startDateTime'] = start_date
    if keyword:
        params['keyword'] = keyword

    # Make the API request
    response = requests.get(base_url, params=params)

    # Check if the request was successful
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error: {response.status_code}")
        print(response.text)
        return None

# Process the events data into structured format
def process_events(events_data):
    if not events_data or '_embedded' not in events_data:
        print("No events found or invalid response")
        return None

    event_list = []

    for event in events_data['_embedded']['events']:
        # Extract basic event info
        event_info = {
            'id': event['id'],
            'name': event['name'],
            'url': event['url'],
            'status': event['dates']['status']['code'] if 'status' in event['dates'] else 'unknown',
            'start_date': event['dates']['start'].get('localDate', 'unknown'),
            'start_time': event['dates']['start'].get('localTime', 'unknown'),
        }

        # Add venue info if available
        if '_embedded' in event and 'venues' in event['_embedded'] and len(event['_embedded']['venues']) > 0:
            venue = event['_embedded']['venues'][0]
            event_info['venue_name'] = venue.get('name', 'unknown')
            event_info['venue_city'] = venue.get('city', {}).get('name', 'unknown')
            event_info['venue_state'] = venue.get('state', {}).get('name', 'unknown')
            event_info['venue_country'] = venue.get('country', {}).get('name', 'unknown')

            # Add venue coordinates if available
            if 'location' in venue:
                event_info['venue_latitude'] = venue['location'].get('latitude', 'unknown')
                event_info['venue_longitude'] = venue['location'].get('longitude', 'unknown')

        # Add price range if available
        if 'priceRanges' in event and len(event['priceRanges']) > 0:
            price_range = event['priceRanges'][0]
            event_info['min_price'] = price_range.get('min', 'unknown')
            event_info['max_price'] = price_range.get('max', 'unknown')
            event_info['currency'] = price_range.get('currency', 'unknown')

        # Add genre/classification if available
        if 'classifications' in event and len(event['classifications']) > 0:
            classification = event['classifications'][0]
            if 'segment' in classification and classification['segment']:
                event_info['segment'] = classification['segment'].get('name', 'unknown')
            if 'genre' in classification and classification['genre']:
                event_info['genre'] = classification['genre'].get('name', 'unknown')
            if 'subGenre' in classification and classification['subGenre']:
                event_info['subgenre'] = classification['subGenre'].get('name', 'unknown')

        # Add image URLs if available
        if 'images' in event and len(event['images']) > 0:
            # Find standard image
            standard_images = [img for img in event['images'] if img.get('ratio') == '16_9' and img.get('width') > 500]
            if standard_images:
                event_info['image_url'] = standard_images[0]['url']
            else:
                event_info['image_url'] = event['images'][0]['url']  # Fallback to first image

        # Add attractions/performers if available
        if '_embedded' in event and 'attractions' in event['_embedded'] and len(event['_embedded']['attractions']) > 0:
            attractions = []
            for attraction in event['_embedded']['attractions']:
                attractions.append(attraction.get('name', 'unknown'))
            event_info['attractions'] = ', '.join(attractions)

        # Add ticket info if available
        if 'sales' in event and 'public' in event['sales']:
            sales_public = event['sales']['public']
            if 'startDateTime' in sales_public:
                event_info['on_sale_date'] = sales_public['startDateTime']
            if 'endDateTime' in sales_public:
                event_info['off_sale_date'] = sales_public['endDateTime']

        event_list.append(event_info)

    # Create DataFrame
    df = pd.DataFrame(event_list)
    return df

# Function to display results as table and JSON
def display_structured_events(events_data):
    # Process the events
    events_df = process_events(events_data)

    if events_df is not None and not events_df.empty:
        # Display info
        print(f"Found {len(events_df)} events")

        # Display as styled table
        print("\n=== EVENTS TABLE ===")
        display(events_df)

        # Convert to JSON format and display
        print("\n=== EVENTS JSON ===")
        events_json = events_df.to_dict(orient='records')
        print(json.dumps(events_json, indent=2))

        return {
            'dataframe': events_df,
            'json': events_json
        }
    else:
        print("No events to display")
        return None

# Example usage
def main():
    # Define your search parameters
    params = {
        'country_code': "US",
        'classification_name': "sports",  # Or Could be Music, Sports, Arts, Film, etc.
        'city': "Los Angeles",
        'state_code': "CA",
        'size': 10  # Number of results
    }

    # Fetch events
    print(f"Fetching {params['classification_name']} events in {params['city']}, {params['state_code']}...")
    events_data = fetch_events(**params)

    # Display structured results
    results = display_structured_events(events_data)

    # Optionally save results
    # save_results(results)

    return results

# Run the main function
results = main()
# Out:
# Fetching sports events in Los Angeles, CA...
# Found 10 events
#
# === EVENTS TABLE ===
#                id                                               name  \
# 0   Z7r9jZ1A7u-oP                  Los Angeles Dodgers vs. Athletics
# 1   Z7r9jZ1A7u-oJ                  Los Angeles Dodgers vs. Athletics
# 2  vvG1IZb_Fe9NH-  Los Angeles Football Club vs. Seattle Sounders FC
# 3   Z7r9jZ1A7fefd  UCLA Bruins Baseball vs. Northwestern Wildcats...
# 4   Z7r9jZ1A7u-o0                  Los Angeles Dodgers vs. Athletics
# 5   Z7r9jZ1A7fef6  UCLA Bruins Baseball vs. Northwestern Wildcats...
# 6   Z7r9jZ1A7u-f7         Los Angeles Dodgers vs. Los Angeles Angels
# 7   Z7r9jZ1A7fef7  UCLA Bruins Baseball vs. Northwestern Wildcats...
# 8  vvG1IZbIr1t-3p            Clásico Femenil: Chivas vs Club America
# 9   Z7r9jZ1A7u-fA         Los Angeles Dodgers vs. Los Angeles Angels
#
#                                                  url  status  start_date  \
# 0   https://www.ticketmaster.com/event/Z7r9jZ1A7u-oP  onsale  2025-05-13
# 1   https://www.ticketmaster.com/event/Z7r9jZ1A7u-oJ  onsale  2025-05-14
# 2  https://www.ticketmaster.com/los-angeles-footb...  onsale  2025-05-14
# 3   https://www.ticketmaster.com/event/Z7r9jZ1A7fefd  onsale  2025-05-15
# 4   https://www.ticketmaster.com/event/Z7r9jZ1A7u-o0  onsale  2025-05-15
# 5   https://www.ticketmaster.com/event/Z7r9jZ1A7fef6  onsale  2025-05-16
# 6   https://www.ticketmaster.com/event/Z7r9jZ1A7u-f7  onsale  2025-05-16
# 7   https://www.ticketmaster.com/event/Z7r9jZ1A7fef7  onsale  2025-05-17
# 8  https://www.ticketmaster.com/clasico-femenil-c...  onsale  2025-05-17
# 9   https://www.ticketmaster.com/event/Z7r9jZ1A7u-fA  onsale  2025-05-17
#
#   start_time               venue_name   venue_city venue_state  \
# 0   19:10:00           Dodger Stadium  Los Angeles  California
# 1   19:10:00           Dodger Stadium  Los Angeles  California
# 2   19:30:00              BMO Stadium  Los Angeles  California
# 3   18:00:00  Jackie Robinson Stadium  Los Angeles  California
# 4   19:10:00           Dodger Stadium  Los Angeles  California
# 5   18:00:00  Jackie Robinson Stadium  Los Angeles  California
# 6   19:10:00           Dodger Stadium  Los Angeles  California
# 7   13:00:00  Jackie Robinson Stadium  Los Angeles  California
# 8   17:30:00              BMO Stadium  Los Angeles  California
# 9   18:10:00           Dodger Stadium  Los Angeles  California
#
#               venue_country venue_latitude venue_longitude segment  \
# 0  United States Of America   34.065800000  -118.238800000  Sports
# 1  United States Of America   34.065800000  -118.238800000  Sports
# 2  United States Of America    34.01287900   -118.28492600  Sports
# 3  United States Of America   34.065701000  -118.436996000  Sports
# 4  United States Of America   34.065800000  -118.238800000  Sports
# 5  United States Of America   34.065701000  -118.436996000  Sports
# 6  United States Of America   34.065800000  -118.238800000  Sports
# 7  United States Of America   34.065701000  -118.436996000  Sports
# 8  United States Of America    34.01287900   -118.28492600  Sports
# 9  United States Of America   34.065800000  -118.238800000  Sports
#
#            genre       subgenre  \
# 0       Baseball            MLB
# 1       Baseball            MLB
# 2         Soccer            MLS
# 3  Miscellaneous  Miscellaneous
# 4       Baseball            MLB
# 5  Miscellaneous  Miscellaneous
# 6       Baseball            MLB
# 7  Miscellaneous  Miscellaneous
# 8         Soccer         Soccer
# 9       Baseball            MLB
#
#                                            image_url  \
# 0  https://s1.ticketm.net/dam/a/eb3/9ec01308-9d94...
# 1  https://s1.ticketm.net/dam/a/eb3/9ec01308-9d94...
# 2  https://s1.ticketm.net/dam/a/7fc/9b98825d-88b7...
# 3  https://s1.ticketm.net/dam/a/60f/4e8e8937-236c...
# 4  https://s1.ticketm.net/dam/a/eb3/9ec01308-9d94...
# 5  https://s1.ticketm.net/dam/a/60f/4e8e8937-236c...
# 6  https://s1.ticketm.net/dam/a/eb3/9ec01308-9d94...
# 7  https://s1.ticketm.net/dam/a/60f/4e8e8937-236c...
# 8  https://s1.ticketm.net/dam/c/f9a/3c3c0a9d-033f...
# 9  https://s1.ticketm.net/dam/a/eb3/9ec01308-9d94...
#
#                                          attractions          on_sale_date  \
# 0                     Los Angeles Dodgers, Athletics  1900-01-01T18:00:00Z
# 1                     Los Angeles Dodgers, Athletics  1900-01-01T18:00:00Z
# 2     Los Angeles Football Club, Seattle Sounders FC                   NaN
# 3  UCLA Bruins Baseball, Northwestern Wildcats Ba...  1900-01-01T06:00:00Z
# 4                     Los Angeles Dodgers, Athletics  1900-01-01T18:00:00Z
# 5  UCLA Bruins Baseball, Northwestern Wildcats Ba...  1900-01-01T06:00:00Z
# 6            Los Angeles Dodgers, Los Angeles Angels  1900-01-01T18:00:00Z
# 7  UCLA Bruins Baseball, Northwestern Wildcats Ba...  1900-01-01T06:00:00Z
# 8     C.D. Guadalajara Femenil, Club América Femenil  2025-04-10T17:00:00Z
# 9            Los Angeles Dodgers, Los Angeles Angels  1900-01-01T18:00:00Z
#
#           off_sale_date
# 0  2025-05-14T02:10:00Z
# 1  2025-05-15T02:10:00Z
# 2                   NaN
# 3  2025-05-16T01:00:00Z
# 4  2025-05-16T02:10:00Z
# 5  2025-05-17T01:00:00Z
# 6  2025-05-17T02:10:00Z
# 7  2025-05-17T20:00:00Z
# 8  2025-05-18T02:30:00Z
# 9  2025-05-18T01:10:00Z
# === EVENTS JSON ===
# [
#   {
#     "id": "Z7r9jZ1A7u-oP",
#     "name": "Los Angeles Dodgers vs. Athletics",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7u-oP",
#     "status": "onsale",
#     "start_date": "2025-05-13",
#     "start_time": "19:10:00",
#     "venue_name": "Dodger Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_latitude": "34.065800000",
#     "venue_longitude": "-118.238800000",
#     "segment": "Sports",
#     "genre": "Baseball",
#     "subgenre": "MLB",
#     "image_url": "https://s1.ticketm.net/dam/a/eb3/9ec01308-9d94-4413-92e2-8d0dc9fe8eb3_RETINA_PORTRAIT_16_9.jpg",
#     "attractions": "Los Angeles Dodgers, Athletics",
#     "on_sale_date": "1900-01-01T18:00:00Z",
#     "off_sale_date": "2025-05-14T02:10:00Z"
#   },
#   {
#     "id": "Z7r9jZ1A7u-oJ",
#     "name": "Los Angeles Dodgers vs. Athletics",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7u-oJ",
#     "status": "onsale",
#     "start_date": "2025-05-14",
#     "start_time": "19:10:00",
#     "venue_name": "Dodger Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_latitude": "34.065800000",
#     "venue_longitude": "-118.238800000",
#     "segment": "Sports",
#     "genre": "Baseball",
#     "subgenre": "MLB",
#     "image_url": "https://s1.ticketm.net/dam/a/eb3/9ec01308-9d94-4413-92e2-8d0dc9fe8eb3_RETINA_PORTRAIT_16_9.jpg",
#     "attractions": "Los Angeles Dodgers, Athletics",
#     "on_sale_date": "1900-01-01T18:00:00Z",
#     "off_sale_date": "2025-05-15T02:10:00Z"
#   },
#   {
#     "id": "vvG1IZb_Fe9NH-",
#     "name": "Los Angeles Football Club vs. Seattle Sounders FC",
#     "url": "https://www.ticketmaster.com/los-angeles-football-club-vs-seattle-los-angeles-california-05-14-2025/event/0A006192025E3F21",
#     "status": "onsale",
#     "start_date": "2025-05-14",
#     "start_time": "19:30:00",
#     "venue_name": "BMO Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_latitude": "34.01287900",
#     "venue_longitude": "-118.28492600",
#     "segment": "Sports",
#     "genre": "Soccer",
#     "subgenre": "MLS",
#     "image_url": "https://s1.ticketm.net/dam/a/7fc/9b98825d-88b7-4a8e-8d6c-799c83ae77fc_SOURCE",
#     "attractions": "Los Angeles Football Club, Seattle Sounders FC",
#     "on_sale_date": NaN,
#     "off_sale_date": NaN
#   },
#   {
#     "id": "Z7r9jZ1A7fefd",
#     "name": "UCLA Bruins Baseball vs. Northwestern Wildcats Baseball",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7fefd",
#     "status": "onsale",
#     "start_date": "2025-05-15",
#     "start_time": "18:00:00",
#     "venue_name": "Jackie Robinson Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_latitude": "34.065701000",
#     "venue_longitude": "-118.436996000",
#     "segment": "Sports",
#     "genre": "Miscellaneous",
#     "subgenre": "Miscellaneous",
#     "image_url": "https://s1.ticketm.net/dam/a/60f/4e8e8937-236c-49d3-bc03-19af5bb0b60f_RETINA_PORTRAIT_16_9.jpg",
#     "attractions": "UCLA Bruins Baseball, Northwestern Wildcats Baseball",
#     "on_sale_date": "1900-01-01T06:00:00Z",
#     "off_sale_date": "2025-05-16T01:00:00Z"
#   },
#   {
#     "id": "Z7r9jZ1A7u-o0",
#     "name": "Los Angeles Dodgers vs. Athletics",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7u-o0",
#     "status": "onsale",
#     "start_date": "2025-05-15",
#     "start_time": "19:10:00",
#     "venue_name": "Dodger Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_latitude": "34.065800000",
#     "venue_longitude": "-118.238800000",
#     "segment": "Sports",
#     "genre": "Baseball",
#     "subgenre": "MLB",
#     "image_url": "https://s1.ticketm.net/dam/a/eb3/9ec01308-9d94-4413-92e2-8d0dc9fe8eb3_RETINA_PORTRAIT_16_9.jpg",
#     "attractions": "Los Angeles Dodgers, Athletics",
#     "on_sale_date": "1900-01-01T18:00:00Z",
#     "off_sale_date": "2025-05-16T02:10:00Z"
#   },
#   {
#     "id": "Z7r9jZ1A7fef6",
#     "name": "UCLA Bruins Baseball vs. Northwestern Wildcats Baseball",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7fef6",
#     "status": "onsale",
#     "start_date": "2025-05-16",
#     "start_time": "18:00:00",
#     "venue_name": "Jackie Robinson Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_latitude": "34.065701000",
#     "venue_longitude": "-118.436996000",
#     "segment": "Sports",
#     "genre": "Miscellaneous",
#     "subgenre": "Miscellaneous",
#     "image_url": "https://s1.ticketm.net/dam/a/60f/4e8e8937-236c-49d3-bc03-19af5bb0b60f_RETINA_PORTRAIT_16_9.jpg",
#     "attractions": "UCLA Bruins Baseball, Northwestern Wildcats Baseball",
#     "on_sale_date": "1900-01-01T06:00:00Z",
#     "off_sale_date": "2025-05-17T01:00:00Z"
#   },
#   {
#     "id": "Z7r9jZ1A7u-f7",
#     "name": "Los Angeles Dodgers vs. Los Angeles Angels",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7u-f7",
#     "status": "onsale",
#     "start_date": "2025-05-16",
#     "start_time": "19:10:00",
#     "venue_name": "Dodger Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_latitude": "34.065800000",
#     "venue_longitude": "-118.238800000",
#     "segment": "Sports",
#     "genre": "Baseball",
#     "subgenre": "MLB",
#     "image_url": "https://s1.ticketm.net/dam/a/eb3/9ec01308-9d94-4413-92e2-8d0dc9fe8eb3_RETINA_PORTRAIT_16_9.jpg",
#     "attractions": "Los Angeles Dodgers, Los Angeles Angels",
#     "on_sale_date": "1900-01-01T18:00:00Z",
#     "off_sale_date": "2025-05-17T02:10:00Z"
#   },
#   {
#     "id": "Z7r9jZ1A7fef7",
#     "name": "UCLA Bruins Baseball vs. Northwestern Wildcats Baseball",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7fef7",
#     "status": "onsale",
#     "start_date": "2025-05-17",
#     "start_time": "13:00:00",
#     "venue_name": "Jackie Robinson Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_latitude": "34.065701000",
#     "venue_longitude": "-118.436996000",
#     "segment": "Sports",
#     "genre": "Miscellaneous",
#     "subgenre": "Miscellaneous",
#     "image_url": "https://s1.ticketm.net/dam/a/60f/4e8e8937-236c-49d3-bc03-19af5bb0b60f_RETINA_PORTRAIT_16_9.jpg",
#     "attractions": "UCLA Bruins Baseball, Northwestern Wildcats Baseball",
#     "on_sale_date": "1900-01-01T06:00:00Z",
#     "off_sale_date": "2025-05-17T20:00:00Z"
#   },
#   {
#     "id": "vvG1IZbIr1t-3p",
#     "name": "Cl\u00e1sico Femenil: Chivas vs Club America",
#     "url": "https://www.ticketmaster.com/clasico-femenil-chivas-vs-club-america-los-angeles-california-05-17-2025/event/0A0062878AA61496",
#     "status": "onsale",
#     "start_date": "2025-05-17",
#     "start_time": "17:30:00",
#     "venue_name": "BMO Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_latitude": "34.01287900",
#     "venue_longitude": "-118.28492600",
#     "segment": "Sports",
#     "genre": "Soccer",
#     "subgenre": "Soccer",
#     "image_url": "https://s1.ticketm.net/dam/c/f9a/3c3c0a9d-033f-47b3-9621-7b554d80df9a_106241_RETINA_PORTRAIT_16_9.jpg",
#     "attractions": "C.D. Guadalajara Femenil, Club Am\u00e9rica Femenil",
#     "on_sale_date": "2025-04-10T17:00:00Z",
#     "off_sale_date": "2025-05-18T02:30:00Z"
#   },
#   {
#     "id": "Z7r9jZ1A7u-fA",
#     "name": "Los Angeles Dodgers vs. Los Angeles Angels",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7u-fA",
#     "status": "onsale",
#     "start_date": "2025-05-17",
#     "start_time": "18:10:00",
#     "venue_name": "Dodger Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_latitude": "34.065800000",
#     "venue_longitude": "-118.238800000",
#     "segment": "Sports",
#     "genre": "Baseball",
#     "subgenre": "MLB",
#     "image_url": "https://s1.ticketm.net/dam/a/eb3/9ec01308-9d94-4413-92e2-8d0dc9fe8eb3_RETINA_PORTRAIT_16_9.jpg",
#     "attractions": "Los Angeles Dodgers, Los Angeles Angels",
#     "on_sale_date": "1900-01-01T18:00:00Z",
#     "off_sale_date": "2025-05-18T01:10:00Z"
#   }
# ]

# %% [markdown]
# # events endpoint

# %%
from google.colab import userdata

import requests
import pandas as pd
import json
from datetime import datetime
from IPython.display import display, HTML

api_key = userdata.get('TICKETMASTER_API_KEY')
base_url = "https://app.ticketmaster.com/discovery/v2/events.json"

def fetch_events(
    # Basic parameters
    country_code=None,
    size=100,
    page=0,
    sort="date,asc",

    # Identification parameters
    id=None,
    keyword=None,
    attraction_id=None,
    venue_id=None,

    # Geographic parameters
    city=None,
    state_code=None,
    postal_code=None,
    latlong=None,
    geo_point=None,
    radius=None,
    unit="miles",
    dma_id=None,

    # Date and time parameters
    start_date_time=None,
    end_date_time=None,
    local_start_date_time=None,
    local_start_end_date_time=None,
    start_end_date_time=None,

    # Classification parameters
    classification_name=None,
    classification_id=None,
    segment_id=None,
    segment_name=None,
    genre_id=None,
    sub_genre_id=None,
    type_id=None,
    sub_type_id=None,

    # Sale parameters
    onsale_start_date_time=None,
    onsale_end_date_time=None,
    onsale_on_start_date=None,
    onsale_on_after_start_date=None,
    pre_sale_date_time=None,
    public_visibility_start_date_time=None,

    # Include/exclude parameters
    include_tba="yes",
    include_tbd="yes",
    include_test="no",
    include_family="yes",
    include_spellcheck="no",

    # Other filtering parameters
    market_id=None,
    promoter_id=None,
    collection_id=None,
    source=None,
    locale="en",
    domain=None,
    preferred_country="us"
):
    # Define parameters dict with base parameters
    params = {
        'apikey': api_key,
        'size': size,
        'page': page,
        'sort': sort,
        'includeTBA': include_tba,
        'includeTBD': include_tbd,
        'includeTest': include_test,
        'includeFamily': include_family,
        'includeSpellcheck': include_spellcheck,
        'locale': locale,
        'preferredCountry': preferred_country
    }

    # Helper function to add parameters if they're provided
    def add_param(param_name, value, api_param_name=None):
        if value is not None:
            params[api_param_name or param_name] = value

    # Add identification parameters
    add_param('id', id)
    add_param('keyword', keyword)
    add_param('attractionId', attraction_id)
    add_param('venueId', venue_id)

    # Add geographic parameters
    add_param('countryCode', country_code)
    add_param('city', city)
    add_param('stateCode', state_code)
    add_param('postalCode', postal_code)
    add_param('latlong', latlong)
    add_param('geoPoint', geo_point)
    add_param('radius', radius)
    add_param('unit', unit)
    add_param('dmaId', dma_id)

    # Add date/time parameters
    add_param('startDateTime', start_date_time)
    add_param('endDateTime', end_date_time)
    add_param('localStartDateTime', local_start_date_time)
    add_param('localStartEndDateTime', local_start_end_date_time)
    add_param('startEndDateTime', start_end_date_time)

    # Add classification parameters
    add_param('classificationName', classification_name)
    add_param('classificationId', classification_id)
    add_param('segmentId', segment_id)
    add_param('segmentName', segment_name)
    add_param('genreId', genre_id)
    add_param('subGenreId', sub_genre_id)
    add_param('typeId', type_id)
    add_param('subTypeId', sub_type_id)

    # Add sale parameters
    add_param('onsaleStartDateTime', onsale_start_date_time)
    add_param('onsaleEndDateTime', onsale_end_date_time)
    add_param('onsaleOnStartDate', onsale_on_start_date)
    add_param('onsaleOnAfterStartDate', onsale_on_after_start_date)
    add_param('preSaleDateTime', pre_sale_date_time)
    add_param('publicVisibilityStartDateTime', public_visibility_start_date_time)

    # Add other filtering parameters
    add_param('marketId', market_id)
    add_param('promoterId', promoter_id)
    add_param('collectionId', collection_id)
    add_param('source', source)
    add_param('domain', domain)

    # Make the API request
    response = requests.get(base_url, params=params)

    # Check if the request was successful
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error: {response.status_code}")
        print(response.text)
        return None

# Process the events data into structured format
def process_events(events_data):
    if not events_data or '_embedded' not in events_data:
        print("No events found or invalid response")
        return None

    event_list = []

    for event in events_data['_embedded']['events']:
        # Extract basic event info
        event_info = {
            'id': event['id'],
            'name': event['name'],
            'url': event['url'],
            'status': event['dates']['status']['code'] if 'status' in event['dates'] else 'unknown',
            'start_date': event['dates']['start'].get('localDate', 'unknown'),
            'start_time': event['dates']['start'].get('localTime', 'unknown'),
        }

        # Add end date and time if available
        if 'end' in event['dates']:
            event_info['end_date'] = event['dates']['end'].get('localDate', 'unknown')
            event_info['end_time'] = event['dates']['end'].get('localTime', 'unknown')

        # Calculate duration if possible
        if ('end' in event['dates'] and
            event_info['start_date'] != 'unknown' and event_info['start_time'] != 'unknown' and
            event_info['end_date'] != 'unknown' and event_info['end_time'] != 'unknown'):
            try:
                start_dt = datetime.strptime(f"{event_info['start_date']} {event_info['start_time']}", "%Y-%m-%d %H:%M:%S")
                end_dt = datetime.strptime(f"{event_info['end_date']} {event_info['end_time']}", "%Y-%m-%d %H:%M:%S")
                duration = end_dt - start_dt
                event_info['duration_minutes'] = duration.total_seconds() / 60
            except:
                # Handle cases where time formats might be different
                event_info['duration_minutes'] = 'unknown'

        # Add venue info if available
        if '_embedded' in event and 'venues' in event['_embedded'] and len(event['_embedded']['venues']) > 0:
            venue = event['_embedded']['venues'][0]
            event_info['venue_id'] = venue.get('id', 'unknown')
            event_info['venue_name'] = venue.get('name', 'unknown')
            event_info['venue_city'] = venue.get('city', {}).get('name', 'unknown')
            event_info['venue_state'] = venue.get('state', {}).get('name', 'unknown')
            event_info['venue_country'] = venue.get('country', {}).get('name', 'unknown')
            event_info['venue_postal_code'] = venue.get('postalCode', 'unknown')
            event_info['venue_url'] = venue.get('url', 'unknown')

            # Add venue coordinates if available
            if 'location' in venue:
                event_info['venue_latitude'] = venue['location'].get('latitude', 'unknown')
                event_info['venue_longitude'] = venue['location'].get('longitude', 'unknown')

        # Add price range if available
        if 'priceRanges' in event and len(event['priceRanges']) > 0:
            price_range = event['priceRanges'][0]
            event_info['min_price'] = price_range.get('min', 'unknown')
            event_info['max_price'] = price_range.get('max', 'unknown')
            event_info['currency'] = price_range.get('currency', 'unknown')

        # Add genre/classification if available
        if 'classifications' in event and len(event['classifications']) > 0:
            classification = event['classifications'][0]
            if 'segment' in classification and classification['segment']:
                event_info['segment'] = classification['segment'].get('name', 'unknown')
                event_info['segment_id'] = classification['segment'].get('id', 'unknown')
            if 'genre' in classification and classification['genre']:
                event_info['genre'] = classification['genre'].get('name', 'unknown')
                event_info['genre_id'] = classification['genre'].get('id', 'unknown')
            if 'subGenre' in classification and classification['subGenre']:
                event_info['subgenre'] = classification['subGenre'].get('name', 'unknown')
                event_info['subgenre_id'] = classification['subGenre'].get('id', 'unknown')
            if 'type' in classification and classification['type']:
                event_info['type'] = classification['type'].get('name', 'unknown')
                event_info['type_id'] = classification['type'].get('id', 'unknown')
            if 'subType' in classification and classification['subType']:
                event_info['subtype'] = classification['subType'].get('name', 'unknown')
                event_info['subtype_id'] = classification['subType'].get('id', 'unknown')

        # Add image URLs if available
        if 'images' in event and len(event['images']) > 0:
            # Find standard image
            standard_images = [img for img in event['images'] if img.get('ratio') == '16_9' and img.get('width') > 500]
            if standard_images:
                event_info['image_url'] = standard_images[0]['url']
            else:
                event_info['image_url'] = event['images'][0]['url']  # Fallback to first image

        # Add attractions/performers if available
        if '_embedded' in event and 'attractions' in event['_embedded'] and len(event['_embedded']['attractions']) > 0:
            attractions = []
            attraction_ids = []
            for attraction in event['_embedded']['attractions']:
                attractions.append(attraction.get('name', 'unknown'))
                attraction_ids.append(attraction.get('id', 'unknown'))
            event_info['attractions'] = ', '.join(attractions)
            event_info['attraction_ids'] = ', '.join(attraction_ids)

        # Add ticket info if available
        if 'sales' in event and 'public' in event['sales']:
            sales_public = event['sales']['public']
            if 'startDateTime' in sales_public:
                event_info['on_sale_date'] = sales_public['startDateTime']
            if 'endDateTime' in sales_public:
                event_info['off_sale_date'] = sales_public['endDateTime']

        # Add pre-sale info if available
        if 'sales' in event and 'presales' in event['sales'] and len(event['sales']['presales']) > 0:
            presale = event['sales']['presales'][0]  # Get the first pre-sale info
            event_info['presale_name'] = presale.get('name', 'unknown')
            event_info['presale_start_date'] = presale.get('startDateTime', 'unknown')
            event_info['presale_end_date'] = presale.get('endDateTime', 'unknown')

        event_list.append(event_info)

    # Create DataFrame
    df = pd.DataFrame(event_list)
    return df

# Function to fetch events with pagination
def fetch_all_events(max_pages=5, events_per_page=20, **search_params):
    all_events = []
    total_elements = 0
    total_pages = 0

    for page in range(max_pages):
        # Update the page parameter
        search_params['page'] = page
        search_params['size'] = events_per_page

        # Fetch the current page
        events_data = fetch_events(**search_params)

        # Check if we have a valid response
        if events_data and '_embedded' in events_data and 'events' in events_data['_embedded']:
            # Get page info
            page_info = events_data.get('page', {})
            total_elements = page_info.get('totalElements', 0)
            total_pages = page_info.get('totalPages', 0)

            # Process the events and add them to our collection
            page_events = events_data['_embedded']['events']
            all_events.extend(page_events)

            print(f"Fetched page {page+1}/{total_pages} ({len(page_events)} events)")

            # Check if we've reached the last page
            if page >= total_pages - 1:
                break
        else:
            print(f"No events found on page {page+1} or error in response")
            break

    # Convert all events to raw format for processing
    raw_events_data = {
        '_embedded': {
            'events': all_events
        }
    }

    print(f"Total events fetched: {len(all_events)} out of {total_elements}")
    return raw_events_data

# Function to display results as table and JSON
def display_structured_events(events_data):
    # Process the events
    events_df = process_events(events_data)

    if events_df is not None and not events_df.empty:
        # Display info
        print(f"Found {len(events_df)} events")

        # Display as styled table
        print("\n=== EVENTS TABLE ===")
        display(events_df)

        # Convert to JSON format and display
        print("\n=== EVENTS JSON ===")
        events_json = events_df.to_dict(orient='records')
        print(json.dumps(events_json, indent=2))

        return {
            'dataframe': events_df,
            'json': events_json
        }
    else:
        print("No events to display")
        return None

# Save results to CSV, JSON, or Excel
def save_results(results, format='all', prefix='events'):
    if results is None or 'dataframe' not in results:
        print("No results to save")
        return

    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    df = results['dataframe']

    if format.lower() in ['csv', 'all']:
        filename = f"{prefix}_{timestamp}.csv"
        df.to_csv(filename, index=False)
        print(f"Saved CSV to {filename}")

    if format.lower() in ['json', 'all']:
        filename = f"{prefix}_{timestamp}.json"
        with open(filename, 'w') as f:
            json.dump(results['json'], f, indent=2)
        print(f"Saved JSON to {filename}")

    if format.lower() in ['excel', 'all']:
        filename = f"{prefix}_{timestamp}.xlsx"
        df.to_excel(filename, index=False)
        print(f"Saved Excel to {filename}")

# Example usage
def main():
    # Define your search parameters with more options
    params = {
        'country_code': "US",
        'classification_name': "sports",  # Music, Sports, Arts, Film, etc.
        'city': "Los Angeles",
        'state_code': "CA",
        'start_date_time': "2025-05-15T00:00:00Z",  # Events after this date
        'end_date_time': "2025-08-15T23:59:59Z",    # Events before this date
        'sort': "date,asc",                        # Sort by date ascending
        'include_family': "yes"                    # Include family-friendly events
    }

    # Fetch events with pagination (up to 3 pages, 20 events per page)
    print(f"Fetching {params['classification_name']} events in {params['city']}, {params['state_code']}...")
    print(f"Time range: {params['start_date_time']} to {params['end_date_time']}")

    events_data = fetch_all_events(max_pages=3, events_per_page=20, **params)

    # Display structured results
    results = display_structured_events(events_data)

    # Save results to files
    save_results(results, format='all', prefix='la_sports_events')

    return results

# Run the main function
if __name__ == "__main__":
    results = main()
# Out:
# Fetching sports events in Los Angeles, CA...
# Time range: 2025-05-15T00:00:00Z to 2025-08-15T23:59:59Z
# Fetched page 1/5 (20 events)
# Fetched page 2/5 (20 events)
# Fetched page 3/5 (20 events)
# Total events fetched: 60 out of 83
# Found 60 events
#
# === EVENTS TABLE ===
#                 id                                               name  \
# 0    Z7r9jZ1A7u-oJ                  Los Angeles Dodgers vs. Athletics
# 1   vvG1IZb_Fe9NH-  Los Angeles Football Club vs. Seattle Sounders FC
# 2    Z7r9jZ1A7fefd  UCLA Bruins Baseball vs. Northwestern Wildcats...
# 3    Z7r9jZ1A7u-o0                  Los Angeles Dodgers vs. Athletics
# 4    Z7r9jZ1A7fef6  UCLA Bruins Baseball vs. Northwestern Wildcats...
# 5    Z7r9jZ1A7u-f7         Los Angeles Dodgers vs. Los Angeles Angels
# 6    Z7r9jZ1A7fef7  UCLA Bruins Baseball vs. Northwestern Wildcats...
# 7   vvG1IZbIr1t-3p            Clásico Femenil: Chivas vs Club America
# 8    Z7r9jZ1A7u-fA         Los Angeles Dodgers vs. Los Angeles Angels
# 9    Z7r9jZ1A7u-fk         Los Angeles Dodgers vs. Los Angeles Angels
# 10   Z7r9jZ1A7oPxA              Los Angeles Sparks vs. Minnesota Lynx
# 11   Z7r9jZ1A7u-f6       Los Angeles Dodgers vs. Arizona Diamondbacks
# 12   Z7r9jZ1A7u-fF       Los Angeles Dodgers vs. Arizona Diamondbacks
# 13   Z7r9jZ1A7u-fa       Los Angeles Dodgers vs. Arizona Diamondbacks
# 14   Z7r9jZ1A7oPxe      Los Angeles Sparks vs. Golden State Valkyries
# 15  vvG1IZbNRXHdV9             Angel City FC vs. Racing Louisville FC
# 16  vvG1IZbthbMf-C    Angel City FC vs. Racing Louisville FC - Suites
# 17   Z7r9jZ1A7oP-I                 Los Angeles Sparks vs. Chicago Sky
# 18   Z7r9jZ1A7oP-Y               Los Angeles Sparks vs. Atlanta Dream
# 19  vvG1IZb_FebNWF  Los Angeles Football Club vs. Sporting Kansas ...
# 20   Z7r9jZ1A7u-f8           Los Angeles Dodgers vs. New York Yankees
# 21   Z7r9jZ1A7u-fo           Los Angeles Dodgers vs. New York Yankees
# 22  vvG1IZb_Fe_KW8      Los Angeles Football Club vs. Colorado Rapids
# 23   Z7r9jZ1A7oPxZ             Los Angeles Sparks vs. Phoenix Mercury
# 24   Z7r9jZ1A7u-f3           Los Angeles Dodgers vs. New York Yankees
# 25   Z7r9jZ1A7u-fK              Los Angeles Dodgers vs. New York Mets
# 26   Z7r9jZ1A7u-ff              Los Angeles Dodgers vs. New York Mets
# 27   Z7r9jZ1A7u-f4              Los Angeles Dodgers vs. New York Mets
# 28   Z7r9jZ1A7u-fp              Los Angeles Dodgers vs. New York Mets
# 29  vvG1IZbNRXHSVI                 Angel City FC vs. Chicago Stars FC
# 30  vvG1IZbthbMV-8        Angel City FC vs. Chicago Stars FC - Suites
# 31   Z7r9jZ1A7oPxv      Los Angeles Sparks vs. Golden State Valkyries
# 32   Z7r9jZ1A7u-f9       Los Angeles Dodgers vs. San Francisco Giants
# 33  vvG1IZb_FeQdW3           Los Angeles Football Club vs. Toronto FC
# 34  vvG1IZbNRXWNVy           Angel City FC vs. North Carolina Courage
# 35  vvG1IZbthbz7-3  Angel City FC vs. North Carolina Courage - Suites
# 36   Z7r9jZ1A7u-fb       Los Angeles Dodgers vs. San Francisco Giants
# 37   Z7r9jZ1A7u-f_       Los Angeles Dodgers vs. San Francisco Giants
# 38   Z7r9jZ1A7u-fO           Los Angeles Dodgers vs. San Diego Padres
# 39   Z7r9jZ1A7oP-w               Los Angeles Sparks vs. Seattle Storm
# 40   Z7r9jZ1A7u-f-           Los Angeles Dodgers vs. San Diego Padres
# 41   Z7r9jZ1A7u-fx           Los Angeles Dodgers vs. San Diego Padres
# 42   Z7r9jZ1A7u-fN           Los Angeles Dodgers vs. San Diego Padres
# 43   Z7r9jZ1A7u-f0       Los Angeles Dodgers vs. Washington Nationals
# 44   Z7r9jZ1A7u-fP       Los Angeles Dodgers vs. Washington Nationals
# 45   Z7r9jZ1A7u-fJ       Los Angeles Dodgers vs. Washington Nationals
# 46  vvG1IZb_FehdWq  Los Angeles Football Club vs. Vancouver Whitec...
# 47   Z7r9jZ1A7oP-M                 Los Angeles Sparks vs. Chicago Sky
# 48   Z7r9jZ1A7u-fE          Los Angeles Dodgers vs. Chicago White Sox
# 49   Z7r9jZ1A7u-fI          Los Angeles Dodgers vs. Chicago White Sox
# 50   Z7r9jZ1A7u-ft          Los Angeles Dodgers vs. Chicago White Sox
# 51   Z7r9jZ1A7u-fY             Los Angeles Dodgers vs. Houston Astros
# 52   Z7r9jZ1A7u-fs             Los Angeles Dodgers vs. Houston Astros
# 53   Z7r9jZ1A7u-fw             Los Angeles Dodgers vs. Houston Astros
# 54   Z7r9jZ1A7oP-V              Los Angeles Sparks vs. Minnesota Lynx
# 55  vvG1IZb_FehSWn            Los Angeles Football Club vs. FC Dallas
# 56   Z7r9jZ1A7oP-y             Los Angeles Sparks vs. Connecticut Sun
# 57   Z7r9jZ1A7oP-t          Los Angeles Sparks vs. Washington Mystics
# 58   Z7r9jZ1A7u-fS          Los Angeles Dodgers vs. Milwaukee Brewers
# 59   Z7r9jZ1A7u-fV          Los Angeles Dodgers vs. Milwaukee Brewers
#
#                                                   url  status  start_date  \
# 0    https://www.ticketmaster.com/event/Z7r9jZ1A7u-oJ  onsale  2025-05-14
# 1   https://www.ticketmaster.com/los-angeles-footb...  onsale  2025-05-14
# 2    https://www.ticketmaster.com/event/Z7r9jZ1A7fefd  onsale  2025-05-15
# 3    https://www.ticketmaster.com/event/Z7r9jZ1A7u-o0  onsale  2025-05-15
# 4    https://www.ticketmaster.com/event/Z7r9jZ1A7fef6  onsale  2025-05-16
# 5    https://www.ticketmaster.com/event/Z7r9jZ1A7u-f7  onsale  2025-05-16
# 6    https://www.ticketmaster.com/event/Z7r9jZ1A7fef7  onsale  2025-05-17
# 7   https://www.ticketmaster.com/clasico-femenil-c...  onsale  2025-05-17
# 8    https://www.ticketmaster.com/event/Z7r9jZ1A7u-fA  onsale  2025-05-17
# 9    https://www.ticketmaster.com/event/Z7r9jZ1A7u-fk  onsale  2025-05-18
# 10   https://www.ticketmaster.com/event/Z7r9jZ1A7oPxA  onsale  2025-05-18
# 11   https://www.ticketmaster.com/event/Z7r9jZ1A7u-f6  onsale  2025-05-19
# 12   https://www.ticketmaster.com/event/Z7r9jZ1A7u-fF  onsale  2025-05-20
# 13   https://www.ticketmaster.com/event/Z7r9jZ1A7u-fa  onsale  2025-05-21
# 14   https://www.ticketmaster.com/event/Z7r9jZ1A7oPxe  onsale  2025-05-23
# 15  https://www.ticketmaster.com/angel-city-fc-vs-...  onsale  2025-05-24
# 16            https://www.gofevo.com/event/ACSUITELOU  onsale  2025-05-24
# 17   https://www.ticketmaster.com/event/Z7r9jZ1A7oP-I  onsale  2025-05-25
# 18   https://www.ticketmaster.com/event/Z7r9jZ1A7oP-Y  onsale  2025-05-27
# 19  https://www.ticketmaster.com/los-angeles-footb...  onsale  2025-05-28
# 20   https://www.ticketmaster.com/event/Z7r9jZ1A7u-f8  onsale  2025-05-30
# 21   https://www.ticketmaster.com/event/Z7r9jZ1A7u-fo  onsale  2025-05-31
# 22  https://www.ticketmaster.com/los-angeles-footb...  onsale  2025-05-31
# 23   https://www.ticketmaster.com/event/Z7r9jZ1A7oPxZ  onsale  2025-06-01
# 24   https://www.ticketmaster.com/event/Z7r9jZ1A7u-f3  onsale  2025-06-01
# 25   https://www.ticketmaster.com/event/Z7r9jZ1A7u-fK  onsale  2025-06-02
# 26   https://www.ticketmaster.com/event/Z7r9jZ1A7u-ff  onsale  2025-06-03
# 27   https://www.ticketmaster.com/event/Z7r9jZ1A7u-f4  onsale  2025-06-04
# 28   https://www.ticketmaster.com/event/Z7r9jZ1A7u-fp  onsale  2025-06-05
# 29  https://www.ticketmaster.com/angel-city-fc-vs-...  onsale  2025-06-07
# 30            https://www.gofevo.com/event/ACSUITECHI  onsale  2025-06-07
# 31   https://www.ticketmaster.com/event/Z7r9jZ1A7oPxv  onsale  2025-06-09
# 32   https://www.ticketmaster.com/event/Z7r9jZ1A7u-f9  onsale  2025-06-13
# 33  https://www.ticketmaster.com/los-angeles-footb...  onsale  2025-06-13
# 34  https://www.ticketmaster.com/angel-city-fc-vs-...  onsale  2025-06-14
# 35             https://www.gofevo.com/event/ACSUITENC  onsale  2025-06-14
# 36   https://www.ticketmaster.com/event/Z7r9jZ1A7u-fb  onsale  2025-06-14
# 37   https://www.ticketmaster.com/event/Z7r9jZ1A7u-f_  onsale  2025-06-15
# 38   https://www.ticketmaster.com/event/Z7r9jZ1A7u-fO  onsale  2025-06-16
# 39   https://www.ticketmaster.com/event/Z7r9jZ1A7oP-w  onsale  2025-06-17
# 40   https://www.ticketmaster.com/event/Z7r9jZ1A7u-f-  onsale  2025-06-17
# 41   https://www.ticketmaster.com/event/Z7r9jZ1A7u-fx  onsale  2025-06-18
# 42   https://www.ticketmaster.com/event/Z7r9jZ1A7u-fN  onsale  2025-06-19
# 43   https://www.ticketmaster.com/event/Z7r9jZ1A7u-f0  onsale  2025-06-20
# 44   https://www.ticketmaster.com/event/Z7r9jZ1A7u-fP  onsale  2025-06-21
# 45   https://www.ticketmaster.com/event/Z7r9jZ1A7u-fJ  onsale  2025-06-22
# 46  https://www.ticketmaster.com/los-angeles-footb...  onsale  2025-06-28
# 47   https://www.ticketmaster.com/event/Z7r9jZ1A7oP-M  onsale  2025-06-29
# 48   https://www.ticketmaster.com/event/Z7r9jZ1A7u-fE  onsale  2025-07-01
# 49   https://www.ticketmaster.com/event/Z7r9jZ1A7u-fI  onsale  2025-07-02
# 50   https://www.ticketmaster.com/event/Z7r9jZ1A7u-ft  onsale  2025-07-03
# 51   https://www.ticketmaster.com/event/Z7r9jZ1A7u-fY  onsale  2025-07-04
# 52   https://www.ticketmaster.com/event/Z7r9jZ1A7u-fs  onsale  2025-07-05
# 53   https://www.ticketmaster.com/event/Z7r9jZ1A7u-fw  onsale  2025-07-06
# 54   https://www.ticketmaster.com/event/Z7r9jZ1A7oP-V  onsale  2025-07-10
# 55  https://www.ticketmaster.com/los-angeles-footb...  onsale  2025-07-12
# 56   https://www.ticketmaster.com/event/Z7r9jZ1A7oP-y  onsale  2025-07-13
# 57   https://www.ticketmaster.com/event/Z7r9jZ1A7oP-t  onsale  2025-07-15
# 58   https://www.ticketmaster.com/event/Z7r9jZ1A7u-fS  onsale  2025-07-18
# 59   https://www.ticketmaster.com/event/Z7r9jZ1A7u-fV  onsale  2025-07-19
#
#    start_time     venue_id               venue_name   venue_city venue_state  \
# 0    19:10:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 1    19:30:00  KovZ917A3c0              BMO Stadium  Los Angeles  California
# 2    18:00:00   ZFr9jZFaka  Jackie Robinson Stadium  Los Angeles  California
# 3    19:10:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 4    18:00:00   ZFr9jZFaka  Jackie Robinson Stadium  Los Angeles  California
# 5    19:10:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 6    13:00:00   ZFr9jZFaka  Jackie Robinson Stadium  Los Angeles  California
# 7    17:30:00  KovZ917A3c0              BMO Stadium  Los Angeles  California
# 8    18:10:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 9    13:10:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 10   15:00:00   ZFr9jZe6vA         Crypto.com Arena  Los Angeles  California
# 11   19:10:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 12   19:10:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 13   19:10:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 14   19:00:00   ZFr9jZe6vA         Crypto.com Arena  Los Angeles  California
# 15   19:00:00  KovZ917A3c0              BMO Stadium  Los Angeles  California
# 16   19:00:00  KovZ917A3c0              BMO Stadium  Los Angeles  California
# 17   15:00:00   ZFr9jZe6vA         Crypto.com Arena  Los Angeles  California
# 18   19:00:00   ZFr9jZe6vA         Crypto.com Arena  Los Angeles  California
# 19   19:30:00  KovZ917A3c0              BMO Stadium  Los Angeles  California
# 20   19:10:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 21   16:15:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 22   19:30:00  KovZ917A3c0              BMO Stadium  Los Angeles  California
# 23   15:00:00   ZFr9jZe6vA         Crypto.com Arena  Los Angeles  California
# 24   16:10:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 25   19:10:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 26   19:10:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 27   19:10:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 28   13:10:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 29   19:00:00  KovZ917A3c0              BMO Stadium  Los Angeles  California
# 30   19:00:00  KovZ917A3c0              BMO Stadium  Los Angeles  California
# 31   19:00:00   ZFr9jZe6vA         Crypto.com Arena  Los Angeles  California
# 32   19:10:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 33   19:30:00  KovZ917A3c0              BMO Stadium  Los Angeles  California
# 34   19:00:00  KovZ917A3c0              BMO Stadium  Los Angeles  California
# 35   19:00:00  KovZ917A3c0              BMO Stadium  Los Angeles  California
# 36   19:10:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 37   13:10:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 38   19:10:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 39   19:00:00   ZFr9jZe6vA         Crypto.com Arena  Los Angeles  California
# 40   19:10:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 41   19:10:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 42   19:10:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 43   19:10:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 44   18:10:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 45   13:10:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 46   19:30:00  KovZ917A3c0              BMO Stadium  Los Angeles  California
# 47   13:00:00   ZFr9jZe6vA         Crypto.com Arena  Los Angeles  California
# 48   19:10:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 49   19:10:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 50   19:10:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 51   18:10:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 52   16:15:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 53   13:10:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 54   12:00:00   ZFr9jZe6vA         Crypto.com Arena  Los Angeles  California
# 55   19:30:00  KovZ917A3c0              BMO Stadium  Los Angeles  California
# 56   15:00:00   ZFr9jZe6vA         Crypto.com Arena  Los Angeles  California
# 57   19:00:00   ZFr9jZe6vA         Crypto.com Arena  Los Angeles  California
# 58   19:10:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
# 59   18:10:00   Z6r9jZAFke           Dodger Stadium  Los Angeles  California
#
#     ...            attraction_ids          on_sale_date         off_sale_date  \
# 0   ...  K8vZ9171oA0, K8vZ9171o60  1900-01-01T18:00:00Z  2025-05-15T02:10:00Z
# 1   ...  K8vZ917p0D0, K8vZ917G8RV                   NaN                   NaN
# 2   ...  K8vZ917GrHf, K8vZ917CATV  1900-01-01T06:00:00Z  2025-05-16T01:00:00Z
# 3   ...  K8vZ9171oA0, K8vZ9171o60  1900-01-01T18:00:00Z  2025-05-16T02:10:00Z
# 4   ...  K8vZ917GrHf, K8vZ917CATV  1900-01-01T06:00:00Z  2025-05-17T01:00:00Z
# 5   ...  K8vZ9171oA0, K8vZ91718D0  1900-01-01T18:00:00Z  2025-05-17T02:10:00Z
# 6   ...  K8vZ917GrHf, K8vZ917CATV  1900-01-01T06:00:00Z  2025-05-17T20:00:00Z
# 7   ...  K8vZ917rAxV, K8vZ917hGmV  2025-04-10T17:00:00Z  2025-05-18T02:30:00Z
# 8   ...  K8vZ9171oA0, K8vZ91718D0  1900-01-01T18:00:00Z  2025-05-18T01:10:00Z
# 9   ...  K8vZ9171oA0, K8vZ91718D0  1900-01-01T18:00:00Z  2025-05-18T20:10:00Z
# 10  ...  K8vZ9171prV, K8vZ9171h3V  1900-01-01T18:00:00Z  2025-05-18T22:00:00Z
# 11  ...  K8vZ9171oA0, K8vZ9171bp7  1900-01-01T18:00:00Z  2025-05-20T02:10:00Z
# 12  ...  K8vZ9171oA0, K8vZ9171bp7  1900-01-01T18:00:00Z  2025-05-21T02:10:00Z
# 13  ...  K8vZ9171oA0, K8vZ9171bp7  1900-01-01T18:00:00Z  2025-05-22T02:10:00Z
# 14  ...  K8vZ9171prV, K8vZ917qxG7  1900-01-01T18:00:00Z  2025-05-24T02:00:00Z
# 15  ...  K8vZ917_Fd7, K8vZ917_pjV                   NaN                   NaN
# 16  ...               K8vZ917_Fd7  2025-04-25T17:00:00Z  2025-05-25T02:00:00Z
# 17  ...  K8vZ9171prV, K8vZ9175zE0  1900-01-01T18:00:00Z  2025-05-25T22:00:00Z
# 18  ...  K8vZ9171prV, K8vZ917G1N0  1900-01-01T18:00:00Z  2025-05-28T02:00:00Z
# 19  ...  K8vZ917p0D0, K8vZ9171bf7                   NaN                   NaN
# 20  ...  K8vZ9171oA0, K8vZ9171okV  1900-01-01T18:00:00Z  2025-05-31T02:10:00Z
# 21  ...  K8vZ9171oA0, K8vZ9171okV  1900-01-01T18:00:00Z  2025-05-31T23:15:00Z
# 22  ...  K8vZ917p0D0, K8vZ9171pM7                   NaN                   NaN
# 23  ...  K8vZ9171prV, K8vZ9171prf  1900-01-01T18:00:00Z  2025-06-01T22:00:00Z
# 24  ...  K8vZ9171oA0, K8vZ9171okV  1900-01-01T18:00:00Z  2025-06-01T23:10:00Z
# 25  ...  K8vZ9171oA0, K8vZ91718B7  1900-01-01T18:00:00Z  2025-06-03T02:10:00Z
# 26  ...  K8vZ9171oA0, K8vZ91718B7  1900-01-01T18:00:00Z  2025-06-04T02:10:00Z
# 27  ...  K8vZ9171oA0, K8vZ91718B7  1900-01-01T18:00:00Z  2025-06-05T02:10:00Z
# 28  ...  K8vZ9171oA0, K8vZ91718B7  1900-01-01T18:00:00Z  2025-06-05T20:10:00Z
# 29  ...  K8vZ917_Fd7, K8vZ917GfQ0                   NaN                   NaN
# 30  ...               K8vZ917_Fd7  2025-04-25T17:00:00Z  2025-06-08T02:00:00Z
# 31  ...  K8vZ9171prV, K8vZ917qxG7  1900-01-01T18:00:00Z  2025-06-10T02:00:00Z
# 32  ...  K8vZ9171oA0, K8vZ91718Df  1900-01-01T18:00:00Z  2025-06-14T02:10:00Z
# 33  ...  K8vZ917p0D0, K8vZ917Ges7                   NaN                   NaN
# 34  ...  K8vZ917_Fd7, K8vZ917psuV                   NaN                   NaN
# 35  ...               K8vZ917_Fd7  2025-04-25T17:00:00Z  2025-06-15T02:00:00Z
# 36  ...  K8vZ9171oA0, K8vZ91718Df  1900-01-01T18:00:00Z  2025-06-15T02:10:00Z
# 37  ...  K8vZ9171oA0, K8vZ91718Df  1900-01-01T18:00:00Z  2025-06-15T20:10:00Z
# 38  ...  K8vZ9171oA0, K8vZ91718BV  1900-01-01T18:00:00Z  2025-06-17T02:10:00Z
# 39  ...  K8vZ9171prV, K8vZ9171xo0  1900-01-01T18:00:00Z  2025-06-18T02:00:00Z
# 40  ...  K8vZ9171oA0, K8vZ91718BV  1900-01-01T18:00:00Z  2025-06-18T02:10:00Z
# 41  ...  K8vZ9171oA0, K8vZ91718BV  1900-01-01T18:00:00Z  2025-06-19T02:10:00Z
# 42  ...  K8vZ9171oA0, K8vZ91718BV  1900-01-01T18:00:00Z  2025-06-20T02:10:00Z
# 43  ...  K8vZ9171oA0, K8vZ9175lJ0  1900-01-01T18:00:00Z  2025-06-21T02:10:00Z
# 44  ...  K8vZ9171oA0, K8vZ9175lJ0  1900-01-01T18:00:00Z  2025-06-22T01:10:00Z
# 45  ...  K8vZ9171oA0, K8vZ9175lJ0  1900-01-01T18:00:00Z  2025-06-22T20:10:00Z
# 46  ...  K8vZ917p0D0, K8vZ9171mtV                   NaN                   NaN
# 47  ...  K8vZ9171prV, K8vZ9175zE0  1900-01-01T18:00:00Z  2025-06-29T20:00:00Z
# 48  ...  K8vZ9171oA0, K8vZ9171ok0  1900-01-01T18:00:00Z  2025-07-02T02:10:00Z
# 49  ...  K8vZ9171oA0, K8vZ9171ok0  1900-01-01T18:00:00Z  2025-07-03T02:10:00Z
# 50  ...  K8vZ9171oA0, K8vZ9171ok0  1900-01-01T18:00:00Z  2025-07-04T02:10:00Z
# 51  ...  K8vZ9171oA0, K8vZ91718zV  1900-01-01T18:00:00Z  2025-07-05T01:10:00Z
# 52  ...  K8vZ9171oA0, K8vZ91718zV  1900-01-01T18:00:00Z  2025-07-05T23:15:00Z
# 53  ...  K8vZ9171oA0, K8vZ91718zV  1900-01-01T18:00:00Z  2025-07-06T20:10:00Z
# 54  ...  K8vZ9171prV, K8vZ9171h3V  1900-01-01T18:00:00Z  2025-07-10T19:00:00Z
# 55  ...  K8vZ917p0D0, K8vZ9171paV                   NaN                   NaN
# 56  ...  K8vZ9171prV, K8vZ91754g0  1900-01-01T18:00:00Z  2025-07-13T22:00:00Z
# 57  ...  K8vZ9171prV, K8vZ9171hKf  1900-01-01T18:00:00Z  2025-07-16T02:00:00Z
# 58  ...  K8vZ9171oA0, K8vZ91718H7  1900-01-01T18:00:00Z  2025-07-19T02:10:00Z
# 59  ...  K8vZ9171oA0, K8vZ91718H7  1900-01-01T18:00:00Z  2025-07-20T01:10:00Z
#
#          type          type_id    subtype          subtype_id   presale_name  \
# 0         NaN              NaN        NaN                 NaN            NaN
# 1       Group  KZAyXgnZfZ7v7l1       Team  KZFzBErXgnZfZ7vA7d            NaN
# 2         NaN              NaN        NaN                 NaN            NaN
# 3         NaN              NaN        NaN                 NaN            NaN
# 4         NaN              NaN        NaN                 NaN            NaN
# 5         NaN              NaN        NaN                 NaN            NaN
# 6         NaN              NaN        NaN                 NaN            NaN
# 7   Undefined  KZAyXgnZfZ7v7nI  Undefined  KZFzBErXgnZfZ7v7lJ  Venue Presale
# 8         NaN              NaN        NaN                 NaN            NaN
# 9         NaN              NaN        NaN                 NaN            NaN
# 10        NaN              NaN        NaN                 NaN            NaN
# 11        NaN              NaN        NaN                 NaN            NaN
# 12        NaN              NaN        NaN                 NaN            NaN
# 13        NaN              NaN        NaN                 NaN            NaN
# 14        NaN              NaN        NaN                 NaN            NaN
# 15  Undefined  KZAyXgnZfZ7v7nI  Undefined  KZFzBErXgnZfZ7v7lJ            NaN
# 16  Undefined  KZAyXgnZfZ7v7nI  Undefined  KZFzBErXgnZfZ7v7lJ            NaN
# 17        NaN              NaN        NaN                 NaN            NaN
# 18        NaN              NaN        NaN                 NaN            NaN
# 19      Group  KZAyXgnZfZ7v7l1       Team  KZFzBErXgnZfZ7vA7d            NaN
# 20        NaN              NaN        NaN                 NaN            NaN
# 21        NaN              NaN        NaN                 NaN            NaN
# 22      Group  KZAyXgnZfZ7v7l1       Team  KZFzBErXgnZfZ7vA7d            NaN
# 23        NaN              NaN        NaN                 NaN            NaN
# 24        NaN              NaN        NaN                 NaN            NaN
# 25        NaN              NaN        NaN                 NaN            NaN
# 26        NaN              NaN        NaN                 NaN            NaN
# 27        NaN              NaN        NaN                 NaN            NaN
# 28        NaN              NaN        NaN                 NaN            NaN
# 29  Undefined  KZAyXgnZfZ7v7nI  Undefined  KZFzBErXgnZfZ7v7lJ            NaN
# 30  Undefined  KZAyXgnZfZ7v7nI  Undefined  KZFzBErXgnZfZ7v7lJ            NaN
# 31        NaN              NaN        NaN                 NaN            NaN
# 32        NaN              NaN        NaN                 NaN            NaN
# 33      Group  KZAyXgnZfZ7v7l1       Team  KZFzBErXgnZfZ7vA7d            NaN
# 34  Undefined  KZAyXgnZfZ7v7nI  Undefined  KZFzBErXgnZfZ7v7lJ            NaN
# 35  Undefined  KZAyXgnZfZ7v7nI  Undefined  KZFzBErXgnZfZ7v7lJ            NaN
# 36        NaN              NaN        NaN                 NaN            NaN
# 37        NaN              NaN        NaN                 NaN            NaN
# 38        NaN              NaN        NaN                 NaN            NaN
# 39        NaN              NaN        NaN                 NaN            NaN
# 40        NaN              NaN        NaN                 NaN            NaN
# 41        NaN              NaN        NaN                 NaN            NaN
# 42        NaN              NaN        NaN                 NaN            NaN
# 43        NaN              NaN        NaN                 NaN            NaN
# 44        NaN              NaN        NaN                 NaN            NaN
# 45        NaN              NaN        NaN                 NaN            NaN
# 46      Group  KZAyXgnZfZ7v7l1       Team  KZFzBErXgnZfZ7vA7d            NaN
# 47        NaN              NaN        NaN                 NaN            NaN
# 48        NaN              NaN        NaN                 NaN            NaN
# 49        NaN              NaN        NaN                 NaN            NaN
# 50        NaN              NaN        NaN                 NaN            NaN
# 51        NaN              NaN        NaN                 NaN            NaN
# 52        NaN              NaN        NaN                 NaN            NaN
# 53        NaN              NaN        NaN                 NaN            NaN
# 54        NaN              NaN        NaN                 NaN            NaN
# 55      Group  KZAyXgnZfZ7v7l1       Team  KZFzBErXgnZfZ7vA7d            NaN
# 56        NaN              NaN        NaN                 NaN            NaN
# 57        NaN              NaN        NaN                 NaN            NaN
# 58        NaN              NaN        NaN                 NaN            NaN
# 59        NaN              NaN        NaN                 NaN            NaN
#
#       presale_start_date      presale_end_date
# 0                    NaN                   NaN
# 1                    NaN                   NaN
# 2                    NaN                   NaN
# 3                    NaN                   NaN
# 4                    NaN                   NaN
# 5                    NaN                   NaN
# 6                    NaN                   NaN
# 7   2025-04-09T17:00:00Z  2025-04-10T05:00:00Z
# 8                    NaN                   NaN
# 9                    NaN                   NaN
# 10                   NaN                   NaN
# 11                   NaN                   NaN
# 12                   NaN                   NaN
# 13                   NaN                   NaN
# 14                   NaN                   NaN
# 15                   NaN                   NaN
# 16                   NaN                   NaN
# 17                   NaN                   NaN
# 18                   NaN                   NaN
# 19                   NaN                   NaN
# 20                   NaN                   NaN
# 21                   NaN                   NaN
# 22                   NaN                   NaN
# 23                   NaN                   NaN
# 24                   NaN                   NaN
# 25                   NaN                   NaN
# 26                   NaN                   NaN
# 27                   NaN                   NaN
# 28                   NaN                   NaN
# 29                   NaN                   NaN
# 30                   NaN                   NaN
# 31                   NaN                   NaN
# 32                   NaN                   NaN
# 33                   NaN                   NaN
# 34                   NaN                   NaN
# 35                   NaN                   NaN
# 36                   NaN                   NaN
# 37                   NaN                   NaN
# 38                   NaN                   NaN
# 39                   NaN                   NaN
# 40                   NaN                   NaN
# 41                   NaN                   NaN
# 42                   NaN                   NaN
# 43                   NaN                   NaN
# 44                   NaN                   NaN
# 45                   NaN                   NaN
# 46                   NaN                   NaN
# 47                   NaN                   NaN
# 48                   NaN                   NaN
# 49                   NaN                   NaN
# 50                   NaN                   NaN
# 51                   NaN                   NaN
# 52                   NaN                   NaN
# 53                   NaN                   NaN
# 54                   NaN                   NaN
# 55                   NaN                   NaN
# 56                   NaN                   NaN
# 57                   NaN                   NaN
# 58                   NaN                   NaN
# 59                   NaN                   NaN
#
# [60 rows x 33 columns]
# === EVENTS JSON ===
# [
#   {
#     "id": "Z7r9jZ1A7u-oJ",
#     "name": "Los Angeles Dodgers vs. Athletics",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7u-oJ",
#     "status": "onsale",
#     "start_date": "2025-05-14",
#     "start_time": "19:10:00",
#     "venue_id": "Z6r9jZAFke",
#     "venue_name": "Dodger Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "90012",
#     "venue_url": "unknown",
#     "venue_latitude": "34.065800000",
#     "venue_longitude": "-118.238800000",
#     "segment": "Sports",
#     "segment_id": "KZFzniwnSyZfZ7v7nE",
#     "genre": "Baseball",
#     "genre_id": "KnvZfZ7vAdv",
#     "subgenre": "MLB",
#     "subgenre_id": "KZazBEonSMnZfZ7vF1n",
#     "image_url": "https://s1.ticketm.net/dam/a/1fb/ad221c4e-06a0-4acb-80a1-082c5d8861fb_SOURCE",
#     "attractions": "Los Angeles Dodgers, Athletics",
#     "attraction_ids": "K8vZ9171oA0, K8vZ9171o60",
#     "on_sale_date": "1900-01-01T18:00:00Z",
#     "off_sale_date": "2025-05-15T02:10:00Z",
#     "type": NaN,
#     "type_id": NaN,
#     "subtype": NaN,
#     "subtype_id": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "vvG1IZb_Fe9NH-",
#     "name": "Los Angeles Football Club vs. Seattle Sounders FC",
#     "url": "https://www.ticketmaster.com/los-angeles-football-club-vs-seattle-los-angeles-california-05-14-2025/event/0A006192025E3F21",
#     "status": "onsale",
#     "start_date": "2025-05-14",
#     "start_time": "19:30:00",
#     "venue_id": "KovZ917A3c0",
#     "venue_name": "BMO Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "90037",
#     "venue_url": "https://www.ticketmaster.com/bmo-stadium-tickets-los-angeles/venue/82799",
#     "venue_latitude": "34.01287900",
#     "venue_longitude": "-118.28492600",
#     "segment": "Sports",
#     "segment_id": "KZFzniwnSyZfZ7v7nE",
#     "genre": "Soccer",
#     "genre_id": "KnvZfZ7vA7E",
#     "subgenre": "MLS",
#     "subgenre_id": "KZazBEonSMnZfZ7vFtI",
#     "image_url": "https://s1.ticketm.net/dam/a/7fc/9b98825d-88b7-4a8e-8d6c-799c83ae77fc_SOURCE",
#     "attractions": "Los Angeles Football Club, Seattle Sounders FC",
#     "attraction_ids": "K8vZ917p0D0, K8vZ917G8RV",
#     "on_sale_date": NaN,
#     "off_sale_date": NaN,
#     "type": "Group",
#     "type_id": "KZAyXgnZfZ7v7l1",
#     "subtype": "Team",
#     "subtype_id": "KZFzBErXgnZfZ7vA7d",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "Z7r9jZ1A7fefd",
#     "name": "UCLA Bruins Baseball vs. Northwestern Wildcats Baseball",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7fefd",
#     "status": "onsale",
#     "start_date": "2025-05-15",
#     "start_time": "18:00:00",
#     "venue_id": "ZFr9jZFaka",
#     "venue_name": "Jackie Robinson Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "90024",
#     "venue_url": "unknown",
#     "venue_latitude": "34.065701000",
#     "venue_longitude": "-118.436996000",
#     "segment": "Sports",
#     "segment_id": "KZFzniwnSyZfZ7v7nE",
#     "genre": "Miscellaneous",
#     "genre_id": "KnvZfZ7vA7A",
#     "subgenre": "Miscellaneous",
#     "subgenre_id": "KZazBEonSMnZfZ7vFIt",
#     "image_url": "https://s1.ticketm.net/dam/a/60f/4e8e8937-236c-49d3-bc03-19af5bb0b60f_RETINA_PORTRAIT_16_9.jpg",
#     "attractions": "UCLA Bruins Baseball, Northwestern Wildcats Baseball",
#     "attraction_ids": "K8vZ917GrHf, K8vZ917CATV",
#     "on_sale_date": "1900-01-01T06:00:00Z",
#     "off_sale_date": "2025-05-16T01:00:00Z",
#     "type": NaN,
#     "type_id": NaN,
#     "subtype": NaN,
#     "subtype_id": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "Z7r9jZ1A7u-o0",
#     "name": "Los Angeles Dodgers vs. Athletics",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7u-o0",
#     "status": "onsale",
#     "start_date": "2025-05-15",
#     "start_time": "19:10:00",
#     "venue_id": "Z6r9jZAFke",
#     "venue_name": "Dodger Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "90012",
#     "venue_url": "unknown",
#     "venue_latitude": "34.065800000",
#     "venue_longitude": "-118.238800000",
#     "segment": "Sports",
#     "segment_id": "KZFzniwnSyZfZ7v7nE",
#     "genre": "Baseball",
#     "genre_id": "KnvZfZ7vAdv",
#     "subgenre": "MLB",
#     "subgenre_id": "KZazBEonSMnZfZ7vF1n",
#     "image_url": "https://s1.ticketm.net/dam/a/1fb/ad221c4e-06a0-4acb-80a1-082c5d8861fb_SOURCE",
#     "attractions": "Los Angeles Dodgers, Athletics",
#     "attraction_ids": "K8vZ9171oA0, K8vZ9171o60",
#     "on_sale_date": "1900-01-01T18:00:00Z",
#     "off_sale_date": "2025-05-16T02:10:00Z",
#     "type": NaN,
#     "type_id": NaN,
#     "subtype": NaN,
#     "subtype_id": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "Z7r9jZ1A7fef6",
#     "name": "UCLA Bruins Baseball vs. Northwestern Wildcats Baseball",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7fef6",
#     "status": "onsale",
#     "start_date": "2025-05-16",
#     "start_time": "18:00:00",
#     "venue_id": "ZFr9jZFaka",
#     "venue_name": "Jackie Robinson Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "90024",
#     "venue_url": "unknown",
#     "venue_latitude": "34.065701000",
#     "venue_longitude": "-118.436996000",
#     "segment": "Sports",
#     "segment_id": "KZFzniwnSyZfZ7v7nE",
#     "genre": "Miscellaneous",
#     "genre_id": "KnvZfZ7vA7A",
#     "subgenre": "Miscellaneous",
#     "subgenre_id": "KZazBEonSMnZfZ7vFIt",
#     "image_url": "https://s1.ticketm.net/dam/a/60f/4e8e8937-236c-49d3-bc03-19af5bb0b60f_RETINA_PORTRAIT_16_9.jpg",
#     "attractions": "UCLA Bruins Baseball, Northwestern Wildcats Baseball",
#     "attraction_ids": "K8vZ917GrHf, K8vZ917CATV",
#     "on_sale_date": "1900-01-01T06:00:00Z",
#     "off_sale_date": "2025-05-17T01:00:00Z",
#     "type": NaN,
#     "type_id": NaN,
#     "subtype": NaN,
#     "subtype_id": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "Z7r9jZ1A7u-f7",
#     "name": "Los Angeles Dodgers vs. Los Angeles Angels",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7u-f7",
#     "status": "onsale",
#     "start_date": "2025-05-16",
#     "start_time": "19:10:00",
#     "venue_id": "Z6r9jZAFke",
#     "venue_name": "Dodger Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "90012",
#     "venue_url": "unknown",
#     "venue_latitude": "34.065800000",
#     "venue_longitude": "-118.238800000",
#     "segment": "Sports",
#     "segment_id": "KZFzniwnSyZfZ7v7nE",
#     "genre": "Baseball",
#     "genre_id": "KnvZfZ7vAdv",
#     "subgenre": "MLB",
#     "subgenre_id": "KZazBEonSMnZfZ7vF1n",
#     "image_url": "https://s1.ticketm.net/dam/a/1fb/ad221c4e-06a0-4acb-80a1-082c5d8861fb_SOURCE",
#     "attractions": "Los Angeles Dodgers, Los Angeles Angels",
#     "attraction_ids": "K8vZ9171oA0, K8vZ91718D0",
#     "on_sale_date": "1900-01-01T18:00:00Z",
#     "off_sale_date": "2025-05-17T02:10:00Z",
#     "type": NaN,
#     "type_id": NaN,
#     "subtype": NaN,
#     "subtype_id": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "Z7r9jZ1A7fef7",
#     "name": "UCLA Bruins Baseball vs. Northwestern Wildcats Baseball",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7fef7",
#     "status": "onsale",
#     "start_date": "2025-05-17",
#     "start_time": "13:00:00",
#     "venue_id": "ZFr9jZFaka",
#     "venue_name": "Jackie Robinson Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "90024",
#     "venue_url": "unknown",
#     "venue_latitude": "34.065701000",
#     "venue_longitude": "-118.436996000",
#     "segment": "Sports",
#     "segment_id": "KZFzniwnSyZfZ7v7nE",
#     "genre": "Miscellaneous",
#     "genre_id": "KnvZfZ7vA7A",
#     "subgenre": "Miscellaneous",
#     "subgenre_id": "KZazBEonSMnZfZ7vFIt",
#     "image_url": "https://s1.ticketm.net/dam/a/60f/4e8e8937-236c-49d3-bc03-19af5bb0b60f_RETINA_PORTRAIT_16_9.jpg",
#     "attractions": "UCLA Bruins Baseball, Northwestern Wildcats Baseball",
#     "attraction_ids": "K8vZ917GrHf, K8vZ917CATV",
#     "on_sale_date": "1900-01-01T06:00:00Z",
#     "off_sale_date": "2025-05-17T20:00:00Z",
#     "type": NaN,
#     "type_id": NaN,
#     "subtype": NaN,
#     "subtype_id": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "vvG1IZbIr1t-3p",
#     "name": "Cl\u00e1sico Femenil: Chivas vs Club America",
#     "url": "https://www.ticketmaster.com/clasico-femenil-chivas-vs-club-america-los-angeles-california-05-17-2025/event/0A0062878AA61496",
#     "status": "onsale",
#     "start_date": "2025-05-17",
#     "start_time": "17:30:00",
#     "venue_id": "KovZ917A3c0",
#     "venue_name": "BMO Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "90037",
#     "venue_url": "https://www.ticketmaster.com/bmo-stadium-tickets-los-angeles/venue/82799",
#     "venue_latitude": "34.01287900",
#     "venue_longitude": "-118.28492600",
#     "segment": "Sports",
#     "segment_id": "KZFzniwnSyZfZ7v7nE",
#     "genre": "Soccer",
#     "genre_id": "KnvZfZ7vA7E",
#     "subgenre": "Soccer",
#     "subgenre_id": "KZazBEonSMnZfZ7vFtt",
#     "image_url": "https://s1.ticketm.net/dam/c/f9a/3c3c0a9d-033f-47b3-9621-7b554d80df9a_106241_RETINA_PORTRAIT_16_9.jpg",
#     "attractions": "C.D. Guadalajara Femenil, Club Am\u00e9rica Femenil",
#     "attraction_ids": "K8vZ917rAxV, K8vZ917hGmV",
#     "on_sale_date": "2025-04-10T17:00:00Z",
#     "off_sale_date": "2025-05-18T02:30:00Z",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "presale_name": "Venue Presale",
#     "presale_start_date": "2025-04-09T17:00:00Z",
#     "presale_end_date": "2025-04-10T05:00:00Z"
#   },
#   {
#     "id": "Z7r9jZ1A7u-fA",
#     "name": "Los Angeles Dodgers vs. Los Angeles Angels",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7u-fA",
#     "status": "onsale",
#     "start_date": "2025-05-17",
#     "start_time": "18:10:00",
#     "venue_id": "Z6r9jZAFke",
#     "venue_name": "Dodger Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "90012",
#     "venue_url": "unknown",
#     "venue_latitude": "34.065800000",
#     "venue_longitude": "-118.238800000",
#     "segment": "Sports",
#     "segment_id": "KZFzniwnSyZfZ7v7nE",
#     "genre": "Baseball",
#     "genre_id": "KnvZfZ7vAdv",
#     "subgenre": "MLB",
#     "subgenre_id": "KZazBEonSMnZfZ7vF1n",
#     "image_url": "https://s1.ticketm.net/dam/a/1fb/ad221c4e-06a0-4acb-80a1-082c5d8861fb_SOURCE",
#     "attractions": "Los Angeles Dodgers, Los Angeles Angels",
#     "attraction_ids": "K8vZ9171oA0, K8vZ91718D0",
#     "on_sale_date": "1900-01-01T18:00:00Z",
#     "off_sale_date": "2025-05-18T01:10:00Z",
#     "type": NaN,
#     "type_id": NaN,
#     "subtype": NaN,
#     "subtype_id": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "Z7r9jZ1A7u-fk",
#     "name": "Los Angeles Dodgers vs. Los Angeles Angels",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7u-fk",
#     "status": "onsale",
#     "start_date": "2025-05-18",
#     "start_time": "13:10:00",
#     "venue_id": "Z6r9jZAFke",
#     "venue_name": "Dodger Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "90012",
#     "venue_url": "unknown",
#     "venue_latitude": "34.065800000",
#     "venue_longitude": "-118.238800000",
#     "segment": "Sports",
#     "segment_id": "KZFzniwnSyZfZ7v7nE",
#     "genre": "Baseball",
#     "genre_id": "KnvZfZ7vAdv",
#     "subgenre": "MLB",
#     "subgenre_id": "KZazBEonSMnZfZ7vF1n",
#     "image_url": "https://s1.ticketm.net/dam/a/1fb/ad221c4e-06a0-4acb-80a1-082c5d8861fb_SOURCE",
#     "attractions": "Los Angeles Dodgers, Los Angeles Angels",
#     "attraction_ids": "K8vZ9171oA0, K8vZ91718D0",
#     "on_sale_date": "1900-01-01T18:00:00Z",
#     "off_sale_date": "2025-05-18T20:10:00Z",
#     "type": NaN,
#     "type_id": NaN,
#     "subtype": NaN,
#     "subtype_id": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "Z7r9jZ1A7oPxA",
#     "name": "Los Angeles Sparks vs. Minnesota Lynx",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7oPxA",
#     "status": "onsale",
#     "start_date": "2025-05-18",
#     "start_time": "15:00:00",
#     "venue_id": "ZFr9jZe6vA",
#     "venue_name": "Crypto.com Arena",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "90017",
#     "venue_url": "unknown",
#     "venue_latitude": "34.053101000",
#     "venue_longitude": "-118.264900000",
#     "segment": "Sports",
#     "segment_id": "KZFzniwnSyZfZ7v7nE",
#     "genre": "Basketball",
#     "genre_id": "KnvZfZ7vAde",
#     "subgenre": "WNBA",
#     "subgenre_id": "KZazBEonSMnZfZ7vFJF",
#     "image_url": "https://s1.ticketm.net/dam/a/afd/d95f82e6-a073-4d64-91a8-2c1707c21afd_1701431_RETINA_PORTRAIT_16_9.jpg",
#     "attractions": "Los Angeles Sparks, Minnesota Lynx",
#     "attraction_ids": "K8vZ9171prV, K8vZ9171h3V",
#     "on_sale_date": "1900-01-01T18:00:00Z",
#     "off_sale_date": "2025-05-18T22:00:00Z",
#     "type": NaN,
#     "type_id": NaN,
#     "subtype": NaN,
#     "subtype_id": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "Z7r9jZ1A7u-f6",
#     "name": "Los Angeles Dodgers vs. Arizona Diamondbacks",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7u-f6",
#     "status": "onsale",
#     "start_date": "2025-05-19",
#     "start_time": "19:10:00",
#     "venue_id": "Z6r9jZAFke",
#     "venue_name": "Dodger Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "90012",
#     "venue_url": "unknown",
#     "venue_latitude": "34.065800000",
#     "venue_longitude": "-118.238800000",
#     "segment": "Sports",
#     "segment_id": "KZFzniwnSyZfZ7v7nE",
#     "genre": "Baseball",
#     "genre_id": "KnvZfZ7vAdv",
#     "subgenre": "MLB",
#     "subgenre_id": "KZazBEonSMnZfZ7vF1n",
#     "image_url": "https://s1.ticketm.net/dam/a/1fb/ad221c4e-06a0-4acb-80a1-082c5d8861fb_SOURCE",
#     "attractions": "Los Angeles Dodgers, Arizona Diamondbacks",
#     "attraction_ids": "K8vZ9171oA0, K8vZ9171bp7",
#     "on_sale_date": "1900-01-01T18:00:00Z",
#     "off_sale_date": "2025-05-20T02:10:00Z",
#     "type": NaN,
#     "type_id": NaN,
#     "subtype": NaN,
#     "subtype_id": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "Z7r9jZ1A7u-fF",
#     "name": "Los Angeles Dodgers vs. Arizona Diamondbacks",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7u-fF",
#     "status": "onsale",
#     "start_date": "2025-05-20",
#     "start_time": "19:10:00",
#     "venue_id": "Z6r9jZAFke",
#     "venue_name": "Dodger Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "90012",
#     "venue_url": "unknown",
#     "venue_latitude": "34.065800000",
#     "venue_longitude": "-118.238800000",
#     "segment": "Sports",
#     "segment_id": "KZFzniwnSyZfZ7v7nE",
#     "genre": "Baseball",
#     "genre_id": "KnvZfZ7vAdv",
#     "subgenre": "MLB",
#     "subgenre_id": "KZazBEonSMnZfZ7vF1n",
#     "image_url": "https://s1.ticketm.net/dam/a/1fb/ad221c4e-06a0-4acb-80a1-082c5d8861fb_SOURCE",
#     "attractions": "Los Angeles Dodgers, Arizona Diamondbacks",
#     "attraction_ids": "K8vZ9171oA0, K8vZ9171bp7",
#     "on_sale_date": "1900-01-01T18:00:00Z",
#     "off_sale_date": "2025-05-21T02:10:00Z",
#     "type": NaN,
#     "type_id": NaN,
#     "subtype": NaN,
#     "subtype_id": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "Z7r9jZ1A7u-fa",
#     "name": "Los Angeles Dodgers vs. Arizona Diamondbacks",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7u-fa",
#     "status": "onsale",
#     "start_date": "2025-05-21",
#     "start_time": "19:10:00",
#     "venue_id": "Z6r9jZAFke",
#     "venue_name": "Dodger Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "90012",
#     "venue_url": "unknown",
#     "venue_latitude": "34.065800000",
#     "venue_longitude": "-118.238800000",
#     "segment": "Sports",
#     "segment_id": "KZFzniwnSyZfZ7v7nE",
#     "genre": "Baseball",
#     "genre_id": "KnvZfZ7vAdv",
#     "subgenre": "MLB",
#     "subgenre_id": "KZazBEonSMnZfZ7vF1n",
#     "image_url": "https://s1.ticketm.net/dam/a/1fb/ad221c4e-06a0-4acb-80a1-082c5d8861fb_SOURCE",
#     "attractions": "Los Angeles Dodgers, Arizona Diamondbacks",
#     "attraction_ids": "K8vZ9171oA0, K8vZ9171bp7",
#     "on_sale_date": "1900-01-01T18:00:00Z",
#     "off_sale_date": "2025-05-22T02:10:00Z",
#     "type": NaN,
#     "type_id": NaN,
#     "subtype": NaN,
#     "subtype_id": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "Z7r9jZ1A7oPxe",
#     "name": "Los Angeles Sparks vs. Golden State Valkyries",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7oPxe",
#     "status": "onsale",
#     "start_date": "2025-05-23",
#     "start_time": "19:00:00",
#     "venue_id": "ZFr9jZe6vA",
#     "venue_name": "Crypto.com Arena",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "90017",
#     "venue_url": "unknown",
#     "venue_latitude": "34.053101000",
#     "venue_longitude": "-118.264900000",
#     "segment": "Sports",
#     "segment_id": "KZFzniwnSyZfZ7v7nE",
#     "genre": "Basketball",
#     "genre_id": "KnvZfZ7vAde",
#     "subgenre": "WNBA",
#     "subgenre_id": "KZazBEonSMnZfZ7vFJF",
#     "image_url": "https://s1.ticketm.net/dam/a/afd/d95f82e6-a073-4d64-91a8-2c1707c21afd_1701431_RETINA_PORTRAIT_16_9.jpg",
#     "attractions": "Los Angeles Sparks, Golden State Valkyries",
#     "attraction_ids": "K8vZ9171prV, K8vZ917qxG7",
#     "on_sale_date": "1900-01-01T18:00:00Z",
#     "off_sale_date": "2025-05-24T02:00:00Z",
#     "type": NaN,
#     "type_id": NaN,
#     "subtype": NaN,
#     "subtype_id": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "vvG1IZbNRXHdV9",
#     "name": "Angel City FC vs. Racing Louisville FC",
#     "url": "https://www.ticketmaster.com/angel-city-fc-vs-racing-louisville-los-angeles-california-05-24-2025/event/0A00623BFEF03D17",
#     "status": "onsale",
#     "start_date": "2025-05-24",
#     "start_time": "19:00:00",
#     "venue_id": "KovZ917A3c0",
#     "venue_name": "BMO Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "90037",
#     "venue_url": "https://www.ticketmaster.com/bmo-stadium-tickets-los-angeles/venue/82799",
#     "venue_latitude": "34.01287900",
#     "venue_longitude": "-118.28492600",
#     "segment": "Sports",
#     "segment_id": "KZFzniwnSyZfZ7v7nE",
#     "genre": "Soccer",
#     "genre_id": "KnvZfZ7vA7E",
#     "subgenre": "Soccer",
#     "subgenre_id": "KZazBEonSMnZfZ7vFtt",
#     "image_url": "https://s1.ticketm.net/dam/a/02c/68e12c1f-c3b1-4162-8c89-199cbe72202c_RETINA_PORTRAIT_16_9.jpg",
#     "attractions": "Angel City FC, Racing Louisville FC",
#     "attraction_ids": "K8vZ917_Fd7, K8vZ917_pjV",
#     "on_sale_date": NaN,
#     "off_sale_date": NaN,
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "vvG1IZbthbMf-C",
#     "name": "Angel City FC vs. Racing Louisville FC - Suites",
#     "url": "https://www.gofevo.com/event/ACSUITELOU",
#     "status": "onsale",
#     "start_date": "2025-05-24",
#     "start_time": "19:00:00",
#     "venue_id": "KovZ917A3c0",
#     "venue_name": "BMO Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "90037",
#     "venue_url": "https://www.ticketmaster.com/bmo-stadium-tickets-los-angeles/venue/82799",
#     "venue_latitude": "34.01287900",
#     "venue_longitude": "-118.28492600",
# ...
#     "status": "onsale",
#     "start_date": "2025-06-29",
#     "start_time": "13:00:00",
#     "venue_id": "ZFr9jZe6vA",
#     "venue_name": "Crypto.com Arena",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "90017",
#     "venue_url": "unknown",
#     "venue_latitude": "34.053101000",
#     "venue_longitude": "-118.264900000",
#     "segment": "Sports",
#     "segment_id": "KZFzniwnSyZfZ7v7nE",
#     "genre": "Basketball",
#     "genre_id": "KnvZfZ7vAde",
#     "subgenre": "WNBA",
#     "subgenre_id": "KZazBEonSMnZfZ7vFJF",
#     "image_url": "https://s1.ticketm.net/dam/a/afd/d95f82e6-a073-4d64-91a8-2c1707c21afd_1701431_RETINA_PORTRAIT_16_9.jpg",
#     "attractions": "Los Angeles Sparks, Chicago Sky",
#     "attraction_ids": "K8vZ9171prV, K8vZ9175zE0",
#     "on_sale_date": "1900-01-01T18:00:00Z",
#     "off_sale_date": "2025-06-29T20:00:00Z",
#     "type": NaN,
#     "type_id": NaN,
#     "subtype": NaN,
#     "subtype_id": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "Z7r9jZ1A7u-fE",
#     "name": "Los Angeles Dodgers vs. Chicago White Sox",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7u-fE",
#     "status": "onsale",
#     "start_date": "2025-07-01",
#     "start_time": "19:10:00",
#     "venue_id": "Z6r9jZAFke",
#     "venue_name": "Dodger Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "90012",
#     "venue_url": "unknown",
#     "venue_latitude": "34.065800000",
#     "venue_longitude": "-118.238800000",
#     "segment": "Sports",
#     "segment_id": "KZFzniwnSyZfZ7v7nE",
#     "genre": "Baseball",
#     "genre_id": "KnvZfZ7vAdv",
#     "subgenre": "MLB",
#     "subgenre_id": "KZazBEonSMnZfZ7vF1n",
#     "image_url": "https://s1.ticketm.net/dam/a/1fb/ad221c4e-06a0-4acb-80a1-082c5d8861fb_SOURCE",
#     "attractions": "Los Angeles Dodgers, Chicago White Sox",
#     "attraction_ids": "K8vZ9171oA0, K8vZ9171ok0",
#     "on_sale_date": "1900-01-01T18:00:00Z",
#     "off_sale_date": "2025-07-02T02:10:00Z",
#     "type": NaN,
#     "type_id": NaN,
#     "subtype": NaN,
#     "subtype_id": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "Z7r9jZ1A7u-fI",
#     "name": "Los Angeles Dodgers vs. Chicago White Sox",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7u-fI",
#     "status": "onsale",
#     "start_date": "2025-07-02",
#     "start_time": "19:10:00",
#     "venue_id": "Z6r9jZAFke",
#     "venue_name": "Dodger Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "90012",
#     "venue_url": "unknown",
#     "venue_latitude": "34.065800000",
#     "venue_longitude": "-118.238800000",
#     "segment": "Sports",
#     "segment_id": "KZFzniwnSyZfZ7v7nE",
#     "genre": "Baseball",
#     "genre_id": "KnvZfZ7vAdv",
#     "subgenre": "MLB",
#     "subgenre_id": "KZazBEonSMnZfZ7vF1n",
#     "image_url": "https://s1.ticketm.net/dam/a/1fb/ad221c4e-06a0-4acb-80a1-082c5d8861fb_SOURCE",
#     "attractions": "Los Angeles Dodgers, Chicago White Sox",
#     "attraction_ids": "K8vZ9171oA0, K8vZ9171ok0",
#     "on_sale_date": "1900-01-01T18:00:00Z",
#     "off_sale_date": "2025-07-03T02:10:00Z",
#     "type": NaN,
#     "type_id": NaN,
#     "subtype": NaN,
#     "subtype_id": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "Z7r9jZ1A7u-ft",
#     "name": "Los Angeles Dodgers vs. Chicago White Sox",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7u-ft",
#     "status": "onsale",
#     "start_date": "2025-07-03",
#     "start_time": "19:10:00",
#     "venue_id": "Z6r9jZAFke",
#     "venue_name": "Dodger Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "90012",
#     "venue_url": "unknown",
#     "venue_latitude": "34.065800000",
#     "venue_longitude": "-118.238800000",
#     "segment": "Sports",
#     "segment_id": "KZFzniwnSyZfZ7v7nE",
#     "genre": "Baseball",
#     "genre_id": "KnvZfZ7vAdv",
#     "subgenre": "MLB",
#     "subgenre_id": "KZazBEonSMnZfZ7vF1n",
#     "image_url": "https://s1.ticketm.net/dam/a/1fb/ad221c4e-06a0-4acb-80a1-082c5d8861fb_SOURCE",
#     "attractions": "Los Angeles Dodgers, Chicago White Sox",
#     "attraction_ids": "K8vZ9171oA0, K8vZ9171ok0",
#     "on_sale_date": "1900-01-01T18:00:00Z",
#     "off_sale_date": "2025-07-04T02:10:00Z",
#     "type": NaN,
#     "type_id": NaN,
#     "subtype": NaN,
#     "subtype_id": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "Z7r9jZ1A7u-fY",
#     "name": "Los Angeles Dodgers vs. Houston Astros",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7u-fY",
#     "status": "onsale",
#     "start_date": "2025-07-04",
#     "start_time": "18:10:00",
#     "venue_id": "Z6r9jZAFke",
#     "venue_name": "Dodger Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "90012",
#     "venue_url": "unknown",
#     "venue_latitude": "34.065800000",
#     "venue_longitude": "-118.238800000",
#     "segment": "Sports",
#     "segment_id": "KZFzniwnSyZfZ7v7nE",
#     "genre": "Baseball",
#     "genre_id": "KnvZfZ7vAdv",
#     "subgenre": "MLB",
#     "subgenre_id": "KZazBEonSMnZfZ7vF1n",
#     "image_url": "https://s1.ticketm.net/dam/a/1fb/ad221c4e-06a0-4acb-80a1-082c5d8861fb_SOURCE",
#     "attractions": "Los Angeles Dodgers, Houston Astros",
#     "attraction_ids": "K8vZ9171oA0, K8vZ91718zV",
#     "on_sale_date": "1900-01-01T18:00:00Z",
#     "off_sale_date": "2025-07-05T01:10:00Z",
#     "type": NaN,
#     "type_id": NaN,
#     "subtype": NaN,
#     "subtype_id": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "Z7r9jZ1A7u-fs",
#     "name": "Los Angeles Dodgers vs. Houston Astros",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7u-fs",
#     "status": "onsale",
#     "start_date": "2025-07-05",
#     "start_time": "16:15:00",
#     "venue_id": "Z6r9jZAFke",
#     "venue_name": "Dodger Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "90012",
#     "venue_url": "unknown",
#     "venue_latitude": "34.065800000",
#     "venue_longitude": "-118.238800000",
#     "segment": "Sports",
#     "segment_id": "KZFzniwnSyZfZ7v7nE",
#     "genre": "Baseball",
#     "genre_id": "KnvZfZ7vAdv",
#     "subgenre": "MLB",
#     "subgenre_id": "KZazBEonSMnZfZ7vF1n",
#     "image_url": "https://s1.ticketm.net/dam/a/1fb/ad221c4e-06a0-4acb-80a1-082c5d8861fb_SOURCE",
#     "attractions": "Los Angeles Dodgers, Houston Astros",
#     "attraction_ids": "K8vZ9171oA0, K8vZ91718zV",
#     "on_sale_date": "1900-01-01T18:00:00Z",
#     "off_sale_date": "2025-07-05T23:15:00Z",
#     "type": NaN,
#     "type_id": NaN,
#     "subtype": NaN,
#     "subtype_id": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "Z7r9jZ1A7u-fw",
#     "name": "Los Angeles Dodgers vs. Houston Astros",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7u-fw",
#     "status": "onsale",
#     "start_date": "2025-07-06",
#     "start_time": "13:10:00",
#     "venue_id": "Z6r9jZAFke",
#     "venue_name": "Dodger Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "90012",
#     "venue_url": "unknown",
#     "venue_latitude": "34.065800000",
#     "venue_longitude": "-118.238800000",
#     "segment": "Sports",
#     "segment_id": "KZFzniwnSyZfZ7v7nE",
#     "genre": "Baseball",
#     "genre_id": "KnvZfZ7vAdv",
#     "subgenre": "MLB",
#     "subgenre_id": "KZazBEonSMnZfZ7vF1n",
#     "image_url": "https://s1.ticketm.net/dam/a/1fb/ad221c4e-06a0-4acb-80a1-082c5d8861fb_SOURCE",
#     "attractions": "Los Angeles Dodgers, Houston Astros",
#     "attraction_ids": "K8vZ9171oA0, K8vZ91718zV",
#     "on_sale_date": "1900-01-01T18:00:00Z",
#     "off_sale_date": "2025-07-06T20:10:00Z",
#     "type": NaN,
#     "type_id": NaN,
#     "subtype": NaN,
#     "subtype_id": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "Z7r9jZ1A7oP-V",
#     "name": "Los Angeles Sparks vs. Minnesota Lynx",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7oP-V",
#     "status": "onsale",
#     "start_date": "2025-07-10",
#     "start_time": "12:00:00",
#     "venue_id": "ZFr9jZe6vA",
#     "venue_name": "Crypto.com Arena",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "90017",
#     "venue_url": "unknown",
#     "venue_latitude": "34.053101000",
#     "venue_longitude": "-118.264900000",
#     "segment": "Sports",
#     "segment_id": "KZFzniwnSyZfZ7v7nE",
#     "genre": "Basketball",
#     "genre_id": "KnvZfZ7vAde",
#     "subgenre": "WNBA",
#     "subgenre_id": "KZazBEonSMnZfZ7vFJF",
#     "image_url": "https://s1.ticketm.net/dam/a/afd/d95f82e6-a073-4d64-91a8-2c1707c21afd_1701431_RETINA_PORTRAIT_16_9.jpg",
#     "attractions": "Los Angeles Sparks, Minnesota Lynx",
#     "attraction_ids": "K8vZ9171prV, K8vZ9171h3V",
#     "on_sale_date": "1900-01-01T18:00:00Z",
#     "off_sale_date": "2025-07-10T19:00:00Z",
#     "type": NaN,
#     "type_id": NaN,
#     "subtype": NaN,
#     "subtype_id": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "vvG1IZb_FehSWn",
#     "name": "Los Angeles Football Club vs. FC Dallas",
#     "url": "https://www.ticketmaster.com/los-angeles-football-club-vs-fc-los-angeles-california-07-12-2025/event/0A006192026F3F6A",
#     "status": "onsale",
#     "start_date": "2025-07-12",
#     "start_time": "19:30:00",
#     "venue_id": "KovZ917A3c0",
#     "venue_name": "BMO Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "90037",
#     "venue_url": "https://www.ticketmaster.com/bmo-stadium-tickets-los-angeles/venue/82799",
#     "venue_latitude": "34.01287900",
#     "venue_longitude": "-118.28492600",
#     "segment": "Sports",
#     "segment_id": "KZFzniwnSyZfZ7v7nE",
#     "genre": "Soccer",
#     "genre_id": "KnvZfZ7vA7E",
#     "subgenre": "MLS",
#     "subgenre_id": "KZazBEonSMnZfZ7vFtI",
#     "image_url": "https://s1.ticketm.net/dam/a/7fc/9b98825d-88b7-4a8e-8d6c-799c83ae77fc_SOURCE",
#     "attractions": "Los Angeles Football Club, FC Dallas",
#     "attraction_ids": "K8vZ917p0D0, K8vZ9171paV",
#     "on_sale_date": NaN,
#     "off_sale_date": NaN,
#     "type": "Group",
#     "type_id": "KZAyXgnZfZ7v7l1",
#     "subtype": "Team",
#     "subtype_id": "KZFzBErXgnZfZ7vA7d",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "Z7r9jZ1A7oP-y",
#     "name": "Los Angeles Sparks vs. Connecticut Sun",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7oP-y",
#     "status": "onsale",
#     "start_date": "2025-07-13",
#     "start_time": "15:00:00",
#     "venue_id": "ZFr9jZe6vA",
#     "venue_name": "Crypto.com Arena",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "90017",
#     "venue_url": "unknown",
#     "venue_latitude": "34.053101000",
#     "venue_longitude": "-118.264900000",
#     "segment": "Sports",
#     "segment_id": "KZFzniwnSyZfZ7v7nE",
#     "genre": "Basketball",
#     "genre_id": "KnvZfZ7vAde",
#     "subgenre": "WNBA",
#     "subgenre_id": "KZazBEonSMnZfZ7vFJF",
#     "image_url": "https://s1.ticketm.net/dam/a/afd/d95f82e6-a073-4d64-91a8-2c1707c21afd_1701431_RETINA_PORTRAIT_16_9.jpg",
#     "attractions": "Los Angeles Sparks, Connecticut Sun",
#     "attraction_ids": "K8vZ9171prV, K8vZ91754g0",
#     "on_sale_date": "1900-01-01T18:00:00Z",
#     "off_sale_date": "2025-07-13T22:00:00Z",
#     "type": NaN,
#     "type_id": NaN,
#     "subtype": NaN,
#     "subtype_id": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "Z7r9jZ1A7oP-t",
#     "name": "Los Angeles Sparks vs. Washington Mystics",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7oP-t",
#     "status": "onsale",
#     "start_date": "2025-07-15",
#     "start_time": "19:00:00",
#     "venue_id": "ZFr9jZe6vA",
#     "venue_name": "Crypto.com Arena",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "90017",
#     "venue_url": "unknown",
#     "venue_latitude": "34.053101000",
#     "venue_longitude": "-118.264900000",
#     "segment": "Sports",
#     "segment_id": "KZFzniwnSyZfZ7v7nE",
#     "genre": "Basketball",
#     "genre_id": "KnvZfZ7vAde",
#     "subgenre": "WNBA",
#     "subgenre_id": "KZazBEonSMnZfZ7vFJF",
#     "image_url": "https://s1.ticketm.net/dam/a/afd/d95f82e6-a073-4d64-91a8-2c1707c21afd_1701431_RETINA_PORTRAIT_16_9.jpg",
#     "attractions": "Los Angeles Sparks, Washington Mystics",
#     "attraction_ids": "K8vZ9171prV, K8vZ9171hKf",
#     "on_sale_date": "1900-01-01T18:00:00Z",
#     "off_sale_date": "2025-07-16T02:00:00Z",
#     "type": NaN,
#     "type_id": NaN,
#     "subtype": NaN,
#     "subtype_id": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "Z7r9jZ1A7u-fS",
#     "name": "Los Angeles Dodgers vs. Milwaukee Brewers",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7u-fS",
#     "status": "onsale",
#     "start_date": "2025-07-18",
#     "start_time": "19:10:00",
#     "venue_id": "Z6r9jZAFke",
#     "venue_name": "Dodger Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "90012",
#     "venue_url": "unknown",
#     "venue_latitude": "34.065800000",
#     "venue_longitude": "-118.238800000",
#     "segment": "Sports",
#     "segment_id": "KZFzniwnSyZfZ7v7nE",
#     "genre": "Baseball",
#     "genre_id": "KnvZfZ7vAdv",
#     "subgenre": "MLB",
#     "subgenre_id": "KZazBEonSMnZfZ7vF1n",
#     "image_url": "https://s1.ticketm.net/dam/a/1fb/ad221c4e-06a0-4acb-80a1-082c5d8861fb_SOURCE",
#     "attractions": "Los Angeles Dodgers, Milwaukee Brewers",
#     "attraction_ids": "K8vZ9171oA0, K8vZ91718H7",
#     "on_sale_date": "1900-01-01T18:00:00Z",
#     "off_sale_date": "2025-07-19T02:10:00Z",
#     "type": NaN,
#     "type_id": NaN,
#     "subtype": NaN,
#     "subtype_id": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   },
#   {
#     "id": "Z7r9jZ1A7u-fV",
#     "name": "Los Angeles Dodgers vs. Milwaukee Brewers",
#     "url": "https://www.ticketmaster.com/event/Z7r9jZ1A7u-fV",
#     "status": "onsale",
#     "start_date": "2025-07-19",
#     "start_time": "18:10:00",
#     "venue_id": "Z6r9jZAFke",
#     "venue_name": "Dodger Stadium",
#     "venue_city": "Los Angeles",
#     "venue_state": "California",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "90012",
#     "venue_url": "unknown",
#     "venue_latitude": "34.065800000",
#     "venue_longitude": "-118.238800000",
#     "segment": "Sports",
#     "segment_id": "KZFzniwnSyZfZ7v7nE",
#     "genre": "Baseball",
#     "genre_id": "KnvZfZ7vAdv",
#     "subgenre": "MLB",
#     "subgenre_id": "KZazBEonSMnZfZ7vF1n",
#     "image_url": "https://s1.ticketm.net/dam/a/1fb/ad221c4e-06a0-4acb-80a1-082c5d8861fb_SOURCE",
#     "attractions": "Los Angeles Dodgers, Milwaukee Brewers",
#     "attraction_ids": "K8vZ9171oA0, K8vZ91718H7",
#     "on_sale_date": "1900-01-01T18:00:00Z",
#     "off_sale_date": "2025-07-20T01:10:00Z",
#     "type": NaN,
#     "type_id": NaN,
#     "subtype": NaN,
#     "subtype_id": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN
#   }
# ]
# Saved CSV to la_sports_events_20250513_204451.csv
# Saved JSON to la_sports_events_20250513_204451.json
# Saved Excel to la_sports_events_20250513_204451.xlsx

# %% [markdown]
# # fetch all available event details

# %%
from google.colab import userdata

import requests
import pandas as pd
import json
from datetime import datetime
from IPython.display import display, HTML

api_key = userdata.get('TICKETMASTER_API_KEY')
base_url = "https://app.ticketmaster.com/discovery/v2/events.json"

def fetch_events(
    # Basic parameters
    country_code=None,
    size=20,
    page=0,
    sort="date,asc",

    # Identification parameters
    id=None,
    keyword=None,
    attraction_id=None,
    venue_id=None,

    # Geographic parameters
    city=None,
    state_code=None,
    postal_code=None,
    latlong=None,
    geo_point=None,
    radius=None,
    unit="miles",
    dma_id=None,

    # Date and time parameters
    start_date_time=None,
    end_date_time=None,
    local_start_date_time=None,
    local_start_end_date_time=None,
    start_end_date_time=None,

    # Classification parameters
    classification_name=None,
    classification_id=None,
    segment_id=None,
    segment_name=None,
    genre_id=None,
    sub_genre_id=None,
    type_id=None,
    sub_type_id=None,

    # Sale parameters
    onsale_start_date_time=None,
    onsale_end_date_time=None,
    onsale_on_start_date=None,
    onsale_on_after_start_date=None,
    pre_sale_date_time=None,
    public_visibility_start_date_time=None,

    # Include/exclude parameters
    include_tba="yes",
    include_tbd="yes",
    include_test="no",
    include_family="yes",
    include_spellcheck="no",

    # Other filtering parameters
    market_id=None,
    promoter_id=None,
    collection_id=None,
    source=None,
    locale="en",
    domain=None,
    preferred_country="us"
):
    # Define parameters dict with base parameters
    params = {
        'apikey': api_key,
        'size': size,
        'page': page,
        'sort': sort,
        'includeTBA': include_tba,
        'includeTBD': include_tbd,
        'includeTest': include_test,
        'includeFamily': include_family,
        'includeSpellcheck': include_spellcheck,
        'locale': locale,
        'preferredCountry': preferred_country
    }

    # Helper function to add parameters if they're provided
    def add_param(param_name, value, api_param_name=None):
        if value is not None:
            params[api_param_name or param_name] = value

    # Add identification parameters
    add_param('id', id)
    add_param('keyword', keyword)
    add_param('attractionId', attraction_id)
    add_param('venueId', venue_id)

    # Add geographic parameters
    add_param('countryCode', country_code)
    add_param('city', city)
    add_param('stateCode', state_code)
    add_param('postalCode', postal_code)
    add_param('latlong', latlong)
    add_param('geoPoint', geo_point)
    add_param('radius', radius)
    add_param('unit', unit)
    add_param('dmaId', dma_id)

    # Add date/time parameters
    add_param('startDateTime', start_date_time)
    add_param('endDateTime', end_date_time)
    add_param('localStartDateTime', local_start_date_time)
    add_param('localStartEndDateTime', local_start_end_date_time)
    add_param('startEndDateTime', start_end_date_time)

    # Add classification parameters
    add_param('classificationName', classification_name)
    add_param('classificationId', classification_id)
    add_param('segmentId', segment_id)
    add_param('segmentName', segment_name)
    add_param('genreId', genre_id)
    add_param('subGenreId', sub_genre_id)
    add_param('typeId', type_id)
    add_param('subTypeId', sub_type_id)

    # Add sale parameters
    add_param('onsaleStartDateTime', onsale_start_date_time)
    add_param('onsaleEndDateTime', onsale_end_date_time)
    add_param('onsaleOnStartDate', onsale_on_start_date)
    add_param('onsaleOnAfterStartDate', onsale_on_after_start_date)
    add_param('preSaleDateTime', pre_sale_date_time)
    add_param('publicVisibilityStartDateTime', public_visibility_start_date_time)

    # Add other filtering parameters
    add_param('marketId', market_id)
    add_param('promoterId', promoter_id)
    add_param('collectionId', collection_id)
    add_param('source', source)
    add_param('domain', domain)

    # Make the API request
    response = requests.get(base_url, params=params)

    # Check if the request was successful
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error: {response.status_code}")
        print(response.text)
        return None

# Process the events data into structured format
def process_events(events_data):
    if not events_data or '_embedded' not in events_data:
        print("No events found or invalid response")
        return None

    event_list = []

    for event in events_data['_embedded']['events']:
        # Extract basic event info
        event_info = {
            'id': event['id'],
            'name': event['name'],
            #'url': event['url'],
            'status': event['dates']['status']['code'] if 'status' in event['dates'] else 'unknown',
            'start_date': event['dates']['start'].get('localDate', 'unknown'),
            'start_time': event['dates']['start'].get('localTime', 'unknown'),
        }

        # Add end date and time if available
        if 'end' in event['dates']:
            event_info['end_date'] = event['dates']['end'].get('localDate', 'unknown')
            event_info['end_time'] = event['dates']['end'].get('localTime', 'unknown')

        # Calculate duration if possible
        if ('end' in event['dates'] and
            event_info['start_date'] != 'unknown' and event_info['start_time'] != 'unknown' and
            event_info['end_date'] != 'unknown' and event_info['end_time'] != 'unknown'):
            try:
                start_dt = datetime.strptime(f"{event_info['start_date']} {event_info['start_time']}", "%Y-%m-%d %H:%M:%S")
                end_dt = datetime.strptime(f"{event_info['end_date']} {event_info['end_time']}", "%Y-%m-%d %H:%M:%S")
                duration = end_dt - start_dt
                event_info['duration_minutes'] = duration.total_seconds() / 60
            except:
                # Handle cases where time formats might be different
                event_info['duration_minutes'] = 'unknown'

        # Add venue info if available
        if '_embedded' in event and 'venues' in event['_embedded'] and len(event['_embedded']['venues']) > 0:
            venue = event['_embedded']['venues'][0]
            event_info['venue_id'] = venue.get('id', 'unknown')
            event_info['venue_name'] = venue.get('name', 'unknown')
            event_info['venue_city'] = venue.get('city', {}).get('name', 'unknown')
            event_info['venue_state'] = venue.get('state', {}).get('name', 'unknown')
            event_info['venue_country'] = venue.get('country', {}).get('name', 'unknown')
            event_info['venue_postal_code'] = venue.get('postalCode', 'unknown')
            event_info['venue_url'] = venue.get('url', 'unknown')

            # Add venue coordinates if available
            if 'location' in venue:
                event_info['venue_latitude'] = venue['location'].get('latitude', 'unknown')
                event_info['venue_longitude'] = venue['location'].get('longitude', 'unknown')

        # Add price range if available
        if 'priceRanges' in event and len(event['priceRanges']) > 0:
            price_range = event['priceRanges'][0]
            event_info['min_price'] = price_range.get('min', 'unknown')
            event_info['max_price'] = price_range.get('max', 'unknown')
            event_info['currency'] = price_range.get('currency', 'unknown')

        # Add genre/classification if available
        if 'classifications' in event and len(event['classifications']) > 0:
            classification = event['classifications'][0]
            if 'segment' in classification and classification['segment']:
                event_info['segment'] = classification['segment'].get('name', 'unknown')
                event_info['segment_id'] = classification['segment'].get('id', 'unknown')
            if 'genre' in classification and classification['genre']:
                event_info['genre'] = classification['genre'].get('name', 'unknown')
                event_info['genre_id'] = classification['genre'].get('id', 'unknown')
            if 'subGenre' in classification and classification['subGenre']:
                event_info['subgenre'] = classification['subGenre'].get('name', 'unknown')
                event_info['subgenre_id'] = classification['subGenre'].get('id', 'unknown')
            if 'type' in classification and classification['type']:
                event_info['type'] = classification['type'].get('name', 'unknown')
                event_info['type_id'] = classification['type'].get('id', 'unknown')
            if 'subType' in classification and classification['subType']:
                event_info['subtype'] = classification['subType'].get('name', 'unknown')
                event_info['subtype_id'] = classification['subType'].get('id', 'unknown')

        # Add image URLs if available
        if 'images' in event and len(event['images']) > 0:
            # Find standard image
            standard_images = [img for img in event['images'] if img.get('ratio') == '16_9' and img.get('width') > 500]
            if standard_images:
                event_info['image_url'] = standard_images[0]['url']
            else:
                event_info['image_url'] = event['images'][0]['url']  # Fallback to first image

        # Add attractions/performers if available
        if '_embedded' in event and 'attractions' in event['_embedded'] and len(event['_embedded']['attractions']) > 0:
            attractions = []
            attraction_ids = []
            for attraction in event['_embedded']['attractions']:
                attractions.append(attraction.get('name', 'unknown'))
                attraction_ids.append(attraction.get('id', 'unknown'))
            event_info['attractions'] = ', '.join(attractions)
            event_info['attraction_ids'] = ', '.join(attraction_ids)

        # Add ticket info if available
        if 'sales' in event and 'public' in event['sales']:
            sales_public = event['sales']['public']
            if 'startDateTime' in sales_public:
                event_info['on_sale_date'] = sales_public['startDateTime']
            if 'endDateTime' in sales_public:
                event_info['off_sale_date'] = sales_public['endDateTime']

        # Add pre-sale info if available
        if 'sales' in event and 'presales' in event['sales'] and len(event['sales']['presales']) > 0:
            presale = event['sales']['presales'][0]  # Get the first pre-sale info
            event_info['presale_name'] = presale.get('name', 'unknown')
            event_info['presale_start_date'] = presale.get('startDateTime', 'unknown')
            event_info['presale_end_date'] = presale.get('endDateTime', 'unknown')

        event_list.append(event_info)

    # Create DataFrame
    df = pd.DataFrame(event_list)
    return df

# Function to fetch events with pagination
def fetch_all_events(max_pages=5, events_per_page=20, **search_params):
    all_events = []
    total_elements = 0
    total_pages = 0
    pagination_info = {}

    for page in range(max_pages):
        # Update the page parameter
        search_params['page'] = page
        search_params['size'] = events_per_page

        # Fetch the current page
        events_data = fetch_events(**search_params)

        # Check if we have a valid response
        if events_data and '_embedded' in events_data and 'events' in events_data['_embedded']:
            # Get page info
            page_info = events_data.get('page', {})
            current_page = page_info.get('number', page)
            events_per_page_actual = page_info.get('size', events_per_page)
            total_elements = page_info.get('totalElements', 0)
            total_pages = page_info.get('totalPages', 0)

            # Store pagination information (from the first page)
            if page == 0:
                pagination_info = {
                    'events_per_page': events_per_page_actual,
                    'total_events': total_elements,
                    'total_pages': total_pages
                }

                # Print pagination information
                print(f"\n=== PAGINATION INFORMATION ===")
                print(f"Events per page: {events_per_page_actual}")
                print(f"Total events available: {total_elements}")
                print(f"Total pages available: {total_pages}")
                print(f"Maximum pages to fetch: {min(max_pages, total_pages)}")
                print("===============================\n")

            # Process the events and add them to our collection
            page_events = events_data['_embedded']['events']
            all_events.extend(page_events)

            print(f"Fetched page {current_page+1}/{total_pages} ({len(page_events)} events)")

            # Check if we've reached the last page
            if page >= total_pages - 1:
                break
        else:
            print(f"No events found on page {page+1} or error in response")
            break

    # Convert all events to raw format for processing
    raw_events_data = {
        '_embedded': {
            'events': all_events
        },
        'pagination_info': pagination_info
    }

    print(f"Total events fetched: {len(all_events)} out of {total_elements}")
    return raw_events_data

# Function to display results as table and JSON
def display_structured_events(events_data):
    # Process the events
    events_df = process_events(events_data)

    if events_df is not None and not events_df.empty:
        # Display info
        print(f"Found {len(events_df)} events")

        # Display pagination info if available
        if 'pagination_info' in events_data:
            pagination = events_data['pagination_info']
            print("\n=== PAGINATION SUMMARY ===")
            print(f"Events per page: {pagination.get('events_per_page', 'Unknown')}")
            print(f"Total events available: {pagination.get('total_events', 'Unknown')}")
            print(f"Total pages available: {pagination.get('total_pages', 'Unknown')}")
            print("===========================")

        # Display as styled table
        #print("\n=== EVENTS TABLE ===")
        #display(events_df)

        # Convert to JSON format and display
        print("\n=== EVENTS JSON ===")
        events_json = events_df.to_dict(orient='records')
        print(json.dumps(events_json, indent=2))

        # Create results dictionary including pagination info if available
        results = {
            'dataframe': events_df,
            'json': events_json
        }

        if 'pagination_info' in events_data:
            results['pagination'] = events_data['pagination_info']

        return results
    else:
        print("No events to display")
        return None

# Save results to CSV, JSON, or Excel
def save_results(results, format='all', prefix='events'):
    if results is None or 'dataframe' not in results:
        print("No results to save")
        return

    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    df = results['dataframe']

    if format.lower() in ['csv', 'all']:
        filename = f"{prefix}_{timestamp}.csv"
        df.to_csv(filename, index=False)
        print(f"Saved CSV to {filename}")

    if format.lower() in ['json', 'all']:
        filename = f"{prefix}_{timestamp}.json"
        with open(filename, 'w') as f:
            json.dump(results['json'], f, indent=2)
        print(f"Saved JSON to {filename}")

    if format.lower() in ['excel', 'all']:
        filename = f"{prefix}_{timestamp}.xlsx"
        df.to_excel(filename, index=False)
        print(f"Saved Excel to {filename}")

# Example usage
def main():
    # Define your search parameters with more options
    params = {
        'country_code': "US",
        'classification_name': "music",  # Music, Sports, Arts, Film, etc.
        'city': "New York",
        'state_code': "NY",
        'start_date_time': "2025-05-15T00:00:00Z",  # Events after this date
        #'end_date_time': "2025-08-15T23:59:59Z",    # Events before this date
        'sort': "date,asc",                        # Sort by date ascending
        #'include_family': "yes"                    # Include family-friendly events
    }

    # Define pagination parameters
    max_pages = 10     # Maximum number of pages to fetch
    events_per_page = 200  # Number of events per page to request

    # You can control the number of events per page by changing the 'size' parameter
    # The API default is 20, but you can set it up to the API's maximum (usually 50-100)
    params['size'] = 200 # Uncomment to override events_per_page

    # Fetch events with pagination
    #print(f"Fetching {params['classification_name']} events in {params['city']}, {params['state_code']}...")
    #print(f"Time range: {params['start_date_time']} to {params['end_date_time']}")
    #print(f"Pagination settings: max {max_pages} pages, {events_per_page} events per page")

    events_data = fetch_all_events(max_pages=max_pages, events_per_page=events_per_page, **params)

    # Display structured results
    results = display_structured_events(events_data)

    # Save results to files
    save_results(results, format='all', prefix='la_sports_events')

    # Return all the information
    if results and 'pagination' in results:
        print("\n=== PAGINATION SUMMARY ===")
        print(f"Events per page: {results['pagination']['events_per_page']}")
        print(f"Total events available: {results['pagination']['total_events']}")
        print(f"Total pages available: {results['pagination']['total_pages']}")

    return results

# Run the main function
if __name__ == "__main__":
    results = main()
# Out:
# Streaming output truncated to the last 5000 lines.
#     "venue_name": "Blue Note Jazz Club",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10012",
#     "venue_url": "https://www.ticketweb.com/venue/blue-note-jazz-club-new-york-ny/23798",
#     "venue_latitude": "40.730940",
#     "venue_longitude": "-74.000650",
#     "min_price": 38.05,
#     "max_price": 54.94,
#     "currency": "USD",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Jazz Funk",
#     "subgenre_id": "KZazBEonSMnZfZ7vkAa",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/cdf/e5c64e3d-7ded-47a0-98f8-0def24b52cdf_SOURCE",
#     "on_sale_date": "2025-03-20T15:00:00Z",
#     "off_sale_date": "2025-07-09T00:00:00Z",
#     "attractions": "The Dirty Dozen Brass Band",
#     "attraction_ids": "K8vZ91718A0",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfGaON",
#     "name": "David Ostwald's Louis Armstrong Eternity Band",
#     "status": "onsale",
#     "start_date": "2025-07-09",
#     "start_time": "17:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "venue_id": "rZ7HnEZ174KrF",
#     "venue_name": "Birdland Theater",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/birdland-theater-new-york-ny/553788",
#     "venue_latitude": "40.7590167",
#     "venue_longitude": "-73.9896861",
#     "min_price": 35.46,
#     "max_price": 45.76,
#     "currency": "USD",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Jazz",
#     "subgenre_id": "KZazBEonSMnZfZ7vkda",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/bea/03d47f66-d37b-4aca-aa17-0135be64dbea_105801_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "on_sale_date": "2025-03-19T16:20:00Z",
#     "off_sale_date": "2025-07-09T21:30:00Z",
#     "attractions": NaN,
#     "attraction_ids": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "G5vVZb0looobd",
#     "name": "Barenaked Ladies",
#     "status": "onsale",
#     "start_date": "2025-07-09",
#     "start_time": "18:00:00",
#     "end_date": NaN,
#     "end_time": NaN,
#     "venue_id": "KovZ917A_QV",
#     "venue_name": "The Rooftop at Pier 17",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10038",
#     "venue_url": "https://www.ticketmaster.com/the-rooftop-at-pier-17-tickets-new-york/venue/237751",
#     "venue_latitude": "40.7056185",
#     "venue_longitude": "-74.001798",
#     "min_price": NaN,
#     "max_price": NaN,
#     "currency": NaN,
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Rock",
#     "genre_id": "KnvZfZ7vAeA",
#     "subgenre": "Pop",
#     "subgenre_id": "KZazBEonSMnZfZ7v6F1",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/141/a1289678-b04d-4511-a80f-d15f95815141_RETINA_LANDSCAPE_16_9.jpg",
#     "on_sale_date": "2025-02-14T15:00:00Z",
#     "off_sale_date": "2025-07-09T22:00:00Z",
#     "attractions": "Barenaked Ladies",
#     "attraction_ids": "K8vZ91716if",
#     "presale_name": "Live Nation Presale",
#     "presale_start_date": "2025-02-12T17:00:00Z",
#     "presale_end_date": "2025-02-14T03:00:00Z",
#     "duration_minutes": NaN
#   },
#   {
#     "id": "Z7r9jZ1A7ffJK",
#     "name": "Barenaked Ladies",
#     "status": "onsale",
#     "start_date": "2025-07-09",
#     "start_time": "18:00:00",
#     "end_date": NaN,
#     "end_time": NaN,
#     "venue_id": "Z7r9jZadrI",
#     "venue_name": "The Rooftop at Pier 17",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10038",
#     "venue_url": "unknown",
#     "venue_latitude": "40.708801000",
#     "venue_longitude": "-74.002899000",
#     "min_price": NaN,
#     "max_price": NaN,
#     "currency": NaN,
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Alternative",
#     "genre_id": "KnvZfZ7vAvv",
#     "subgenre": "Alternative Rock",
#     "subgenre_id": "KZazBEonSMnZfZ7vAvn",
#     "type": NaN,
#     "type_id": NaN,
#     "subtype": NaN,
#     "subtype_id": NaN,
#     "image_url": "https://s1.ticketm.net/dam/a/141/a1289678-b04d-4511-a80f-d15f95815141_RETINA_LANDSCAPE_16_9.jpg",
#     "on_sale_date": "2025-02-14T15:00:00Z",
#     "off_sale_date": "2025-07-09T22:00:00Z",
#     "attractions": "Barenaked Ladies",
#     "attraction_ids": "K8vZ91716if",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "k7vGFbI5LSIoq",
#     "name": "Kevian Kraemer",
#     "status": "onsale",
#     "start_date": "2025-07-09",
#     "start_time": "18:00:00",
#     "end_date": NaN,
#     "end_time": NaN,
#     "venue_id": "KovZpZAJAkAA",
#     "venue_name": "Mercury Lounge",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10002",
#     "venue_url": "https://www.ticketmaster.com/mercury-lounge-tickets-new-york/venue/1101",
#     "venue_latitude": "40.72203600",
#     "venue_longitude": "-73.98680600",
#     "min_price": NaN,
#     "max_price": NaN,
#     "currency": NaN,
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Pop",
#     "genre_id": "KnvZfZ7vAev",
#     "subgenre": "Pop",
#     "subgenre_id": "KZazBEonSMnZfZ7vk1t",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/e/210/f6a76f7d-4f9d-4b55-959a-73d9b89d7210_TABLET_LANDSCAPE_16_9.jpg",
#     "on_sale_date": "2025-04-10T14:00:00Z",
#     "off_sale_date": "2025-07-10T00:00:00Z",
#     "attractions": "Kevian Kraemer",
#     "attraction_ids": "K8vZ917rAH7",
#     "presale_name": "Citi\u00ae Cardmember Presale",
#     "presale_start_date": "2025-04-08T14:00:00Z",
#     "presale_end_date": "2025-04-10T02:00:00Z",
#     "duration_minutes": NaN
#   },
#   {
#     "id": "k7vGFb9l5cdb4",
#     "name": "The Cat Empire - Bird in Paradise Album Tour",
#     "status": "onsale",
#     "start_date": "2025-07-09",
#     "start_time": "19:00:00",
#     "end_date": NaN,
#     "end_time": NaN,
#     "venue_id": "KovZpaFPje",
#     "venue_name": "Irving Plaza Powered By Verizon 5G",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10003",
#     "venue_url": "https://www.ticketmaster.com/irving-plaza-powered-by-verizon-5g-tickets-new-york/venue/47",
#     "venue_latitude": "40.73491700",
#     "venue_longitude": "-73.98844690",
#     "min_price": NaN,
#     "max_price": NaN,
#     "currency": NaN,
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Rock",
#     "genre_id": "KnvZfZ7vAeA",
#     "subgenre": "Pop",
#     "subgenre_id": "KZazBEonSMnZfZ7v6F1",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/731/d13a1669-4794-4a5a-a7ea-cbde1669b731_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "on_sale_date": "2024-12-05T17:00:00Z",
#     "off_sale_date": "2025-07-10T01:00:00Z",
#     "attractions": "The Cat Empire, The Alternate Routes",
#     "attraction_ids": "K8vZ9175BuV, K8vZ917Gcq0",
#     "presale_name": "Citi\u00ae Cardmember Preferred Tickets",
#     "presale_start_date": "2024-12-05T17:00:00Z",
#     "presale_end_date": "2025-06-12T02:00:00Z",
#     "duration_minutes": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfGa_K",
#     "name": "Anat Cohen Quartetinho",
#     "status": "onsale",
#     "start_date": "2025-07-09",
#     "start_time": "19:00:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "venue_id": "rZ7HnEZ178J7g",
#     "venue_name": "Birdland Jazz Club",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/birdland-jazz-club-new-york-ny/426135",
#     "venue_latitude": "40.7590167",
#     "venue_longitude": "-73.9896861",
#     "min_price": 40.61,
#     "max_price": 50.91,
#     "currency": "USD",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Jazz",
#     "subgenre_id": "KZazBEonSMnZfZ7vkda",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/ad3/32a1c318-ce7e-4787-8653-433be1ddaad3_SOURCE",
#     "on_sale_date": "2025-03-19T18:05:00Z",
#     "off_sale_date": "2025-07-09T23:00:00Z",
#     "attractions": "Anat Cohen",
#     "attraction_ids": "K8vZ917uQLV",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "rZ7HnEZ1Af18FN",
#     "name": "The Dirty Dozen Brass Band",
#     "status": "onsale",
#     "start_date": "2025-07-09",
#     "start_time": "20:00:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "venue_id": "rZ7HnEZaASU",
#     "venue_name": "Blue Note Jazz Club",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10012",
#     "venue_url": "https://www.ticketweb.com/venue/blue-note-jazz-club-new-york-ny/23798",
#     "venue_latitude": "40.730940",
#     "venue_longitude": "-74.000650",
#     "min_price": 38.05,
#     "max_price": 54.94,
#     "currency": "USD",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Jazz Funk",
#     "subgenre_id": "KZazBEonSMnZfZ7vkAa",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/cdf/e5c64e3d-7ded-47a0-98f8-0def24b52cdf_SOURCE",
#     "on_sale_date": "2025-03-20T15:00:00Z",
#     "off_sale_date": "2025-07-09T00:00:00Z",
#     "attractions": "The Dirty Dozen Brass Band",
#     "attraction_ids": "K8vZ91718A0",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfGaxd",
#     "name": "Frank Vignola's Guitar Night",
#     "status": "onsale",
#     "start_date": "2025-07-09",
#     "start_time": "20:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "venue_id": "rZ7HnEZ174KrF",
#     "venue_name": "Birdland Theater",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/birdland-theater-new-york-ny/553788",
#     "venue_latitude": "40.7590167",
#     "venue_longitude": "-73.9896861",
#     "min_price": 35.46,
#     "max_price": 45.76,
#     "currency": "USD",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Jazz",
#     "subgenre_id": "KZazBEonSMnZfZ7vkda",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/bea/03d47f66-d37b-4aca-aa17-0135be64dbea_105801_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "on_sale_date": "2025-03-19T16:20:00Z",
#     "off_sale_date": "2025-07-10T00:30:00Z",
#     "attractions": "Frank Vignola",
#     "attraction_ids": "K8vZ917u_V7",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfGaQd",
#     "name": "Anat Cohen Quartetinho",
#     "status": "onsale",
#     "start_date": "2025-07-09",
#     "start_time": "21:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "venue_id": "rZ7HnEZ178J7g",
#     "venue_name": "Birdland Jazz Club",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/birdland-jazz-club-new-york-ny/426135",
#     "venue_latitude": "40.7590167",
#     "venue_longitude": "-73.9896861",
#     "min_price": 40.61,
#     "max_price": 50.91,
#     "currency": "USD",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Jazz",
#     "subgenre_id": "KZazBEonSMnZfZ7vkda",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/ad3/32a1c318-ce7e-4787-8653-433be1ddaad3_SOURCE",
#     "on_sale_date": "2025-03-19T18:05:00Z",
#     "off_sale_date": "2025-07-10T01:30:00Z",
#     "attractions": "Anat Cohen",
#     "attraction_ids": "K8vZ917uQLV",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "rZ7HnEZ1Af18FK",
#     "name": "The Dirty Dozen Brass Band",
#     "status": "onsale",
#     "start_date": "2025-07-09",
#     "start_time": "22:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "venue_id": "rZ7HnEZaASU",
#     "venue_name": "Blue Note Jazz Club",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10012",
#     "venue_url": "https://www.ticketweb.com/venue/blue-note-jazz-club-new-york-ny/23798",
#     "venue_latitude": "40.730940",
#     "venue_longitude": "-74.000650",
#     "min_price": 38.05,
#     "max_price": 54.94,
#     "currency": "USD",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Jazz Funk",
#     "subgenre_id": "KZazBEonSMnZfZ7vkAa",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/cdf/e5c64e3d-7ded-47a0-98f8-0def24b52cdf_SOURCE",
#     "on_sale_date": "2025-03-20T15:00:00Z",
#     "off_sale_date": "2025-07-09T00:00:00Z",
#     "attractions": "The Dirty Dozen Brass Band",
#     "attraction_ids": "K8vZ91718A0",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfGaPN",
#     "name": "The High Society New Orleans Jazz Band",
#     "status": "onsale",
#     "start_date": "2025-07-10",
#     "start_time": "17:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "venue_id": "rZ7HnEZ174KrF",
#     "venue_name": "Birdland Theater",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/birdland-theater-new-york-ny/553788",
#     "venue_latitude": "40.7590167",
#     "venue_longitude": "-73.9896861",
#     "min_price": 35.46,
#     "max_price": 45.76,
#     "currency": "USD",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Folk",
#     "genre_id": "KnvZfZ7vAva",
#     "subgenre": "Folk Jazz",
#     "subgenre_id": "KZazBEonSMnZfZ7vAl7",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/779/d4bc7e11-1b50-4aa4-a2be-0a21569f5779_106531_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "on_sale_date": "2025-03-19T16:00:00Z",
#     "off_sale_date": "2025-07-10T21:30:00Z",
#     "attractions": NaN,
#     "attraction_ids": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "rZ7HnEZ1Af8-ed",
#     "name": "Sea Lemon, Work Wife",
#     "status": "onsale",
#     "start_date": "2025-07-10",
#     "start_time": "19:00:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "venue_id": "rZ7HnEZ17QkQd",
#     "venue_name": "Night Club 101",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10009",
#     "venue_url": "https://www.ticketweb.com/venue/night-club-101-new-york-ny/686683",
#     "venue_latitude": "40.725911",
#     "venue_longitude": "-73.984043",
#     "min_price": 26.71,
#     "max_price": 26.71,
#     "currency": "USD",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Other",
#     "genre_id": "KnvZfZ7vAvl",
#     "subgenre": NaN,
#     "subgenre_id": NaN,
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/060/c5c08e7a-9912-456c-a060-2758be94e060_105881_TABLET_LANDSCAPE_16_9.jpg",
#     "on_sale_date": "2025-04-29T13:00:00Z",
#     "off_sale_date": "2025-07-11T23:00:00Z",
#     "attractions": NaN,
#     "attraction_ids": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfGaQK",
#     "name": "Anat Cohen Quartetinho",
#     "status": "onsale",
#     "start_date": "2025-07-10",
#     "start_time": "19:00:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "venue_id": "rZ7HnEZ178J7g",
#     "venue_name": "Birdland Jazz Club",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/birdland-jazz-club-new-york-ny/426135",
#     "venue_latitude": "40.7590167",
#     "venue_longitude": "-73.9896861",
#     "min_price": 40.61,
#     "max_price": 50.91,
#     "currency": "USD",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Jazz",
#     "subgenre_id": "KZazBEonSMnZfZ7vkda",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/ad3/32a1c318-ce7e-4787-8653-433be1ddaad3_SOURCE",
#     "on_sale_date": "2025-03-19T18:05:00Z",
#     "off_sale_date": "2025-07-10T23:00:00Z",
#     "attractions": "Anat Cohen",
#     "attraction_ids": "K8vZ917uQLV",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "Z7r9jZ1A7og0K",
#     "name": "Cosmo Sheldrake (16 & Over)",
#     "status": "onsale",
#     "start_date": "2025-07-10",
#     "start_time": "20:00:00",
#     "end_date": NaN,
#     "end_time": NaN,
#     "venue_id": "Z7r9jZa7MU",
#     "venue_name": "Racket NYC",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10011",
#     "venue_url": "unknown",
#     "venue_latitude": "40.740898000",
#     "venue_longitude": "-73.999702000",
#     "min_price": NaN,
#     "max_price": NaN,
#     "currency": NaN,
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Other",
#     "genre_id": "KnvZfZ7vAvl",
#     "subgenre": "Other",
#     "subgenre_id": "KZazBEonSMnZfZ7vk1I",
#     "type": NaN,
#     "type_id": NaN,
#     "subtype": NaN,
#     "subtype_id": NaN,
#     "image_url": "https://s1.ticketm.net/dam/c/060/c5c08e7a-9912-456c-a060-2758be94e060_105881_TABLET_LANDSCAPE_16_9.jpg",
#     "on_sale_date": "1900-01-01T06:00:00Z",
#     "off_sale_date": "2025-07-11T00:00:00Z",
#     "attractions": "Cosmo Sheldrake",
#     "attraction_ids": "Z7r9jZaCfp",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "rZ7HnEZ1Af18FS",
#     "name": "The Dirty Dozen Brass Band",
#     "status": "onsale",
#     "start_date": "2025-07-10",
#     "start_time": "20:00:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "venue_id": "rZ7HnEZaASU",
#     "venue_name": "Blue Note Jazz Club",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10012",
#     "venue_url": "https://www.ticketweb.com/venue/blue-note-jazz-club-new-york-ny/23798",
#     "venue_latitude": "40.730940",
#     "venue_longitude": "-74.000650",
#     "min_price": 38.05,
#     "max_price": 54.94,
#     "currency": "USD",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Jazz Funk",
#     "subgenre_id": "KZazBEonSMnZfZ7vkAa",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/cdf/e5c64e3d-7ded-47a0-98f8-0def24b52cdf_SOURCE",
#     "on_sale_date": "2025-03-20T15:00:00Z",
#     "off_sale_date": "2025-07-09T00:00:00Z",
#     "attractions": "The Dirty Dozen Brass Band",
#     "attraction_ids": "K8vZ91718A0",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "rZ7HnEZ1Afu-rK",
#     "name": "LaMP ft Russ Lawton, Scott Metzger, Ray Paczkowski Concert Cruise",
#     "status": "onsale",
#     "start_date": "2025-07-10",
#     "start_time": "20:00:00",
#     "end_date": "2025-07-10",
#     "end_time": "23:00:00",
#     "venue_id": "rZ7HnEZ178tqA",
#     "venue_name": "The Liberty Belle - Rocks Off Concert Cruise",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10002",
#     "venue_url": "https://www.ticketweb.com/venue/the-liberty-belle--rocks-off-concert-cruise-new-york-ny/429745",
#     "venue_latitude": "40.706355",
#     "venue_longitude": "-73.974563",
#     "min_price": 43.4,
#     "max_price": 43.4,
#     "currency": "USD",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Other",
#     "genre_id": "KnvZfZ7vAvl",
#     "subgenre": NaN,
#     "subgenre_id": NaN,
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/060/c5c08e7a-9912-456c-a060-2758be94e060_105881_TABLET_LANDSCAPE_16_9.jpg",
#     "on_sale_date": "2025-04-11T16:00:00Z",
#     "off_sale_date": "2025-07-10T23:55:00Z",
#     "attractions": NaN,
#     "attraction_ids": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": 180.0
#   },
#   {
#     "id": "rZ7HnEZ1AfG8ZN",
#     "name": "The High Society New Orleans Jazz Band",
#     "status": "onsale",
#     "start_date": "2025-07-10",
#     "start_time": "20:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "venue_id": "rZ7HnEZ174KrF",
#     "venue_name": "Birdland Theater",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/birdland-theater-new-york-ny/553788",
#     "venue_latitude": "40.7590167",
#     "venue_longitude": "-73.9896861",
#     "min_price": 35.46,
#     "max_price": 45.76,
#     "currency": "USD",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Folk",
#     "genre_id": "KnvZfZ7vAva",
#     "subgenre": "Folk Jazz",
#     "subgenre_id": "KZazBEonSMnZfZ7vAl7",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/779/d4bc7e11-1b50-4aa4-a2be-0a21569f5779_106531_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "on_sale_date": "2025-03-19T16:00:00Z",
#     "off_sale_date": "2025-07-11T00:30:00Z",
#     "attractions": NaN,
#     "attraction_ids": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "k7vGFb0lTT4oV",
#     "name": "Winona Fighter",
#     "status": "onsale",
#     "start_date": "2025-07-10",
#     "start_time": "21:00:00",
#     "end_date": NaN,
#     "end_time": NaN,
#     "venue_id": "KovZpZAJAkAA",
#     "venue_name": "Mercury Lounge",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10002",
#     "venue_url": "https://www.ticketmaster.com/mercury-lounge-tickets-new-york/venue/1101",
#     "venue_latitude": "40.72203600",
#     "venue_longitude": "-73.98680600",
#     "min_price": NaN,
#     "max_price": NaN,
#     "currency": NaN,
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Rock",
#     "genre_id": "KnvZfZ7vAeA",
#     "subgenre": "Punk",
#     "subgenre_id": "KZazBEonSMnZfZ7v6a6",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/9d4/67580508-546c-46ba-8b9a-9875811fb9d4_RETINA_LANDSCAPE_16_9.jpg",
#     "on_sale_date": "2025-02-21T15:00:00Z",
#     "off_sale_date": "2025-07-11T03:00:00Z",
#     "attractions": "Winona Fighter, Carissa Johnson & the Cure-Alls",
#     "attraction_ids": "K8vZ917QNwf, K8vZ917bYPV",
#     "presale_name": "Citi\u00ae Cardmember Presale",
#     "presale_start_date": "2025-02-19T15:00:00Z",
#     "presale_end_date": "2025-02-21T03:00:00Z",
#     "duration_minutes": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfGa_N",
#     "name": "Anat Cohen Quartetinho",
#     "status": "onsale",
#     "start_date": "2025-07-10",
#     "start_time": "21:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "venue_id": "rZ7HnEZ178J7g",
#     "venue_name": "Birdland Jazz Club",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/birdland-jazz-club-new-york-ny/426135",
#     "venue_latitude": "40.7590167",
#     "venue_longitude": "-73.9896861",
#     "min_price": 40.61,
#     "max_price": 50.91,
#     "currency": "USD",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Jazz",
#     "subgenre_id": "KZazBEonSMnZfZ7vkda",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/ad3/32a1c318-ce7e-4787-8653-433be1ddaad3_SOURCE",
#     "on_sale_date": "2025-03-19T18:05:00Z",
#     "off_sale_date": "2025-07-11T01:30:00Z",
#     "attractions": "Anat Cohen",
#     "attraction_ids": "K8vZ917uQLV",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfoavS",
#     "name": "The Thing",
#     "status": "onsale",
#     "start_date": "2025-07-10",
#     "start_time": "22:00:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "venue_id": "rZ7HnEZ17QkQd",
#     "venue_name": "Night Club 101",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10009",
#     "venue_url": "https://www.ticketweb.com/venue/night-club-101-new-york-ny/686683",
#     "venue_latitude": "40.725911",
#     "venue_longitude": "-73.984043",
#     "min_price": 16.41,
#     "max_price": 16.41,
#     "currency": "USD",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Rock",
#     "genre_id": "KnvZfZ7vAeA",
#     "subgenre": "Psychedelic",
#     "subgenre_id": "KZazBEonSMnZfZ7v6aA",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/fbc/b293c0ad-c904-4215-bc59-8d7f2414dfbc_106141_RETINA_LANDSCAPE_16_9.jpg",
#     "on_sale_date": "2025-05-07T16:00:00Z",
#     "off_sale_date": "2025-07-11T02:00:00Z",
#     "attractions": NaN,
#     "attraction_ids": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "rZ7HnEZ1Af18Fd",
#     "name": "The Dirty Dozen Brass Band",
#     "status": "onsale",
#     "start_date": "2025-07-10",
#     "start_time": "22:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "venue_id": "rZ7HnEZaASU",
#     "venue_name": "Blue Note Jazz Club",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10012",
#     "venue_url": "https://www.ticketweb.com/venue/blue-note-jazz-club-new-york-ny/23798",
#     "venue_latitude": "40.730940",
#     "venue_longitude": "-74.000650",
#     "min_price": 38.05,
#     "max_price": 54.94,
#     "currency": "USD",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Jazz Funk",
#     "subgenre_id": "KZazBEonSMnZfZ7vkAa",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/cdf/e5c64e3d-7ded-47a0-98f8-0def24b52cdf_SOURCE",
#     "on_sale_date": "2025-03-20T15:00:00Z",
#     "off_sale_date": "2025-07-09T00:00:00Z",
#     "attractions": "The Dirty Dozen Brass Band",
#     "attraction_ids": "K8vZ91718A0",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfG87N",
#     "name": "Birdland Big Band",
#     "status": "onsale",
#     "start_date": "2025-07-11",
#     "start_time": "17:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "venue_id": "rZ7HnEZ178J7g",
#     "venue_name": "Birdland Jazz Club",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/birdland-jazz-club-new-york-ny/426135",
#     "venue_latitude": "40.7590167",
#     "venue_longitude": "-73.9896861",
#     "min_price": 35.46,
#     "max_price": 45.76,
#     "currency": "USD",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Big Band",
#     "subgenre_id": "KZazBEonSMnZfZ7vk7v",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/bea/03d47f66-d37b-4aca-aa17-0135be64dbea_105801_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "on_sale_date": "2025-03-19T16:00:00Z",
#     "off_sale_date": "2025-07-11T21:30:00Z",
#     "attractions": NaN,
#     "attraction_ids": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "G5vVZbEJopv_o",
#     "name": "Michael Franti & Spearhead",
#     "status": "onsale",
#     "start_date": "2025-07-11",
#     "start_time": "18:30:00",
#     "end_date": NaN,
#     "end_time": NaN,
#     "venue_id": "KovZ917A_QV",
#     "venue_name": "The Rooftop at Pier 17",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10038",
#     "venue_url": "https://www.ticketmaster.com/the-rooftop-at-pier-17-tickets-new-york/venue/237751",
#     "venue_latitude": "40.7056185",
#     "venue_longitude": "-74.001798",
#     "min_price": NaN,
#     "max_price": NaN,
#     "currency": NaN,
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Rock",
#     "genre_id": "KnvZfZ7vAeA",
#     "subgenre": "Pop",
#     "subgenre_id": "KZazBEonSMnZfZ7v6F1",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/5e1/316efbbd-c4a3-4e0e-a6d2-5a021d0175e1_RETINA_PORTRAIT_16_9.jpg",
#     "on_sale_date": "2025-03-28T14:00:00Z",
#     "off_sale_date": "2025-07-11T22:30:00Z",
#     "attractions": "Michael Franti & Spearhead",
#     "attraction_ids": "K8vZ917uFQV",
#     "presale_name": "LIVE NATION PRESALE",
#     "presale_start_date": "2025-03-27T14:00:00Z",
#     "presale_end_date": "2025-03-28T02:00:00Z",
#     "duration_minutes": NaN
#   },
#   {
#     "id": "Z7r9jZ1A74afw",
#     "name": "Michael Franti & Spearhead",
#     "status": "onsale",
#     "start_date": "2025-07-11",
#     "start_time": "18:30:00",
#     "end_date": NaN,
#     "end_time": NaN,
#     "venue_id": "Z7r9jZadrI",
#     "venue_name": "The Rooftop at Pier 17",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10038",
#     "venue_url": "unknown",
#     "venue_latitude": "40.708801000",
#     "venue_longitude": "-74.002899000",
#     "min_price": NaN,
#     "max_price": NaN,
#     "currency": NaN,
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "World",
#     "genre_id": "KnvZfZ7vAeF",
#     "subgenre": "World",
#     "subgenre_id": "KZazBEonSMnZfZ7v6Jt",
#     "type": NaN,
#     "type_id": NaN,
#     "subtype": NaN,
#     "subtype_id": NaN,
#     "image_url": "https://s1.ticketm.net/dam/a/5e1/316efbbd-c4a3-4e0e-a6d2-5a021d0175e1_RETINA_PORTRAIT_16_9.jpg",
#     "on_sale_date": "2025-03-28T14:00:00Z",
#     "off_sale_date": "2025-07-11T22:30:00Z",
#     "attractions": "Michael Franti & Spearhead",
#     "attraction_ids": "K8vZ917uFQV",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "k7vGFbt6PUI-e",
#     "name": "Driveways & Capstan",
#     "status": "onsale",
#     "start_date": "2025-07-11",
#     "start_time": "19:00:00",
#     "end_date": NaN,
#     "end_time": NaN,
#     "venue_id": "KovZpZAEAdaA",
#     "venue_name": "Gramercy Theatre",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10010",
#     "venue_url": "https://www.ticketmaster.com/gramercy-theatre-tickets-new-york/venue/107",
#     "venue_latitude": "40.73975368",
#     "venue_longitude": "-73.98501292",
#     "min_price": NaN,
#     "max_price": NaN,
#     "currency": NaN,
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Rock",
#     "genre_id": "KnvZfZ7vAeA",
#     "subgenre": "Alternative Rock",
#     "subgenre_id": "KZazBEonSMnZfZ7v6dt",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/b2d/6b327733-0b09-4a58-9fe5-a05b1efa7b2d_RETINA_LANDSCAPE_16_9.jpg",
#     "on_sale_date": "2025-05-02T14:00:00Z",
#     "off_sale_date": "2025-07-12T01:00:00Z",
#     "attractions": "Driveways, Capstan",
#     "attraction_ids": "K8vZ917hTuf, K8vZ917K-B7",
#     "presale_name": "Live Nation Presale",
#     "presale_start_date": "2025-05-01T14:00:00Z",
#     "presale_end_date": "2025-05-02T02:00:00Z",
#     "duration_minutes": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfuOGS",
#     "name": "Pasquale Grasso Quartet w/ Special Guest Luigi Grasso",
#     "status": "onsale",
#     "start_date": "2025-07-11",
#     "start_time": "19:00:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "venue_id": "rZ7HnEZ174KrF",
#     "venue_name": "Birdland Theater",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/birdland-theater-new-york-ny/553788",
#     "venue_latitude": "40.7590167",
#     "venue_longitude": "-73.9896861",
#     "min_price": 35.46,
#     "max_price": 45.76,
#     "currency": "USD",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Jazz",
#     "subgenre_id": "KZazBEonSMnZfZ7vkda",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/bea/03d47f66-d37b-4aca-aa17-0135be64dbea_105801_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "on_sale_date": "2025-04-07T15:00:00Z",
#     "off_sale_date": "2025-07-11T23:00:00Z",
#     "attractions": NaN,
#     "attraction_ids": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "G5diZb0D_Eoxh",
#     "name": "An Evening with Vince Gill",
#     "status": "onsale",
#     "start_date": "2025-07-11",
#     "start_time": "19:30:00",
#     "end_date": NaN,
#     "end_time": NaN,
#     "venue_id": "KovZpZAEAd6A",
#     "venue_name": "Beacon Theatre",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10023",
#     "venue_url": "https://www.ticketmaster.com/beacon-theatre-tickets-new-york/venue/483425",
#     "venue_latitude": "40.77992500",
#     "venue_longitude": "-73.98067300",
#     "min_price": NaN,
#     "max_price": NaN,
#     "currency": NaN,
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Country",
#     "genre_id": "KnvZfZ7vAv6",
#     "subgenre": "Country",
#     "subgenre_id": "KZazBEonSMnZfZ7vAFa",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/9a5/35a98f60-f9fe-4497-9f91-7d95ac3889a5_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "on_sale_date": "2025-02-28T15:00:00Z",
#     "off_sale_date": "2025-07-12T00:30:00Z",
#     "attractions": "Vince Gill",
#     "attraction_ids": "K8vZ917117f",
#     "presale_name": "Vince Gill Fan Club Presale",
#     "presale_start_date": "2025-02-26T15:00:00Z",
#     "presale_end_date": "2025-02-28T03:00:00Z",
#     "duration_minutes": NaN
#   },
#   {
#     "id": "k7v1FbNxbGSAf",
#     "name": "Chris Tomlin - Worship Under the Stars",
#     "status": "onsale",
#     "start_date": "2025-07-11",
#     "start_time": "19:30:00",
#     "end_date": NaN,
#     "end_time": NaN,
#     "venue_id": "KovZpZA77eJA",
#     "venue_name": "Capital One City Parks Foundation SummerStage",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10021",
#     "venue_url": "https://www.ticketmaster.com/capital-one-city-parks-foundation-summerstage-tickets-new-york/venue/21",
#     "venue_latitude": "40.76920158",
#     "venue_longitude": "-73.97155468",
#     "min_price": NaN,
#     "max_price": NaN,
#     "currency": NaN,
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Religious",
#     "genre_id": "KnvZfZ7vAe7",
#     "subgenre": "Gospel",
#     "subgenre_id": "KZazBEonSMnZfZ7v6ea",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/ad6/46848aab-c22d-4f38-b4ac-ac82dc156ad6_RETINA_LANDSCAPE_16_9.jpg",
#     "on_sale_date": "2025-01-31T15:00:00Z",
#     "off_sale_date": "2025-07-12T01:30:00Z",
#     "attractions": "Chris Tomlin",
#     "attraction_ids": "K8vZ9175WR0",
#     "presale_name": "Artist Presale",
#     "presale_start_date": "2025-01-28T15:00:00Z",
#     "presale_end_date": "2025-01-31T04:59:00Z",
#     "duration_minutes": NaN
#   },
#   {
#     "id": "k7vGFbICDKEVO",
#     "name": "maye: M\u00fasica Para Abrir El Cielo Tour",
#     "status": "onsale",
#     "start_date": "2025-07-11",
#     "start_time": "20:00:00",
#     "end_date": NaN,
#     "end_time": NaN,
#     "venue_id": "KovZpZA7dkJA",
#     "venue_name": "Bowery Ballroom",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10002",
#     "venue_url": "https://www.ticketmaster.com/bowery-ballroom-tickets-new-york/venue/1100",
#     "venue_latitude": "40.72036400",
#     "venue_longitude": "-73.99354200",
#     "min_price": NaN,
#     "max_price": NaN,
#     "currency": NaN,
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Rock",
#     "genre_id": "KnvZfZ7vAeA",
#     "subgenre": "Pop",
#     "subgenre_id": "KZazBEonSMnZfZ7v6F1",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/e/be7/accfdd57-854a-484b-9c2d-e856fd4e3be7_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "on_sale_date": "2025-04-10T14:00:00Z",
#     "off_sale_date": "2025-07-12T02:00:00Z",
#     "attractions": "maye",
#     "attraction_ids": "K8vZ917QdpV",
#     "presale_name": "Citi\u00ae Cardmember Presale",
#     "presale_start_date": "2025-04-08T18:00:00Z",
#     "presale_end_date": "2025-04-10T02:00:00Z",
#     "duration_minutes": NaN
#   },
#   {
#     "id": "rZ7HnEZ1Af181K",
#     "name": "The Dirty Dozen Brass Band",
#     "status": "onsale",
#     "start_date": "2025-07-11",
#     "start_time": "20:00:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "venue_id": "rZ7HnEZaASU",
#     "venue_name": "Blue Note Jazz Club",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10012",
#     "venue_url": "https://www.ticketweb.com/venue/blue-note-jazz-club-new-york-ny/23798",
#     "venue_latitude": "40.730940",
#     "venue_longitude": "-74.000650",
#     "min_price": 49.38,
#     "max_price": 66.27,
#     "currency": "USD",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Jazz Funk",
#     "subgenre_id": "KZazBEonSMnZfZ7vkAa",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/cdf/e5c64e3d-7ded-47a0-98f8-0def24b52cdf_SOURCE",
#     "on_sale_date": "2025-03-19T13:45:00Z",
#     "off_sale_date": "2025-07-12T00:00:00Z",
#     "attractions": "The Dirty Dozen Brass Band",
#     "attraction_ids": "K8vZ91718A0",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfGabK",
#     "name": "Anat Cohen Quartetinho",
#     "status": "onsale",
#     "start_date": "2025-07-11",
#     "start_time": "20:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "venue_id": "rZ7HnEZ178J7g",
#     "venue_name": "Birdland Jazz Club",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/birdland-jazz-club-new-york-ny/426135",
#     "venue_latitude": "40.7590167",
#     "venue_longitude": "-73.9896861",
#     "min_price": 40.61,
#     "max_price": 50.91,
#     "currency": "USD",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Jazz",
#     "subgenre_id": "KZazBEonSMnZfZ7vkda",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/ad3/32a1c318-ce7e-4787-8653-433be1ddaad3_SOURCE",
#     "on_sale_date": "2025-03-19T18:05:00Z",
#     "off_sale_date": "2025-07-12T00:30:00Z",
#     "attractions": "Anat Cohen",
#     "attraction_ids": "K8vZ917uQLV",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "rZ7HnEZ1Afoa4N",
#     "name": "Bettye Lavette",
#     "status": "onsale",
#     "start_date": "2025-07-11",
#     "start_time": "20:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "venue_id": "rZ7HnEZaert",
#     "venue_name": "Iridium",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10019",
#     "venue_url": "https://www.ticketweb.com/venue/iridium-new-york-ny/10153",
#     "venue_latitude": "40.761816",
#     "venue_longitude": "-73.983389",
#     "min_price": 67.78,
#     "max_price": 79.47,
#     "currency": "USD",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Rock",
#     "genre_id": "KnvZfZ7vAeA",
#     "subgenre": "Pop",
#     "subgenre_id": "KZazBEonSMnZfZ7v6F1",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/827/1baac474-a4b1-4b12-bf36-f13573093827_RETINA_PORTRAIT_16_9.jpg",
#     "on_sale_date": "2025-05-07T04:00:00Z",
#     "off_sale_date": "2025-07-11T23:30:00Z",
#     "attractions": "Bettye LaVette",
#     "attraction_ids": "K8vZ9175gx0",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfuOud",
#     "name": "Pasquale Grasso Quartet w/ Special Guest Luigi Grasso",
#     "status": "onsale",
#     "start_date": "2025-07-11",
#     "start_time": "21:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "venue_id": "rZ7HnEZ174KrF",
#     "venue_name": "Birdland Theater",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/birdland-theater-new-york-ny/553788",
#     "venue_latitude": "40.7590167",
#     "venue_longitude": "-73.9896861",
#     "min_price": 35.46,
#     "max_price": 45.76,
#     "currency": "USD",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Jazz",
#     "subgenre_id": "KZazBEonSMnZfZ7vkda",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/bea/03d47f66-d37b-4aca-aa17-0135be64dbea_105801_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "on_sale_date": "2025-04-07T15:00:00Z",
#     "off_sale_date": "2025-07-12T01:30:00Z",
#     "attractions": NaN,
#     "attraction_ids": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfokqS",
#     "name": "Cantina After Dark FRIDAYS",
#     "status": "onsale",
#     "start_date": "2025-07-11",
#     "start_time": "22:00:00",
#     "end_date": "2025-07-12",
#     "end_time": "04:00:00",
#     "venue_id": "rZ7HnEZ173v3A",
#     "venue_name": "Cantina Rooftop",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/cantina-rooftop-new-york-ny/481485",
#     "venue_latitude": "40.7649566",
#     "venue_longitude": "-73.995973",
#     "min_price": 0.0,
#     "max_price": 20.47,
#     "currency": "USD",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "World",
#     "genre_id": "KnvZfZ7vAeF",
#     "subgenre": "Latin",
#     "subgenre_id": "KZazBEonSMnZfZ7vFdJ",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/548/5fefbd1c-973b-4b0e-9b2e-d78e4ce37548_106111_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "on_sale_date": "2025-05-06T16:00:00Z",
#     "off_sale_date": "2025-07-12T02:00:00Z",
#     "attractions": NaN,
#     "attraction_ids": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": 360.0
#   },
#   {
#     "id": "rZ7HnEZ1Af18GN",
#     "name": "The Dirty Dozen Brass Band",
# ...
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/ee6/a53be826-d659-4b27-8da2-e54446775ee6_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "on_sale_date": "2025-05-15T14:00:00Z",
#     "off_sale_date": "2025-07-19T22:00:00Z",
#     "attractions": "Don Diablo",
#     "attraction_ids": "K8vZ917otNV",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "k7vGFbI3EN90d",
#     "name": "Diggy Graves",
#     "status": "onsale",
#     "start_date": "2025-07-19",
#     "start_time": "19:00:00",
#     "end_date": NaN,
#     "end_time": NaN,
#     "venue_id": "KovZpZAEAdaA",
#     "venue_name": "Gramercy Theatre",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10010",
#     "venue_url": "https://www.ticketmaster.com/gramercy-theatre-tickets-new-york/venue/107",
#     "venue_latitude": "40.73975368",
#     "venue_longitude": "-73.98501292",
#     "min_price": NaN,
#     "max_price": NaN,
#     "currency": NaN,
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Hip-Hop/Rap",
#     "genre_id": "KnvZfZ7vAv1",
#     "subgenre": "French Rap",
#     "subgenre_id": "KZazBEonSMnZfZ7vaa1",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/e2d/36f230c2-f27f-4b61-bb93-de44d3bcae2d_RETINA_LANDSCAPE_16_9.jpg",
#     "on_sale_date": "2025-04-11T14:00:00Z",
#     "off_sale_date": "2025-07-20T01:00:00Z",
#     "attractions": "Diggy Graves, Resentvul",
#     "attraction_ids": "K8vZ917rdHV, K8vZ917rAQf",
#     "presale_name": "Live Nation Presale",
#     "presale_start_date": "2025-04-10T14:00:00Z",
#     "presale_end_date": "2025-04-11T02:00:00Z",
#     "duration_minutes": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfCe_N",
#     "name": "Hot Club of Cowtown",
#     "status": "onsale",
#     "start_date": "2025-07-19",
#     "start_time": "19:00:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "venue_id": "rZ7HnEZ174KrF",
#     "venue_name": "Birdland Theater",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/birdland-theater-new-york-ny/553788",
#     "venue_latitude": "40.7590167",
#     "venue_longitude": "-73.9896861",
#     "min_price": 30.06,
#     "max_price": 40.61,
#     "currency": "USD",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Country",
#     "genre_id": "KnvZfZ7vAv6",
#     "subgenre": "Western Swing & Country Boogie",
#     "subgenre_id": "KZazBEonSMnZfZ7vA1F",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/df8/81eadad8-4449-412e-a2b1-3d8bbb78edf8_106181_RETINA_PORTRAIT_16_9.jpg",
#     "on_sale_date": "2025-04-15T15:00:00Z",
#     "off_sale_date": "2025-07-19T21:30:00Z",
#     "attractions": "Hot Club of Cowtown",
#     "attraction_ids": "K8vZ9171nNf",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "G5dYZbfNcroLY",
#     "name": "Hugh Jackman: From New York, With Love",
#     "status": "onsale",
#     "start_date": "2025-07-19",
#     "start_time": "20:00:00",
#     "end_date": NaN,
#     "end_time": NaN,
#     "venue_id": "KovZpZAE7vdA",
#     "venue_name": "Radio City Music Hall",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10020",
#     "venue_url": "https://www.ticketmaster.com/radio-city-music-hall-tickets-new-york/venue/491523",
#     "venue_latitude": "40.75991360",
#     "venue_longitude": "-73.98039810",
#     "min_price": NaN,
#     "max_price": NaN,
#     "currency": NaN,
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Pop",
#     "genre_id": "KnvZfZ7vAev",
#     "subgenre": "Pop",
#     "subgenre_id": "KZazBEonSMnZfZ7vk1t",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/44e/17176264-319e-43ea-9aaa-9c4360ef644e_RETINA_LANDSCAPE_16_9.jpg",
#     "on_sale_date": "2024-10-18T14:00:00Z",
#     "off_sale_date": "2025-07-20T01:00:00Z",
#     "attractions": "Hugh Jackman",
#     "attraction_ids": "K8vZ917C3VV",
#     "presale_name": "Hugh Jackman Presale",
#     "presale_start_date": "2024-10-15T14:00:00Z",
#     "presale_end_date": "2024-10-18T02:00:00Z",
#     "duration_minutes": NaN
#   },
#   {
#     "id": "k7vGFbP5pSPAh",
#     "name": "Rose City Band",
#     "status": "onsale",
#     "start_date": "2025-07-19",
#     "start_time": "20:00:00",
#     "end_date": NaN,
#     "end_time": NaN,
#     "venue_id": "KovZpZA7dkJA",
#     "venue_name": "Bowery Ballroom",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10002",
#     "venue_url": "https://www.ticketmaster.com/bowery-ballroom-tickets-new-york/venue/1100",
#     "venue_latitude": "40.72036400",
#     "venue_longitude": "-73.99354200",
#     "min_price": NaN,
#     "max_price": NaN,
#     "currency": NaN,
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Country",
#     "genre_id": "KnvZfZ7vAv6",
#     "subgenre": "Country",
#     "subgenre_id": "KZazBEonSMnZfZ7vAFa",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/e/d1f/f1084e2b-6df4-4ab4-a4c6-ae28e388ed1f_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "on_sale_date": "2025-02-21T15:00:00Z",
#     "off_sale_date": "2025-07-20T02:00:00Z",
#     "attractions": "Rose City Band, Powers/Rolin Duo",
#     "attraction_ids": "K8vZ917QIC7, K8vZ917qBRV",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AK_fj7",
#     "name": "The Bad Plus",
#     "status": "onsale",
#     "start_date": "2025-07-19",
#     "start_time": "20:00:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "venue_id": "rZ7HnEZaASU",
#     "venue_name": "Blue Note Jazz Club",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10012",
#     "venue_url": "https://www.ticketweb.com/venue/blue-note-jazz-club-new-york-ny/23798",
#     "venue_latitude": "40.730940",
#     "venue_longitude": "-74.000650",
#     "min_price": 32.28,
#     "max_price": 43.61,
#     "currency": "USD",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Jazz",
#     "subgenre_id": "KZazBEonSMnZfZ7vkda",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/4b1/51028dc3-30bd-4d75-908f-fbd757eb04b1_RETINA_LANDSCAPE_16_9.jpg",
#     "on_sale_date": "2025-03-07T14:45:00Z",
#     "off_sale_date": "2025-07-20T00:00:00Z",
#     "attractions": "The Bad Plus",
#     "attraction_ids": "K8vZ9175Nef",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfGP3K",
#     "name": "Big Chief Donald Harrison Quartet",
#     "status": "onsale",
#     "start_date": "2025-07-19",
#     "start_time": "20:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "venue_id": "rZ7HnEZ178J7g",
#     "venue_name": "Birdland Jazz Club",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/birdland-jazz-club-new-york-ny/426135",
#     "venue_latitude": "40.7590167",
#     "venue_longitude": "-73.9896861",
#     "min_price": 40.61,
#     "max_price": 50.91,
#     "currency": "USD",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Jazz",
#     "subgenre_id": "KZazBEonSMnZfZ7vkda",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/3af/f9a75272-c065-4a34-bc3e-b175310513af_SOURCE",
#     "on_sale_date": "2025-03-25T18:55:00Z",
#     "off_sale_date": "2025-07-20T00:30:00Z",
#     "attractions": "Donald Harrison",
#     "attraction_ids": "K8vZ9175kd7",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfuPvd",
#     "name": "Jimmy Carpenter's Blues Band",
#     "status": "onsale",
#     "start_date": "2025-07-19",
#     "start_time": "20:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "venue_id": "rZ7HnEZaert",
#     "venue_name": "Iridium",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10019",
#     "venue_url": "https://www.ticketweb.com/venue/iridium-new-york-ny/10153",
#     "venue_latitude": "40.761816",
#     "venue_longitude": "-73.983389",
#     "min_price": 32.72,
#     "max_price": 38.56,
#     "currency": "USD",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Blues",
#     "genre_id": "KnvZfZ7vAvd",
#     "subgenre": "Blues",
#     "subgenre_id": "KZazBEonSMnZfZ7vAAd",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/7be/4e1e9428-29ec-401f-aa45-f1577614b7be_105421_RETINA_LANDSCAPE_16_9.jpg",
#     "on_sale_date": "2025-04-08T04:00:00Z",
#     "off_sale_date": "2025-07-19T23:30:00Z",
#     "attractions": NaN,
#     "attraction_ids": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfCebS",
#     "name": "Hot Club of Cowtown",
#     "status": "onsale",
#     "start_date": "2025-07-19",
#     "start_time": "21:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "venue_id": "rZ7HnEZ174KrF",
#     "venue_name": "Birdland Theater",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/birdland-theater-new-york-ny/553788",
#     "venue_latitude": "40.7590167",
#     "venue_longitude": "-73.9896861",
#     "min_price": 30.06,
#     "max_price": 40.61,
#     "currency": "USD",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Country",
#     "genre_id": "KnvZfZ7vAv6",
#     "subgenre": "Western Swing & Country Boogie",
#     "subgenre_id": "KZazBEonSMnZfZ7vA1F",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/df8/81eadad8-4449-412e-a2b1-3d8bbb78edf8_106181_RETINA_PORTRAIT_16_9.jpg",
#     "on_sale_date": "2025-04-15T15:00:00Z",
#     "off_sale_date": "2025-07-20T00:00:00Z",
#     "attractions": "Hot Club of Cowtown",
#     "attraction_ids": "K8vZ9171nNf",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "rZ7HnEZ1Afok7N",
#     "name": "Cantina After Dark SATURDAYS",
#     "status": "onsale",
#     "start_date": "2025-07-19",
#     "start_time": "22:00:00",
#     "end_date": "2025-07-20",
#     "end_time": "04:00:00",
#     "venue_id": "rZ7HnEZ173v3A",
#     "venue_name": "Cantina Rooftop",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/cantina-rooftop-new-york-ny/481485",
#     "venue_latitude": "40.7649566",
#     "venue_longitude": "-73.995973",
#     "min_price": 0.0,
#     "max_price": 20.47,
#     "currency": "USD",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "World",
#     "genre_id": "KnvZfZ7vAeF",
#     "subgenre": "Latin",
#     "subgenre_id": "KZazBEonSMnZfZ7vFdJ",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/c/548/5fefbd1c-973b-4b0e-9b2e-d78e4ce37548_106111_TABLET_LANDSCAPE_LARGE_16_9.jpg",
#     "on_sale_date": "2025-05-06T16:00:00Z",
#     "off_sale_date": "2025-07-20T02:00:00Z",
#     "attractions": NaN,
#     "attraction_ids": NaN,
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": 360.0
#   },
#   {
#     "id": "rZ7HnEZ1AK_fjV",
#     "name": "The Bad Plus",
#     "status": "onsale",
#     "start_date": "2025-07-19",
#     "start_time": "22:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "venue_id": "rZ7HnEZaASU",
#     "venue_name": "Blue Note Jazz Club",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10012",
#     "venue_url": "https://www.ticketweb.com/venue/blue-note-jazz-club-new-york-ny/23798",
#     "venue_latitude": "40.730940",
#     "venue_longitude": "-74.000650",
#     "min_price": 32.28,
#     "max_price": 43.61,
#     "currency": "USD",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Jazz",
#     "subgenre_id": "KZazBEonSMnZfZ7vkda",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/4b1/51028dc3-30bd-4d75-908f-fbd757eb04b1_RETINA_LANDSCAPE_16_9.jpg",
#     "on_sale_date": "2025-03-07T14:45:00Z",
#     "off_sale_date": "2025-07-20T02:30:00Z",
#     "attractions": "The Bad Plus",
#     "attraction_ids": "K8vZ9175Nef",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   },
#   {
#     "id": "rZ7HnEZ1AfGP4S",
#     "name": "Big Chief Donald Harrison Quartet",
#     "status": "onsale",
#     "start_date": "2025-07-19",
#     "start_time": "22:30:00",
#     "end_date": "unknown",
#     "end_time": "unknown",
#     "venue_id": "rZ7HnEZ178J7g",
#     "venue_name": "Birdland Jazz Club",
#     "venue_city": "New York",
#     "venue_state": "New York",
#     "venue_country": "United States Of America",
#     "venue_postal_code": "10036",
#     "venue_url": "https://www.ticketweb.com/venue/birdland-jazz-club-new-york-ny/426135",
#     "venue_latitude": "40.7590167",
#     "venue_longitude": "-73.9896861",
#     "min_price": 40.61,
#     "max_price": 50.91,
#     "currency": "USD",
#     "segment": "Music",
#     "segment_id": "KZFzniwnSyZfZ7v7nJ",
#     "genre": "Jazz",
#     "genre_id": "KnvZfZ7vAvE",
#     "subgenre": "Jazz",
#     "subgenre_id": "KZazBEonSMnZfZ7vkda",
#     "type": "Undefined",
#     "type_id": "KZAyXgnZfZ7v7nI",
#     "subtype": "Undefined",
#     "subtype_id": "KZFzBErXgnZfZ7v7lJ",
#     "image_url": "https://s1.ticketm.net/dam/a/3af/f9a75272-c065-4a34-bc3e-b175310513af_SOURCE",
#     "on_sale_date": "2025-03-25T18:55:00Z",
#     "off_sale_date": "2025-07-20T02:30:00Z",
#     "attractions": "Donald Harrison",
#     "attraction_ids": "K8vZ9175kd7",
#     "presale_name": NaN,
#     "presale_start_date": NaN,
#     "presale_end_date": NaN,
#     "duration_minutes": NaN
#   }
# ]
# Saved CSV to la_sports_events_20250515_140021.csv
# Saved JSON to la_sports_events_20250515_140021.json
# Saved Excel to la_sports_events_20250515_140021.xlsx
#
# === PAGINATION SUMMARY ===
# Events per page: 200
# Total events available: 1743
# Total pages available: 9
